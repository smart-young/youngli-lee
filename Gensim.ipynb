# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Gensim

# %%
df = pd.read_csv('data/petitions',sep='|', encoding='utf-8')

# %%
df.head()
# Out:
#    category       begin         end  \
# 0       일자리  2019-04-01  2019-05-01
# 1  교통/건축/국토  2019-04-01  2019-05-01
# 2       일자리  2019-04-01  2019-05-01
# 3     안전/환경  2019-04-01  2019-05-01
# 4     안전/환경  2019-04-01  2019-05-01
#
#                                              content num_agree  petition_idx  \
# 0  국민건강보험 공단 고객센터 상담사 입니다. 문재인 정부가 출범 하면서 1호 정책으로...     4,116        579345
# 1  저는 방송인 오영실입니다. 2년전 조합의 반대파 이사로 뽑인후 수많은 건수의 말도 ...     1,678        579346
# 2  안녕하십니까? 저는 사랑하는 아내와 눈에 넣어도 아프지 않은 4살난 딸을 키우고 있...     4,760        579347
# 3  국민의 이름으로 명한다 전국 환경미화원 30만공무직 그의 가족들에게 진정성 사죄와 ...     4,804        579348
# 4  안녕하십니까? 저는 부산에 살고있는 32세 청년입니다. 다름이 아니라 2019.03...     1,086        579349
#
#   status                                              title
# 0   청원종료                    국민건강보험공단 고객센터 비정규직 근로자 정규직 전환요청
# 1   청원종료  방송인 오영실입니다. 살려주세요.버닝구**, 영화 이끼같은 우리동네 조합장을 고발합니다.
# 2   청원종료        **나이스와 ***엔지니어링이 직원들에게 업무상 기름값을 지원하게 해주십시오!
# 3   청원종료                        ★환경미화원 무시 비하발언 부산시 이동호 시의원★
# 4   청원종료                                          화학공장 폭발사고

# %%
df['content'] = df['content'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") ## 한글이 아니면 ""로 변환
df['title'] = df['title'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")

# %%
df.head()
# Out:
#    category       begin         end  \
# 0       일자리  2019-04-01  2019-05-01
# 1  교통/건축/국토  2019-04-01  2019-05-01
# 2       일자리  2019-04-01  2019-05-01
# 3     안전/환경  2019-04-01  2019-05-01
# 4     안전/환경  2019-04-01  2019-05-01
#
#                                              content num_agree  petition_idx  \
# 0  국민건강보험 공단 고객센터 상담사 입니다 문재인 정부가 출범 하면서 호 정책으로 내...     4,116        579345
# 1  저는 방송인 오영실입니다 년전 조합의 반대파 이사로 뽑인후 수많은 건수의 말도 안되...     1,678        579346
# 2  안녕하십니까 저는 사랑하는 아내와 눈에 넣어도 아프지 않은 살난 딸을 키우고 있는 ...     4,760        579347
# 3  국민의 이름으로 명한다 전국 환경미화원 만공무직 그의 가족들에게 진정성 사죄와 사퇴...     4,804        579348
# 4  안녕하십니까 저는 부산에 살고있는 세 청년입니다 다름이 아니라  저희친형이 근무하고...     1,086        579349
#
#   status                                        title
# 0   청원종료              국민건강보험공단 고객센터 비정규직 근로자 정규직 전환요청
# 1   청원종료  방송인 오영실입니다 살려주세요버닝구 영화 이끼같은 우리동네 조합장을 고발합니다
# 2   청원종료        나이스와 엔지니어링이 직원들에게 업무상 기름값을 지원하게 해주십시오
# 3   청원종료                    환경미화원 무시 비하발언 부산시 이동호 시의원
# 4   청원종료                                    화학공장 폭발사고

# %%
dic = []

for title  in df['title']:
    dic.append(title.split())

# %%
dic
# Out:
# [['국민건강보험공단', '고객센터', '비정규직', '근로자', '정규직', '전환요청'],
#  ['방송인', '오영실입니다', '살려주세요버닝구', '영화', '이끼같은', '우리동네', '조합장을', '고발합니다'],
#  ['나이스와', '엔지니어링이', '직원들에게', '업무상', '기름값을', '지원하게', '해주십시오'],
#  ['환경미화원', '무시', '비하발언', '부산시', '이동호', '시의원'],
#  ['화학공장', '폭발사고'],
#  ['년',
#   '기본급을',
#   '시간으로',
#   '계산하여',
#   '누락된',
#   '약정유급휴일',
#   '수당',
#   '년치시간를',
#   '통상임금으로',
#   '지급하십시요'],
#  ['난임', '불임가정에게', '첫아이만이라도', '돈걱정안하고', '준비할수있게도와주세요'],
#  ['종교인', '퇴직소득세', '특혜법', '당장', '철회돼야', '합니다'],
#  ['정부아이돌봄서비스',
#   '아이돌보미',
#   '영유아',
#   '폭행',
#   '강력',
#   '처벌',
#   '및',
#   '재발방지방안',
#   '수립을',
#   '부탁합니다개월',
#   '아기가',
#   '아이돌보미에게',
#   '폭행을',
#   '당했습니다'],
#  ['봉사연금제', '도입으로', '국민모두가', '노후걱정없이', '안정되고', '행복한', '삶을', '누리자'],
#  ['자동차에', '강아지를', '매달고', '운전한', '인간악마를', '중형내려주세요'],
#  ['저는',
#   '의료사고로',
#   '후각장애가',
#   '왔고후각소실로',
#   '화재',
#   '가해자도',
#   '되고',
#   '피해자도',
#   '되고있습니다꼭',
#   '읽어주세요'],
#  ['경남', '의', '징계를', '막아주세요'],
#  ['정도를', '넘어', '지나친', '여성가족부의', '만행'],
#  ['한국장학재단의', '무책임함으로', '많은', '직원들이', '실직위기에', '놓여있습니다', '도와주세요'],
#  ['안녕하세요', '강릉에서도', '작은', '시골마을', '이야기입니다'],
#  ['악법도', '법', '이게', '정의', '인가', '피눈물', '나는', '돈', '돈', '돈', '을', '돌려', '주시오'],
#  ['인터넷이', '들어오게', '해주세요'],
#  ['다자녀주차장', '문제점'],
#  ['화학물질관련법', '시행에', '따른', '지입차주', '피해호소'],
#  ['투표소에서', '수개표', '청원입니다'],
#  ['국민연금유족연금을', '받을', '수', '있게', '도와', '주십시요'],
#  ['난임부부', '시험관', '지원금', '관련하여', '청원드립니다'],
#  ['월', '강서구', '환청', '살인', '사건', '가해자', '심신상실무죄', '주장'],
#  ['제', '친구가', '친아빠에게', '성추행을', '당했습니다', '도와주세요'],
#  ['공공기관', '정규직근로자를', '비정규직근로자로', '전환', '문재인', '대통령님께', '답을', '구합니다'],
#  ['수첩', '방송된', '성폭행범으로', '몰려', '억울하게', '옥살이하게한', '부실', '경검찰', '판사', '처벌해주세요'],
#  ['장애인을', '폭행한', '사람은', '강력하게', '처벌해', '주십시요'],
#  ['조기오픈밎', '연장영업금지'],
#  ['주한미군부대',
#   '내',
#   '안전조치',
#   '미흡으로',
#   '안타깝게',
#   '돌아가신',
#   '저의',
#   '삼촌',
#   '재발방지',
#   '대책',
#   '마련이',
#   '필요합니다'],
#  ['언론사의',
#   '갑질로',
#   '강원도',
#   '산골의',
#   '작은',
#   '중소기업이',
#   '크나큰',
#   '곤경에',
#   '빠졌습니다국민여러분이',
#   '힘',
#   '입니다저희에게',
#   '힘을',
#   '실어주세요'],
#  ['아이의', '미래를', '망가뜨리는', '어린이집', '정서적', '아동학대', '반드시', '처벌', '받아야', '합니다'],
#  ['평생교육의', '생태계를', '파괴하는', '재한', '이사들을', '고발합니다'],
#  ['인천', '송도에', '세계적인', '환경센터', '건립을', '희망합니다미세먼지', '관련'],
#  ['흑석구역',
#   '재개발사업의',
#   '샤시',
#   '업체',
#   '선정',
#   '특정',
#   '업체를',
#   '선정하기',
#   '위한',
#   '경쟁입찰',
#   '저해',
#   '담합',
#   '의심',
#   '신고'],
#  ['양천구강서구', '죽이는', '김포공항국제선', '추진', '반대합니다', '꼭', '하겠다면', '이것부터', '결단해주십시요'],
#  ['대학야구를', '살려주세요'],
#  ['의무공개매수', '제도를', '도입해서', '소액주주들의', '피해를', '막아주세요'],
#  ['혈액관리를', '국가정부에서', '직접', '엄격하게', '관리', '감독해주세요'],
#  ['영동군에서', '주민들', '동의', '없이', '산막리', '양수발전소', '유치', '및', '건설을', '반대합니다'],
#  ['원주', '기업도시', '초등학교', '개교를', '앞당겨', '주십시오'],
#  ['책임경영을', '다하지', '않는', '윤', '회장은', '경영에서', '물러나라'],
#  ['전문의약품', '광고금지법', '개정을', '요청합니다'],
#  ['인천', '병원의', '만행', '의료사고'],
#  ['강제적인', '종교를', '강요하는', '중학종교학교를', '폐교시켜주세요'],
#  ['미얀마', '감옥에', '갇힌', '한국인을', '구해주세요'],
#  ['자동차', '급발진', '사고', '진상규명', '바랍니다'],
#  ['학교장과',
#   '교감에',
#   '의한',
#   '직권면직',
#   '처리',
#   '진행건과',
#   '교사와',
#   '교사의',
#   '남편인',
#   '경찰에',
#   '의한',
#   '명예훼손',
#   '개인정보',
#   '침해',
#   '업무',
#   '방해',
#   '건'],
#  ['흡혈기업', '물류를', '단죄하여주세요'],
#  ['음식물',
#   '쓰레기',
#   '분리',
#   '배출이',
#   '유기물',
#   '재활용으로',
#   '변경',
#   '되기를',
#   '청원',
#   '합니다',
#   '불법',
#   '개농장의',
#   '짠밥이',
#   '사라지길',
#   '바랍니다'],
#  ['저작권을', '이용해서', '소상공인', '돈', '뜯어내는', '업체들', '막아주세요'],
#  ['공룡발자국',
#   '점이',
#   '소멸위기에',
#   '처해있어요',
#   '문화재청은',
#   '현지보존',
#   '조치를',
#   '내려',
#   '이곳을',
#   '보존해',
#   '주세요'],
#  ['주', '몽골', '대한민국', '대사관'],
#  ['드럼통', '의자', '손가락', '절단', '안전사고를', '막아주세요'],
#  ['입양', '처리', '시간', '단축'],
#  ['이재명', '경기도지사의', '보복성', '용인정신병원', '폐원을', '막아주세요'],
#  ['연합뉴스에', '국민혈세로', '지급하는', '연', '억원의', '재정보조금', '제도의', '전면', '폐지를', '청원합니다'],
#  ['수상한', '한국거래소는', '즉각', '종합감사를', '받으라'],
#  ['근로자에서', '노동자로', '명칭을', '바꿔', '주십시오'],
#  ['가', '독감백신을', '어린이', '국가예방접종에', '포함시켜주세요'],
#  ['가', '뭐꼬'],
#  ['부산시', '구', '구역', '재개발비리', '수사촉구', '청원'],
#  ['대법원은', '이윤행', '함평군수에', '대한', '상고심을', '신속하게', '진행하라'],
#  ['자유한국당', '나경원', '원내대표의', '세가지', '의혹', '풀어주세요'],
#  ['계모와', '의붓아들간의', '사실적', '관계를', '인정하는', '법률제정', '청원'],
#  ['부동산', '사기로', '날아가버린', '젊은이들의', '꿈과', '삶'],
#  ['재난', '발생', '시', '각', '방송사의', '속보', '방송', '편성을', '요청합니다'],
#  ['대규모', '화재를', '신속히', '진압할', '수', '있는', '소방비행기의', '도입을', '청원합니다'],
#  ['장애인', '재해', '대피요령을', '활성화시키고', '제대로', '검토해주세요'],
#  ['건강보험공단의', '행정업무', '실수'],
#  ['비양육자에', '대한', '양육비이행', '법을', '강력하게', '청원합니다'],
#  ['장기실종',
#   '수사팀을',
#   '전국에',
#   '만들어주시고',
#   '실종된',
#   '제',
#   '동생도',
#   '재수사',
#   '요청합니다',
#   '그리고',
#   '실종팀',
#   '인력도',
#   '늘려주십시오'],
#  ['병원', '의료과실업무과실에', '대한', '억울함을', '호소합니다'],
#  ['악성', '전문집회인', '통제', '강화', '요청', '어린이집', '인근', '통제', '강화'],
#  ['이동식주택농막', '생활권주거권', '확대와', '규제완화', '요청'],
#  ['공직자들의', '비리에', '대해서는', '공소시효를', '없애거나', '두', '배로', '늘려주세요'],
#  ['속초산불'],
#  ['군', '수협의', '수상한', '조합원', '정리에', '대해', '문제를', '제기합니다'],
#  ['자유한국당에게', '징계를', '내려주세요'],
#  ['대구',
#   '북구',
#   '농수산물시장',
#   '시장도매인',
#   '지정관련',
#   '대구시와의',
#   '유착관계',
#   '또는',
#   '공정성이',
#   '의문스럽습니다'],
#  ['은평구의', '민주주의를', '지켜주세요'],
#  ['소방공무원을', '국가직으로', '전환해주세요'],
#  ['이대로는', '소상공인들', '다', '죽습니다', '대한민국의', '문화도', '죽습니다'],
#  ['국가가', '책임져야할', '부채가', '있다던', '거짓말쟁이', '문', '대통령님'],
#  ['로스쿨', '시험', '일정', '요일을', '바꾸어', '주세요'],
#  ['마트캐셔들은', '고객님들의', '화풀이', '대상이', '아닙니다'],
#  ['쪼개기식', '난개발', '및', '공무원의', '봐주기식', '편법개발'],
#  ['현', '피해액만', '억원', '피해세입자', '여명', '익산', '전세사기사건'],
#  ['어글리', '코리안'],
#  ['여가부가', '정말', '필요한가요', '폐지', '해야합니다'],
#  ['일본의', '독도에', '대한', '역사', '왜곡에', '대해', '강하게', '대응해주세요'],
#  ['군산', '서천', '실뱀장어', '불법조업', '강력단속', '해주십시오'],
#  ['뇌전증', '환우들의', '간절한', '희망을', '국가가', '나서', '주세요'],
#  ['거꾸로', '가는', '정부', '정책', '하도급', '노동자의', '죽음을', '제발', '막아주세요'],
#  ['소방관', '분들', '및', '소방', '장비', '개선을', '위해', '다시한번', '나서주세요'],
#  ['교육청에서',
#   '버스용',
#   '카시트를',
#   '구입하고',
#   '유치원과',
#   '어린이집에',
#   '대여해',
#   '아이들이',
#   '현장학습을',
#   '안전하게',
#   '갈',
#   '수',
#   '있도록',
#   '해주세요'],
#  ['비상재난시', '어린이집도', '휴원하게', '해주세요'],
#  ['소방인력', '충원', '발목잡고', '안보실장', '붙든', '나경원', '퇴출합시다'],
#  ['건설', '근로자의', '눈물'],
#  ['뇌성마비', '아이들이', '맞는', '보톡스를', '급여화', '해주세요'],
#  ['소방관들의', '월급을', '인상', '부탁', '드립니다'],
#  ['수학여행', '폐지해주세요'],
#  ['근무하고있는', '병원의', '병원장에게', '성희롱을', '당했습니다'],
#  ['제발',
#   '난치병',
#   '환자들의',
#   '마지막',
#   '희망을',
#   '꺽지',
#   '말아',
#   '주세요',
#   '조속한',
#   '첨단재생의료법',
#   '통과를',
#   '지지해',
#   '주세요'],
#  ['나경원', '의원', '국회의원직', '박탈', '해야합니다'],
#  ['반려동물', '출입', '가능', '대피소를', '만들어', '주세요'],
#  ['산림청', '헬기', '및', '조종사에', '대한', '처우개선을', '해주세요'],
#  ['고성', '산불', '이재민들이', '국회고성연수원에서', '지낼', '수', '있도록', '도와주세요'],
#  ['소방관님들의', '월급을', '올려주세요'],
#  ['문재인', '대통령님의', '국민개헌을', '다시', '청원합니다'],
#  ['국민의', '생명을', '위협하는', '국회의원을', '고발합니다'],
#  ['수원', '고등학교', '학생들을', '도와주세요'],
#  ['소방관장갑'],
#  ['어린이집지원금을', '엄마에게주세요'],
#  ['성범죄자들에', '인심이', '후한', '대한민국'],
#  ['산림청', '특수진화대원들의', '정규직', '전환을', '청원합니다'],
#  ['동성혼을', '합법화', '해주세요'],
#  ['호박즙', '외', '먹거리', '안전성', '관련법', '개정'],
#  ['부천링거', '사망사건', '누나입니다', '동생의', '억울한', '죽음을', '밝혀주세요'],
#  ['알박기', '지주', '적폐', '박회장', '처벌하여', '주십시요'],
#  ['종묘제례악의', '정체성을', '원상복구하여', '후손에게', '물려주자'],
#  ['시', '월', '일', '풍등', '축제', '취소바랍니다'],
#  ['검찰총장의', '사건외압'],
#  ['임산부와', '교통사고', '합의', '의사가', '없는', '택시공제회를', '처벌해주세요'],
#  ['홍준연', '대구시', '구의원의', '여당', '복당에', '힘을', '실어주세요'],
#  ['거제시', '의', '억울함을', '밝혀', '주십시오', '살려주십시오'],
#  ['간통죄', '부활시켜주십시요'],
#  ['부산시', '수영구청의', '갑질행정을', '고하고자', '합니다'],
#  ['첨단바이오재생의료사업', '법안통과'],
#  ['매년', '수천억', '부당요금', '걷어가는', '도시가스회사를', '공영제로', '운영하게', '도시가스사업법을'],
#  ['양주시', '동', '축사돈사에서', '나오는', '악취를', '해결해주세요'],
#  ['살', '만세', '저희딸이', '유치원에서', '성추행을', '당했습니다'],
#  ['국가에서', '인정한', '노동자를', '만', '부정하네요'],
#  ['낙태법', '폐지를', '반대합니다', '생명의', '존엄성을', '지켜주세요'],
#  ['팩트체크', '소급입법으로', '주택임대사업자의', '뒤통수를', '친', '정부가', '맞나요'],
#  ['구역', '생활권', '시범마을', '주민', '재정착형', '잃어버린', '용적율을', '회복할수', '있게', '부탁드립니다'],
#  ['기존', '지지자들', '더이상', '이탈을', '막아주세요'],
#  ['대부업', '대출정보', '공유에', '대한', '재고를', '요청합니다'],
#  ['군', '수협', '냉동창고', '임대에', '관한', '의문점을', '해소하고', '싶습니다'],
#  ['민주당', '당대표', '이해찬', '자진사퇴를', '촉구하며', '거부시', '당', '차원', '탄핵', '요청합니다'],
#  ['전기자동차', '이동형', '충전', '모자분리', '과금을', '단독주택', '원룸', '다세대에도', '확대해', '주세요'],
#  ['마약사건조차', '신고', '접수받지', '않으려하는', '경찰의', '소극', '행정에', '대한', '대책마련'],
#  ['세계최초에', '울고있는', '협력사직원들'],
#  ['임대의무기간',
#   '년을',
#   '계약한',
#   '공공임대아파트를',
#   '임대주택법을',
#   '위반하면서',
#   '사기업에',
#   '팔아먹은',
#   '한국토지주택공사의',
#   '죄를',
#   '덮어준',
#   '감사원'],
#  ['점검시스템구축시까지', '공매도금지', '청원합니다'],
#  ['제의', '드루킹', '언론여론', '댓글', '조작', '수사해주세요', '명', '규모'],
#  ['성범죄자', '하의', '인간문화재', '자격을', '박탈해주십시오'],
#  ['학교선생님', '성추행범', '되어', '감옥행원칙과', '공정은', '어디에'],
#  ['환노위', '위원님들', '폐기물', '관리법', '통과해주세요'],
#  ['비리', '공무원에', '대한', '연금지급', '중단', '및', '국회의원', '세비', '삭감'],
#  ['건설회사', '횡포를', '막아', '주세요'],
#  ['개별주택', '공시가격', '전면', '재산정', '요청'],
#  ['구순구개열',
#   '환자',
#   '교정치료의',
#   '건강보험',
#   '급여',
#   '적용',
#   '특정',
#   '전문의가',
#   '진료한',
#   '경우만',
#   '급여',
#   '적용',
#   '규정',
#   '철회',
#   '청원합니다'],
#  ['는', '미분양', '주택', '매입을', '왜', '세금으로', '사들이나', '중단하라'],
#  ['노인', '학대하는', '아파트'],
#  ['이나라', '이정부', '검찰', '어떻게', '해야하나요'],
#  ['동물보호단체의',
#   '후원금',
#   '및',
#   '국가지원금을',
#   '기부금회계관리',
#   '플렛폼을',
#   '통해',
#   '관리',
#   '운영하는',
#   '방안을',
#   '제안드립니다'],
#  ['재교육연구원에', '대한', '허위사실유포', '및', '명예훼손행위', '중단촉구에', '동참해', '주십시오'],
#  ['화물연대의', '횡패와', '무능한', '경찰의', '공권력'],
#  ['공사비를', '못', '받아', '회사가', '부도위기에', '처해', '있습니다'],
#  ['응급',
#   '환자',
#   '처치중',
#   '구급대원의',
#   '요청을',
#   '은평',
#   '구청장은',
#   '무시했습니다',
#   '쓰러진',
#   '환자를',
#   '구호조치',
#   '하지',
#   '않은',
#   '구청장을',
#   '처벌해',
#   '주시기',
#   '바랍니다'],
#  ['개발제한구역', '내', '과도한', '행위제한으로', '도심', '속', '흉물', '제도개선', '건의'],
#  ['시청료', '납부를', '거부합니다'],
#  ['화물시장의', '적폐를', '개선해주세요'],
#  ['바다에서', '동력선을', '이용해', '낚시하는것은', '되고', '민물에서', '하는', '것은', '안되는', '이상한법'],
#  ['고성산불피해자입니다'],
#  ['퇴직금갈취', '피해자들을', '도와주세요'],
#  ['유치원초등학생중학생고등학생의', '등하교길이', '위협받고', '있습니다'],
#  ['아파트와',
#   '초중고',
#   '학교가',
#   '밀집된',
#   '지역내',
#   '층',
#   '규모의',
#   '물류센터',
#   '건립',
#   '허가용인시가',
#   '정상인가요'],
#  ['은평구', '구역', '주민들을', '살려주십시요'],
#  ['채용비리가', '난무하는', '투자증권의', '직원', '처우를', '고발합니다'],
#  ['제', '아들은', '보이스피싱', '범죄자가', '아니라', '보이스피싱', '피해자입니다', '꼭', '바로잡아', '주세요'],
#  ['속초', '강릉', '고성', '일대에', '국민참여의', '숲을', '조성해주세요'],
#  ['줬다', '뺏어', '가는'],
#  ['중증환자', '등록', '기간', '연장', '부탁', '드립니다'],
#  ['국민과', '더불어', '지역과', '소통하는', '대통령', '세종집무실', '설치를', '청원합니다'],
#  ['정치적으로', '가짜뉴스를', '퍼트리는', '사람들에게', '강력한', '제재와', '처벌이', '필요합니다'],
#  ['버닝썬', '룸', '인을', '수사해', '주세요'],
#  ['양측', '보청기', '보조금', '지원을', '받게', '해주세요'],
#  ['불법',
#   '체류',
#   '태국인에게',
#   '살해당할뻔했는데',
#   '그',
#   '태국인은',
#   '아무런',
#   '처벌없이',
#   '강제',
#   '출국했습니다',
#   '도와주십시오'],
#  ['공수처고위공직자비리수사처', '신설', '촉구', '만', '청원'],
#  ['저의',
#   '반려견이',
#   '호텔입소중',
#   '로드킬',
#   '사고를',
#   '당했습니다해당호텔대표를',
#   '처벌할수',
#   '있는',
#   '법안을',
#   '마련해주세요'],
#  ['서울', '지하철', '임산부', '배려석에', '핑크라이트', '도입을', '요청합니다'],
#  ['고액연봉', '위', '국회의원', '일은', '제대로', '하고', '있나요'],
#  ['계속기업가치',
#   '높은',
#   '해운사',
#   '회생시켜주세요',
#   '선원과',
#   '직원이',
#   '길바닥에',
#   '나',
#   '앉게',
#   '생겼습니다',
#   '협력업체의',
#   '연쇄',
#   '도산도',
#   '걱정입니다'],
#  ['보이스피싱', '전담', '합동수사단', '개설', '및', '보이스피싱', '발본색원', '요청합니다'],
#  ['세계', '수소산업', '선점을', '선언한', '문재인대통령의', '약속을', '지켜주세요'],
#  ['학교', '성교육에서', '성', '소수자의', '존재를', '지우지', '말아주세요'],
#  ['해양경찰', '근무방식을', '재조정', '해주십시오'],
#  ['후쿠시마',
#   '수산물',
#   '수입금지',
#   '관련하여',
#   '최종승소를',
#   '이끌어낸',
#   '공무원들이',
#   '특진할',
#   '수',
#   '있도록',
#   '해',
#   '주세요'],
#  ['변산반도', '운호리', '관광도로변', '석산개발을', '막아주세요'],
#  ['문재인', '대통령님', '대한민국', '가죽패션', '소공인들을', '살려', '주세요'],
#  ['동대문', '지게일을', '계속하고싶습니다'],
#  ['분양', '아파트', '건설사', '와', '시공사의', '횡포'],
#  ['유치원', '교사', '근무', '여건', '개선해주세요'],
#  ['낙태', '합법화', '이제', '저는', '산부인과', '의사를', '그만둬야', '하는', '것인지ㅠ'],
#  ['어린이', '통학차량', '안전기준', '확립'],
#  ['판사', '이미선을', '파면하고', '부당이익을', '환수해주시길', '바랍니다'],
#  ['낚시어선', '승선시', '구명조끼', '착용기준', '완화', '요청드립니다'],
#  ['중공업', '갑질', '제발', '멈춰주세요'],
#  ['그린벨트', '토지주에', '대한', '처우', '개선을', '청원합니다'],
#  ['배스를', '외래어종에서', '제외시켜', '주시기', '바랍니다'],
#  ['재벌기업', '현대의', '자유항공', '탈취를', '단죄해', '주십시오'],
#  ['고교무상교육', '정책에', '대하여', '공개질의합니다'],
#  ['신용카드', '자동납부와', '관련된', '현행제도의', '보완'],
#  ['실손보험병원비', '미지급건'],
#  ['한국과', '일본이', '성신의', '마음으로', '화목한', '이웃이', '되도록', '노력해주세요'],
#  ['교통혼잡세', '미세먼지저감'],
#  ['낙태죄', '폐지', '반대합니다'],
#  ['의료비', '지원', '보험청구의', '문제점'],
#  ['부패', '공무원', '퇴출이', '필요합니다', '원', '스트라이크제', '도입', '제안'],
#  ['동물', '실험을', '제한해주세요'],
#  ['아들의', '억울한', '죽음안에', '가려진', '음모를', '밝혀주세요'],
#  ['이미선', '헌법재판관', '후보자의', '지명철회를', '청원합니다'],
#  ['한국', '노동', '시장', '개선', '방안'],
#  ['세월호참사재난에서', '생명을', '지켜줄', '안전장치', '법안', '제정'],
#  ['편의점', '허위', '과장', '정보제공으로', '인한', '피해'],
#  ['왜', '국가는', '수', '십', '년간', '같은', '불편을', '겪고', '있는', '국민들을', '대변하지', '않습니까'],
#  ['애완견', '관리', '소홀에', '대한', '처벌', '강력', '법제화', '요청'],
#  ['미성년자', '아동폭행에', '대한', '처벌', '강화', '및', '피해보상', '강화성폭행은', '무기징역', '바람'],
#  ['신안', '압해읍', '도로', '차선으로', '빨리', '시공하라'],
#  ['남양주시', '읍', '배드민턴', '실체'],
#  ['대통령보다', '군수가', '더', '높습니까'],
#  ['통신판매점',
#   '갑질',
#   '횡포',
#   '본인',
#   '아래는',
#   '서민이라',
#   '칭하는',
#   '사람',
#   '돈이면',
#   '다되는',
#   '갑질',
#   '횡포'],
#  ['대', '에브리타임의', '익명제보', '시스템을', '바꿔주시기를', '간곡히', '부탁드립니다'],
#  ['년차',
#   '월',
#   '만원대의',
#   '급여를',
#   '받으며',
#   '한전',
#   '직원',
#   '아닌',
#   '시간',
#   '일',
#   '일하고',
#   '있는',
#   '한전',
#   '고객센터',
#   '상담사입니다'],
#  ['경기도', '안성의', '요양원', '원장을', '강력히', '처벌해', '주십시요'],
#  ['정부지침', '어기는', '한전을', '말한다', '그리고', '한전고객센터의', '비정규직의', '현실'],
#  ['복합부위통증증후군', '환우분들을', '도와주세요'],
#  ['교육부의', '노예계약과', '차별정책', '철폐를', '청원합니다'],
#  ['소셜카지노', '규제완화를', '통한', '모바일', '게임', '강국의', '위상을', '높여주세요'],
#  ['억울하게', '미얀마', '교도소에', '갇혀있는', '아버지를', '구해주세요'],
#  ['제', '아들을', '돌려주세요양육권', '불이행'],
#  ['지역자활센터의', '부당한', '일', '처리'],
#  ['검찰개혁을', '위해', '이시대의', '양심자', '임은정', '검사님을', '검찰총장으로', '추천합니다'],
#  ['세월호', '유가족', '막말한', '차명진', '전', '새누리당', '의원을', '처벌해주시기', '바랍니다'],
#  ['긴급', '아파트', '경비원', '부당해고', '관련', '청원합니다'],
#  ['반민특위',
#   '다큐멘터리',
#   '제작',
#   '중단에',
#   '책임이',
#   '있는',
#   '인사의',
#   '부사장',
#   '임명',
#   '철회와',
#   '의',
#   '반민특위',
#   '다큐멘터리',
#   '제작',
#   '재개를',
#   '요구합니다'],
#  ['대', '수의대에서', '실험중인', '퇴역', '탐지견을', '구조해주십시요'],
#  ['서울대', '법대생', '노', '진수학번실종사건'],
#  ['어렵고',
#   '힘든시기를',
#   '상생의',
#   '마음으로',
#   '생사고락을',
#   '함께하며',
#   '오늘의',
#   '시를',
#   '있게',
#   '한',
#   '대리점을',
#   '헌신짝',
#   '버리듯',
#   '우습게',
#   '아는',
#   '시를',
#   '고발합니다'],
#  ['무조건적인', '반대', '전', '반대합니다'],
#  ['국립생태원공공기관', '정규직', '전환후', '임금삭감', '월', '여만원'],
#  ['동물학대범', '대', '이교수를', '조사', '및', '처벌해주세요'],
#  ['직장',
#   '내',
#   '괴롭힘의',
#   '금지',
#   '법안',
#   '소급적용',
#   '및',
#   '가해자',
#   '및',
#   '책임자',
#   '엄벌기준',
#   '강화',
#   '요청'],
#  ['검찰', '고위직', '출신', '변호사의', '사기', '방조행위를', '공정하게', '수사해', '주세요'],
#  ['거리흡연금지법을', '만들어주세요', '흡연구역', '제정'],
#  ['세월호', '유족을', '조롱하는', '네이버', '댓글에', '대한', '조사를', '해주세요'],
#  ['중고나라', '사기꾼', '엄벌', '청원합니다'],
#  ['벚꽃대신', '무궁화를', '살려시민의식을', '높입시다'],
#  ['이게', '학교인가'],
#  ['기타시도', '버스', '종사자', '국가공영제', '실시해주세요'],
#  ['변경된', '초등학교신설기준을학교총량제', '완화해주세요'],
#  ['불법안마시술소', '안마사자격증', '회', '적발시에도', '영구', '퇴출', '청원합니다'],
#  ['제의', '도가니', '어린이집', '이사장의', '강제성추행과', '국가보조금', '횡령'],
#  ['포항에이즈사건', '전국에', '개설신고필증', '없는', '마사지업소', '강제폐쇄', '요구', '합니다'],
#  ['송파구', '잠실주공단지', '주민의', '지옥같은', '삶을', '구해', '주십시요'],
#  ['인천', '지구대와', '경찰서와', '조폭과의', '유착의혹이', '듭니다'],
#  ['임산부배려석이', '없는', '차종을', '운행하는', '호선'],
#  ['문화재를', '파괴하는', '문화재', '보호법'],
#  ['억울하게', '돌아가신', '저희', '아버지를', '도와주세요'],
#  ['문재인', '정부의', '풍력발전', '강행은', '또다른', '대강이며', '적폐', '또는', '파괴자다'],
#  ['고', '장자연님', '증언사기', '윤의', '대국민', '사기극을', '막아주시길', '간곡히', '부탁', '드립니다'],
#  ['가정파괴범', '신의', '총회장이자', '교주인', '이를', '구속수사해주세요'],
#  ['박근혜', '대통령님의', '석방을', '청원합니다'],
#  ['진주', '방화', '및', '살인', '범죄자에', '대해서', '무관용', '원칙이', '필요합니다'],
#  ['세월호', '시간', '관련', '봉인된', '대통령', '기록물', '공개', '요청'],
#  ['젖병세정제에', '유해물질', '검출', '재발방지', '대책을', '마련하라'],
#  ['불투명한', '엄궁구역', '재개발', '조합'],
#  ['적폐청산'],
#  ['사회적',
#   '약자가',
#   '공정한',
#   '재판을',
#   '받을수',
#   '있도록',
#   '제발',
#   '도와주세요',
#   '저는',
#   '현재',
#   '임산부입니다'],
#  ['박근혜에게', '형', '집행금지', '허가', '금지', '사면', '석방', '절대', '금지'],
#  ['가습기', '살균제', '젖병세정제', '대표', '구속', '수사', '해주세요'],
#  ['범죄자와', '민원신고누적자의', '임대아파트', '강제퇴거', '방안을', '마련해주세요'],
#  ['진주',
#   '방화및',
#   '살인',
#   '범죄자에',
#   '대해서',
#   '피해자와',
#   '남겨진',
#   '가족들을',
#   '먼저',
#   '봐주셨으면',
#   '합니다'],
#  ['진주',
#   '계획형',
#   '방화살인사건에',
#   '초기',
#   '부실한',
#   '대처로',
#   '예견된',
#   '사건을',
#   '막지',
#   '못한',
#   '경찰들',
#   '및',
#   '관련자들의',
#   '엄중한',
#   '수사를',
#   '부탁드립니다'],
#  ['산불진화대원의', '억울한사연'],
#  ['김경수경남', '도지사의', '특검', '허익범을', '특검밎조사해주십시요'],
#  ['남양주시', '토지매입의혹', '예식장', '특혜매입', '철저히', '밝혀주세요'],
#  ['박근혜', '대통령의', '형집행정지', '및', '사면은', '절대', '안됩니다'],
#  ['농민', '및', '일반인여명을', '상대로한', '사기피해를', '호소합니다실명'],
#  ['교사가', '학생을', '지도할', '수', '있게', '대책을', '세워주세요'],
#  ['공무원들의', '소극적인', '태도가', '돈없고', '힘없는', '국민들을', '더', '피말리게', '합니다'],
#  ['피해자를',
#   '두번',
#   '죽이는',
#   '부패한',
#   '법조인들과',
#   '청와대와',
#   '책임과',
#   '의무를',
#   '함께',
#   '하지',
#   '않는',
#   '사법',
#   '기관은',
#   '반드시',
#   '고쳐져야',
#   '합니다'],
#  ['건설사의', '불법행위에', '대하여', '처벌바랍니다'],
#  ['지하철', '버스', '임산부', '배려석에', '대해', '한', '말씀드리겠습니다'],
#  ['진주', '사건과', '관련하여', '출동', '경찰관에', '대한', '문책을', '중단할', '것을', '청원합니다'],
#  ['칠곡군의회', '이재호의장의', '꼼수', '해외연수를', '막아주세요'],
#  ['청정진도', '팽목항현', '진도항배후지', '석탄재폐기물', '매립', '막아주세요'],
#  ['금성탑리', '버스터미널을', '지원해주세요'],
#  ['상장페지', '관련'],
#  ['소액사기', '업체들을', '강력처벌할', '수', '있게', '해주세요'],
#  ['범죄', '관한', '법', '개안하고', '바꾸길', '원합니다'],
#  ['뼈폐', '전이된', '말기', '암환자들도', '대한민국', '국민입니다'],
#  ['비급여', '항암치료에', '대한', '건강보험', '적용', '청원합니다'],
#  ['후계농업인이', '너무', '힘들어요'],
#  ['불법체류자에게',
#   '출생신고',
#   '의료',
#   '교육',
#   '혜택',
#   '주는',
#   '경기도',
#   '이주',
#   '아동',
#   '지원',
#   '조례',
#   '추진하지',
#   '마십시오'],
#  ['이동통신사의', '일방적이고', '불법적인', '위약금', '및', '요금체계를', '바로잡아주세요'],
#  ['불법과', '인권유린을', '반복자행하는', '요양원을', '폐쇄시켜주시기', '바랍니다'],
#  ['대한민국', '올바른', '동물병원', '진료비', '개선과', '동물보호법', '개정에', '대해', '청원합니다'],
#  ['제의', '상도유치원', '항동지구를', '무너트리는', '서서울고속도로', '사람이', '죽어야', '돌아보시겠습니까'],
#  ['관광버스에', '만세미만', '카시트장착', '유예기간을', '년', '준', '국토부는', '해결하십시오'],
#  ['손녀를', '만나게', '해주세요'],
#  ['포탄파편을',
#   '평생',
#   '몸에',
#   '지닌채',
#   '살아가는',
#   '연평도포격전',
#   '부상자들에게',
#   '명예를',
#   '회복시켜주시고',
#   '성대한',
#   '전역식을',
#   '치뤄주십시요'],
#  ['사기로', '수천만원', '공금횡령한', '자에게', '불문경고가', '왠', '말'],
#  ['신성장동력', '농업환경보건복지'],
#  ['심신미약', '등의', '판정을', '얻기', '위해', '조현병으로', '둔갑하려는', '강력범죄자들을', '엄벌하여', '주세요'],
#  ['안녕하세요', '증인', '윤지오입니다', '증인보호법을', '간곡히', '요청합니다'],
#  ['문재인', '탄핵', '동의하시길', '부탁드립니다'],
#  ['터무니',
#   '없는',
#   '공동주택',
#   '공시가격',
#   '인상에',
#   '중산층이',
#   '무너지고',
#   '있습니다',
#   '이에',
#   '대한',
#   '재고를',
#   '강력히',
#   '요청합니다'],
#  ['원주', '무실', '민간임대주택촉진지구'],
#  ['교과교실제폐지', '청원'],
#  ['수협의', '적폐를', '청산해주십시요'],
#  ['대학원', '년', '동안', '단', '회', '출석으로', '박사학위', '취득', '이거', '정당한가요'],
#  ['남학생의',
#   '학교',
#   '폭력으로',
#   '제',
#   '딸이',
#   '간이',
#   '찢어졌습니다',
#   '가해자',
#   '부모는',
#   '학폭',
#   '담당',
#   '교사입니다'],
#  ['생지옥의',
#   '계단실',
#   '안인득',
#   '방화',
#   '살인사건에',
#   '대한',
#   '개양파출소와',
#   '경찰의',
#   '명백한',
#   '책임인정과',
#   '진심어린',
#   '사과문',
#   '발표를',
#   '청원합니다'],
#  ['상가임대차보호법을', '무시하고', '무법으로', '세입자를', '쫓아내는', '환경을', '고발합니다'],
#  ['고소인', '없는', '형사고소', '사건', '있을', '수', '있는', '일인가요'],
#  ['교사로부터의', '정서적', '학대'],
#  ['친일', '교사를', '공무원', '박탈', '시켜주세요'],
#  ['층간소음', '피해자를', '위한', '법안을', '만들어주세요'],
#  ['케익', '본사의', '횡포', '처벌규정강화및', '철저한', '조사청원합니다'],
#  ['노후건물', '외벽붕괴', '위험으로', '도로를', '지나기가', '불안합니다'],
#  ['일방통행', '무조건적인', '과도한', '부동산', '규제정책', '지역', '면적', '용도별', '완화를', '원합니다'],
#  ['속초', '이등병', '자살사전', '묻히지', '않게', '제대로된', '조사를', '부탁합니다'],
#  ['경남', '진주', '시장', '세입자들의', '억울함을', '들어주세요'],
#  ['경찰서', '경찰들이', '김경수', '지사', '차량에', '테러를', '시도하는', '태극기을', '비호'],
#  ['아파트조합원임대일반분양취득세부담'],
#  ['살고싶습니다', '바른정비하는', '자동차정비공업사들을', '도와주세요'],
#  ['개인에게',
#   '행하는',
#   '지속적인',
#   '언어',
#   '폭력이',
#   '범죄인지',
#   '모르는',
#   '소년범들',
#   '피해자가',
#   '피해',
#   '상황을',
#   '수사하고',
#   '입증해서',
#   '떠먹여줘야',
#   '되는',
#   '경찰과',
#   '검찰',
#   '우리나라는',
#   '범죄자가',
#   '살기',
#   '좋은',
#   '나라입니다'],
#  ['고성한전발화', '피해보상', '요청합니다'],
#  ['건설사', '건설의', '횡포', '언제까지', '공동주택하자', '아파트하자', '있는', '집에', '살아야합니까'],
#  ['자운대', '군', '주거시설', '시설', '및', '미화노동자에', '대한', '무기계약정규직', '전환의', '건'],
#  ['자유', '한국당', '정당해산', '청원'],
#  ['낙태법', '폐지에', '대하여'],
#  ['주베트남', '대한민국대사', '김도현', '관련'],
#  ['한베가족',
#   '아쉬운',
#   '것은',
#   '폭넓은',
#   '이해와',
#   '관심으로서',
#   '진취적으로',
#   '자기일처럼',
#   '나서주실분을',
#   '다시',
#   '만날',
#   '기회가',
#   '과연',
#   '있겠나',
#   '하는',
#   '생각이',
#   '들었습니다'],
#  ['불법', '촬영물을', '유포한', '기자', '단체', '카톡방의', '수사를', '강력히', '촉구합니다'],
#  ['태극기집회', '지원금을', '막아주세요'],
#  ['헌법재판소', '해산'],
#  ['세종고속도로', '안성공구', '고삼교', '및', '고삼휴게소', '건설간', '재난', '및', '피해방지책', '촉구'],
#  ['권순일',
#   '대법관님',
#   '관련',
#   '문재인',
#   '대통령님은',
#   '재수사',
#   '하라고',
#   '긴급',
#   '대통령령을',
#   '발하',
#   '요청',
#   '및',
#   '공수처',
#   '신설',
#   '법안',
#   '대상',
#   '확대',
#   '발의안',
#   '국회',
#   '통과',
#   '요청',
#   '신규',
#   '청원서'],
#  ['법원으로',
#   '부터',
#   '양육권과',
#   '친권을',
#   '받으면',
#   '뭐하나요',
#   '아이뺏기면',
#   '판결문',
#   '토대로',
#   '바로',
#   '데리고',
#   '올수',
#   '있도록',
#   '법안을',
#   '만들어주세요'],
#  ['아동학대는',
#   '어떠한',
#   '사유로도',
#   '정당화',
#   '될',
#   '수',
#   '없습니다',
#   '법의',
#   '진실은',
#   '꼭',
#   '밝혀질것입니다'],
#  ['물류',
#   '현',
#   '사태의',
#   '배경',
#   '물류',
#   '지입기사',
#   '명',
#   '무고지',
#   '강제',
#   '계약해지',
#   '운송료',
#   '차별지급'],
#  ['국회의원의',
#   '장관',
#   '겸직은',
#   '반드시',
#   '없어져야',
#   '합니다',
#   '국회의원의',
#   '장관',
#   '겸직',
#   '자체가',
#   '특권이다'],
#  ['산재', '처리'],
#  ['산불', '화재', '한전', '노후', '개폐기', '변압기', '교체해야', '되지', '않을까요'],
#  ['상수원', '정수장', '하수처리장을', '재난', '예방지구', '지정해요'],
#  ['한국산업인력공단에서', '시행하는', '모든', '자격시험', '종료후', '모범답안을', '공개해', '주세요'],
#  ['경찰이',
#   '칼부림',
#   '등',
#   '시민들의',
#   '생명이',
#   '위협받는',
#   '상황에서',
#   '안전하게',
#   '사태를',
#   '진압하고',
#   '현행범을',
#   '사살하더라도',
#   '법적책임을',
#   '지지않게',
#   '해주세요ㅂ'],
#  ['건물주의', '무관심', '관리인의', '횡포에', '세입자는', '울고간다'],
#  ['진주',
#   '방화살인사건',
#   '같이',
#   '불안하게',
#   '살아야',
#   '하는',
#   '우리',
#   '대한민국을',
#   '국가가',
#   '적극',
#   '관리하여주시기를',
#   '간절히',
#   '청원',
#   '합니다'],
#  ['대만미국이라', '국호', '잘못', '쓴', '문재인대통령', '사퇴', '시켜주세요'],
#  ['손녀를보여주세요의', '속이야기입니다'],
#  ['년을', '일해도', '최저임금', '한전고객센터상담사들의', '비애'],
#  ['명', '조합원', '좀', '살려주세요'],
#  ['화재가',
#   '보험료',
#   '사기한',
#   '사실들을',
#   '묵살',
#   '은폐',
#   '방조',
#   '비호하고',
#   '있는',
#   '썩을데로',
#   '썩어버린',
#   '금융감독원',
#   '서울경찰을',
#   '고발합니다'],
#  ['화재손해보험보험회사의', '횡포와', '갑질에서', '벗어날', '수', '있도록', '도와주세요'],
#  ['국회의원도', '국민이', '직접', '소환할', '수', '있어야', '합니다'],
#  ['인천여의도', '번', '버스', '폐선을', '막아주세요'],
#  ['북한군', '추모제를', '지내는', '적군묘지를', '폐쇄해', '주세요'],
#  ['지금의',
#   '를',
#   '있게',
#   '한',
#   '숨은',
#   '주역',
#   '운용협력사하청업체',
#   '직원들은',
#   '에',
#   '직고용',
#   '되어야',
#   '합니다'],
#  ['중소기억', '억', '수주한', '분에대한', '혐오를', '멈춰주세요'],
#  ['악의적', '민원의', '검증', '및', '원인제공자', '처벌과', '시정유예기간', '연장관련', '행정', '요청'],
#  ['장애인', '근로자의', '생존권을', '지켜주세요'],
#  ['전자개표기', '폐지', '동의하시길', '부탁드립니다'],
#  ['공공임대주택', '전세형태', '계약', '가능하게', '등'],
#  ['저는', '하청운용협력사', '노동자입니다'],
#  ['방송', '조계사', '국고보조금', '부정수급', '철저한', '수사와', '감사를', '바랍니다'],
#  ['인천소방', '현장중심', '승진은', '내근중심', '승진제도를', '개선해주세요'],
#  ['잘못된건축정책건축행정의난맥상은바뀌어져야합니다'],
#  ['김기현', '전', '울산시장', '측근비리수사', '특검을', '청원합니다'],
#  ['저희', '할아버지께서', '요양병원에서', '조선족', '간병인한테', '무척', '심한폭행을', '받았습니다', '도와주세요'],
#  ['국민의',
#   '안전을',
#   '위해',
#   '대규모',
#   '아파트',
#   '단지구로',
#   '항동지구를',
#   '관통하는',
#   '고속도로',
#   '지하터널',
#   '건설을',
#   '재고해주시길',
#   '청원합니다'],
#  ['유아전집', '출판사의', '갑질을', '신고합니다'],
#  ['심신미약자에게는', '한없이', '자비로운', '대한민국'],
#  ['남편의', '죽음에', '정부는', '뒷짐지지', '말아주십시오'],
#  ['부도덕한일을하고도', '바로잡혀지질않습니다'],
#  ['고흥군', '면', '마울은', '귀농귀촌안들에게', '강도행위을', '중단하게', '해주세요'],
#  ['산업인력공단', '전기공사실기'],
#  ['제친구가', '억울하게죽음을맞이햇습니다'],
#  ['민주주의', '대한민국에서', '벌어지는', '공산당과', '같은', '행위를', '막아주세요'],
#  ['조선일보가',
#   '주관하는',
#   '청룡봉사상',
#   '수상자에',
#   '대한',
#   '경찰',
#   '계급',
#   '특진제도',
#   '당장',
#   '폐지하여',
#   '주십시오'],
#  ['가좌주공',
#   '살인방화사건에',
#   '남겨진',
#   '입주민들의',
#   '차',
#   '피해대책',
#   '제대로',
#   '알아봐주세요',
#   '현실은',
#   '다릅니다'],
#  ['노인', '무임승차제도를', '폐지해주세요'],
#  ['운동을', '혁명으로', '바꾸자'],
#  ['국회의원', '의정활동', '실시간', '평가', '및', '국민제명', '시스템', '구축'],
#  ['한국어교원', '전용', '근로감독', '부서를', '개설해', '주십시오'],
#  ['진주사건', '막을', '수', '있었다', '지역기반', '응급대응체계', '구축을', '바로', '실시해', '주세요'],
#  ['건설현장', '차단막', '미설치는', '피해자잘못'],
#  ['강력범죄자는', '이렇게', '처벌해주세요'],
#  ['정부는', '집값', '안정화', '대책에', '대해', '다시', '한번', '고민', '바랍니다'],
#  ['소주', '가격', '인상', '막아주셨으면', '합니다'],
#  ['학교폭력을', '조장하는', '학교', '가담자를', '은폐하는', '학교', '저희', '아이들을', '지켜주세요'],
#  ['아파트', '관리동', '어린이집', '비리를', '고발합니다'],
#  ['간호사와', '간호조무사', '간', '업무분장을', '법으로', '명시해', '주십시오'],
#  ['나경원', '원내대표', '세가지', '의혹', '풀어', '줍시다'],
#  ['악질',
#   '할머니',
#   '한테',
#   '모진',
#   '고문과',
#   '학대를',
#   '받은',
#   '손녀손자',
#   '들의',
#   '억욱함을',
#   '풀어',
#   '주세요'],
#  ['국회법',
#   '제',
#   '조',
#   '및',
#   '제',
#   '조에',
#   '의거',
#   '사개특위',
#   '회의를',
#   '방해한',
#   '자유한국당',
#   '의원들의',
#   '처벌을',
#   '바랍니다'],
#  ['상가', '권리금', '중개에', '관한', '기준을', '만들어주세요'],
#  ['더불어민주당', '해체', '동의하시길', '부탁드립니다'],
#  ['어린이집', '원장', '담임을', '못하게', '해주세요'],
#  ['산불',
#   '때문에',
#   '국가비상사태가',
#   '일어난',
#   '와중에',
#   '상황',
#   '파악을',
#   '전혀',
#   '안하고',
#   '악행의',
#   '끝을',
#   '찍은',
#   '자한당에',
#   '대한',
#   '전면',
#   '해체를',
#   '강력',
#   '요청합니다'],
#  ['중고등학교에서', '비전공', '교사가', '교과를', '가르치지', '않도록', '해주세요'],
#  ['경남진주에서',
#   '발생한',
#   '정신질환자',
#   '안씨가',
#   '저지른',
#   '방화살인사건의',
#   '원인이',
#   '된',
#   '개정',
#   '정신보건법',
#   '전면',
#   '재개정이',
#   '요구된다'],
#  ['화목보일러로', '인한', '주택전소', '및', '인명피해'],
#  ['대통령님', '고', '이선생님을', '만나', '주세요'],
#  ['더불어', '민주당', '해산하라'],
#  ['피해자를',
#   '범죄자로',
#   '만들어',
#   '적법한',
#   '절차없는',
#   '구치소',
#   '구금',
#   '등',
#   '공권력에',
#   '의한',
#   '인권유린고발'],
#  ['서울', '장안초등학교', '정문', '폐쇄건'],
#  ['더불어', '민주당', '정당', '해체', '청원'],
#  ['억울한',
#   '일을',
#   '당했습니다',
#   '평창군청이',
#   '지하수개발업체',
#   '측의',
#   '편에서',
#   '저희',
#   '집',
#   '바로옆에',
#   '공장허가',
#   '승인을',
#   '했습니다'],
#  ['청년실업을', '넘어', '이제는서민가정이', '위험'],
#  ['채이배',
#   '국회의원의',
#   '의원실을',
#   '점거하여',
#   '채이배를',
#   '감금한',
#   '자유한국당의원',
#   '민경욱',
#   '여상규',
#   '등',
#   '그외',
#   '자유한국당',
#   '의원들을',
#   '협박',
#   '및',
#   '감금죄로',
#   '형사처벌',
#   '해주십시오'],
#  ['더불어', '민주당', '정당해산', '청원'],
#  ['더블어', '민주당', '해산', '청원', '합니다'],
#  ['성인사시과', '과연', '성형수술과', '같은', '미용', '목적의', '수술과', '동일시', '될만한', '수술인가요'],
#  ['어린이집', '법정', '교사대', '아동비율을', '줄여주세요'],
#  ['성남', '교회의', '피해대책을', '요구합니다'],
#  ['저는',
#   '조현병을',
#   '앓고',
#   '있는',
#   '환자의',
#   '동생입니다',
#   '무고한',
#   '이웃이',
#   '희생되지',
#   '않게',
#   '조현병',
#   '환자를',
#   '관리할',
#   '법',
#   '개정이',
#   '시급합니다'],
#  ['민주당', '해산청원합니다'],
#  ['곰탕집',
#   '성추행',
#   '사건의',
#   '위헌재판',
#   '결과에',
#   '유감을',
#   '표하며',
#   '향후',
#   '위헌재판',
#   '재발방지와',
#   '사법부의',
#   '대국민',
#   '사과를',
#   '요구합니다'],
#  ['국회', '선진화법을', '위반한', '국회의원의', '처벌을', '강력히', '원합니다'],
#  ['복지원', '피해자', '입니다'],
#  ['조부의', '추악한', '성적', '아동학대'],
#  ['구역', '주택재개발사업조합장'],
#  ['정신질환자', '공동생활', '시설', '건립을', '철회', '해주세요'],
#  ['더불어', '민주당', '정당해산청구'],
#  ['전기산업기사', '과정평가형', '으로의', '변경안', '반대합니다'],
#  ['친일', '매국노의', '대법원', '공직자들이', '여년간', '나라', '땅을', '강탈한', '내용입니다'],
#  ['반인륜적', '사기행각을', '벌이는', '사이비교회', '교회', '이목사를', '처벌해주세요'],
#  ['국회법',
#   '조',
#   '조를',
#   '위반한',
#   '국회의원과',
#   '당직자',
#   '전원에',
#   '대한',
#   '신속하고',
#   '엄격한',
#   '처벌을',
#   '청원합니다'],
#  ['특별법',
#   '개정안',
#   '역사왜곡',
#   '처벌법',
#   '현재',
#   '패스트트랙으로',
#   '처리되려고',
#   '하는',
#   '공수처법고위공직자비리수사처',
#   '설치법과',
#   '선거제',
#   '개혁안연동형',
#   '비례대표제',
#   '반대합니다'],
#  ['전기산업기사의', '과정형평가', '전환을', '결사', '반대', '합니다', '전기안전관리는', '뒷전인가'],
#  ['사회복무요원의', '식비는', '과연', '정당한가'],
#  ['한유총', '로비스트된', '민주당', '경기도', '의원들을', '징계해야', '합니다'],
#  ['좌파독재정당', '더불어민주당을', '해산시켜주세요'],
#  ['제천화재', '소방관', '징계', '철회', '해주세요'],
#  ['전기산업기사', '과정평가형', '자격제도', '전환', '반대합니다'],
#  ['국민대사기', '넷', '진상조사', '간곡히', '부탁드립니다'],
#  ['자유한국당의원', '단', '한명이라도', '법적', '처벌은', '안된다'],
#  ['국회의원', '비례대표제', '폐지를', '청원합니다'],
#  ['범죄자', '조두순의', '출소를', '강력히', '반대합니다'],
#  ['퇴직금',
#   '요구하는',
#   '퇴사자를',
#   '모욕하고',
#   '시장상인들과',
#   '담합해',
#   '손씨를',
#   '퇴출결의한',
#   '항',
#   '상인과',
#   '항',
#   '수산시장을',
#   '처벌해주세요'],
#  ['가이드라인을', '악용하는', '한전', '정규직화', '막힌', '한전고객센터'],
#  ['대부업체와', '사법적폐세력의', '커넥션', '조사'],
#  ['언니', '글씨체가', '아니었다', '증인', '윤지오', '사기혐의', '검토', '및', '처벌', '요청'],
#  ['엔터테인먼트', '소속사에게', '말하고', '싶습니다'],
#  ['반려동물을', '이동식', '장례차에서', '간편하게', '장례를', '치를', '수', '있도록', '해주세요'],
#  ['대기업의',
#   '채용에',
#   '하청업체협력업체',
#   '밴드',
#   '사내',
#   '사외에서',
#   '이상을',
#   '채용하는',
#   '것을',
#   '법규',
#   '또는',
#   '규정으로',
#   '만들어',
#   '주길',
#   '바램니다'],
#  ['전기산업기사', '과정평가제도', '반대'],
#  ['자유한국당의', '해산을', '촉구합니다'],
#  ['더불어민주당', '정당', '해산', '청원'],
#  ['시각장애인들의', '위한', '지폐의', '점자', '활성화'],
#  ['금융', '관리', '서리제차', '유동화회사의', '부채로', '인한', '서민의', '어려움을', '간곡하게', '호소합니다'],
#  ['다자녀', '가정에겐', '자동차세', '감면', '혜택을', '청원합니다'],
#  ['더불어민주당', '정당해산청구를', '강력', '촉구합니다'],
#  ['법원과', '검찰은', '법과', '원칙을', '지켜라국회폭력'],
#  ['더불어민주당', '정당해산', '국민청원'],
#  ['김', '감독을', '에서', '영구제명', '시켜주세요'],
#  ['우리아이의유일한', '치료법이', '국가에', '의해', '금지된ㅠㅠ'],
#  ['저희', '아이', '어쩌면', '좋을까요'],
#  ['국회선진화법으로', '자유', '한국당', '전원', '의원직', '박탈', '청원합니다'],
#  ['문재인', '대통령님', '제', '손가락을', '잘라버리고', '싶습니다'],
#  ['전국의', '인형뽑기방에', '대한', '무분별한', '단속을', '자제해주시고', '년', '전의', '법을', '개정바랍니다'],
#  ['국회의원', '국민소환제', '도입', '부탁드립니다'],
#  ['서울도시철도지하철', '종로가역에', '전태일역을', '병기해', '주세요'],
#  ['자유한국당',
#   '해체',
#   '청원에',
#   '반대하며',
#   '오히려',
#   '진정',
#   '해체',
#   '되어야',
#   '할',
#   '건',
#   '지금의',
#   '더불어',
#   '민주당으로',
#   '민주당',
#   '해체',
#   '해산',
#   '바랍니다'],
#  ['중증아토피', '치료제인', '듀피젠트를', '보험적용화', '보급화시켜주세요'],
#  ['교육계에서', '비리가이하', '인권침해', '생활기록부위조', '인권유린', '일어나도', '되는건가요'],
#  ['전쟁',
#   '중에',
#   '장수를',
#   '교체할',
#   '수',
#   '없습니다',
#   '더불어민주당',
#   '신임',
#   '원내대표',
#   '선출을',
#   '위한',
#   '선거',
#   '연기를',
#   '간곡히',
#   '청원합니다'],
#  ['자유한국당은', '의원직', '총사퇴', '약속을', '꼭', '지켜주시기', '바랍니다'],
#  ['화공기사', '과정평가형으로의', '전환을', '결사', '반대합니다'],
#  ['낚시승객의', '음주단속은', '폐지되어야', '합니다'],
#  ['바이크이상', '자동차', '전용도로', '통행규제', '풀어주세요'],
#  ['코레일', '신호제어장치', '납품비리'],
#  ['국회', '선진화법', '위반자의', '고소고발을', '철회하지', '마세요'],
#  ['홍영표', '원내대표', '연임', '청원'],
#  ['나경원', '딸', '입학비리와', '자유당', '채용비리', '재수사', '바랍니다'],
#  ['살', '어린', '여자아이', '최모양과', '삼촌', '강모살씨', '총명의', '탈북자', '강제북송을', '막아주세요'],
#  ['일보', '인가취소', '청원합니다'],
#  ['파리', '한인', '교회', '송목사', '성폭행가정폭력', '처벌해주세요'],
#  ['항공', '시카고', '직항노선', '폐지에', '반대합니다'],
#  ['패스트트랙', '통과되자', '국회경위에게', '갑질하고', '화풀이한', '장제원', '의원의', '제명을', '요구합니다'],
#  ['이런', '갑질', '교장을', '그냥', '두어야', '하나요', '봐주기', '감사는', '절대', '안', '됩니다'],
#  ['조합원아파트',
#   '시공사',
#   '갑질과',
#   '불량조합원의',
#   '투기형태로',
#   '인해',
#   '선량한',
#   '조합원들이',
#   '피해를',
#   '보고있습니다'],
#  ['수백의', '가정이', '벼랑끝에', '있습니다', '도와주세요'],
#  ['문재인', '대통령의', '탄핵을', '청원합니다'],
#  ['평창동계올림픽조직위', '방송용컨테이너', '납품', '대금', '먹튀로', '업체', '도산', '위기'],
#  ['지역주택조합원은', '대한민국', '국민이', '아닙니까'],
#  ['타워크레인', '검사료', '차등적용', '요청'],
#  ['거제', '조선'],
#  ['공직선거법을', '개정하라'],
#  ['광주', '민주화', '운동의', '유공자', '명단을', '공개해주십시오'],
#  ['아예', '비례대표제를', '폐지해주세요'],
#  ['고소장을',
#   '접수하러',
#   '간',
#   '피해자에게',
#   '사이비종교를',
#   '강요하며',
#   '고소장을',
#   '반려한',
#   '형사',
#   '대한민국',
#   '경찰',
#   '맞습니까'],
#  ['동물보호법', '강화', '학대한', '사람', '엄벌', '처벌', '강화', '해주세요'],
#  ['어린이집',
#   '선생님',
#   '인당',
#   '돌볼',
#   '수',
#   '있는',
#   '아이',
#   '수',
#   '연령별',
#   '보육인원을',
#   '줄여',
#   '주세요'],
#  ['수원시복지과', '갑질', '횡포'],
#  ['공무원의', '근로자의', '날', '휴가를', '보장법정공휴일', '지정하여', '주십시오'],
#  ['원분양자', '대출하향조정으로', '인한', '진짜', '서민', '죽이는', '금강원정책', '철회하라'],
#  ['미성년자', '음주로인한', '업주의', '무거운', '처벌', '이래도', '됩니까'],
#  ['타운의입주지정일을연기해주세요'],
#  ['주거지역에', '보호감찰', '정신병원이말도', '아니됩니다국민', '여러분', '도와주세요'],
#  ['어린이집', '아동학대', '피해자', '엄마입니다', '더이상의', '솜방망이', '처벌은', '안됩니다도와주세요'],
#  ['학교', '옆', '정신질환자', '수용소', '설립을', '철회해주세요'],
#  ['파렴치한', '종', '총인', '일가를', '국민의', '힘으로', '엄벌에', '처해주세요'],
#  ['과일포장재', '팬캡', '비닐랩', '화학수지난좌', '사용금지'],
#  ['중국', '공안에', '잡혀', '북송', '위기에', '처한', '탈북자', '명을', '구해주세요'],
#  ['아이들이', '많은곳에', '베드의', '일반병원을', '가장한', '정신병원이', '들어왔습니다'],
#  ['아동그룹홈', '처우개선을', '위한', '국민청원'],
#  ['수도권시민의', '안전을', '위협하는', '수자원공사와', '산업의', '만행을', '막아주세요'],
#  ['공무원의', '갑질행정'],
#  ['방문학습지', '에서', '절', '고소했어요억울합니다'],
#  ['더불어민주당정의당', '정당', '해산과', '관련', '국회의원', '징계'],
#  ['부당해고와', '임금체불을', '당한', '노동자들을', '구해주십시오'],
#  ['한국자유당',
#   '출신의',
#   '전직',
#   '대통령과',
#   '전현직',
#   '국회의원을',
#   '반면교사',
#   '삼아',
#   '경상도',
#   '지역의',
#   '국회의원',
#   '지역구',
#   '수를',
#   '전국',
#   '평균치의',
#   '지역구',
#   '수로',
#   '조정해',
#   '주세요'],
#  ['경남학생인권조례', '제정을', '즉각', '중단해주십시오'],
#  ['그것이',
#   '알고싶다에서',
#   '다룬',
#   '파리교회',
#   '성폭행가정폭력',
#   '목사가',
#   '제대로',
#   '처벌받을',
#   '수',
#   '있도록',
#   '도와주세요'],
#  ['국회선진화법', '위반', '고발사건', '신속하게', '철저한', '수사진행을', '청원합니다'],
#  ['불법체류자추방'],
#  ['이해찬', '더불어민주당', '대표', '탄핵', '요청'],
#  ['근로자의', '날을', '노동절로', '바꿔주십시오'],
#  ['병역의무자에게도', '최저임금을', '보장해야', '합니다'],
#  ['도둑', '맞은', '억원을', '찾아', '주십시오'],
#  ['병원', '광역학치료', '연구종류안건'],
#  ['어느',
#   '장기기증',
#   '유가족의',
#   '바램',
#   '보건복지부는',
#   '장기기증',
#   '유가족을',
#   '위해',
#   '설립된',
#   '재를',
#   '없애지',
#   '말고',
#   '적극',
#   '지원',
#   '해주십시오'],
#  ['청와대', '국민', '청원에', '외국인들이', '의견', '등록', '못하게', '해', '주세요국가', '주권', '침해'],
#  ['청와대', '국민청원', '게시판', '폐쇄를', '청원', '합니다'],
#  ['국민혈세로', '살아난', '조선의', '성과급', '잔치'],
#  ['국민청원제도', '폐지'],
#  ['회사', '이래도되는건지', '궁금합니다'],
#  ['문무일', '검찰총장의', '파면을', '청원합니다'],
#  ['문무일', '검찰총장과', '김명수', '대법원장', '교체'],
#  ['남편', '시신', '실종', '그리고', '의문의', '죽음'],
#  ['증권의', '노인상대', '영업사기를', '처벌하여', '주십시요'],
#  ['어린이', '통학버스', '하차확인', '장치', '개조업체에', '대한', '강력한', '처벌을', '원합니다'],
#  ['강간과', '아동학대를', '일삼은', '대학생의', '퇴학과', '처벌을', '부탁드립니다'],
#  ['국민의',
#   '직접',
#   '투표',
#   '주권을',
#   '무시하는',
#   '연동형',
#   '비례대표제',
#   '패스트트랙',
#   '선거법',
#   '개정안을',
#   '강력',
#   '반대합니다'],
#  ['패스트트랙에', '반기를', '든', '문무일', '검찰총장을', '해임해주세요'],
#  ['저희', '아이', '미래를', '짓밟아', '버린', '학교', '고발합니다'],
#  ['인간이길', '포기한', '살', '딸을죽인', '친모랑', '계부', '사형집행해', '주세요'],
#  ['내년부터', '맞춤형', '폐지및', '시분까지', '보육', '의무화에', '따른', '건의'],
#  ['국회선진화법', '위반자들에', '대한', '처벌을', '강력히', '촉구합니다'],
#  ['도쿄', '올림픽', '한국선수단', '식자재', '공수', '요청및', '식당운영', '요청'],
#  ['주거용', '오피스텔등', '집합건물', '관리단문제'],
#  ['스승의', '날을', '교육의', '날로', '바꿀', '것을', '청원합니다'],
#  ['전기공사산업기사', '과정평가형제도', '도입을', '반대합니다'],
#  ['교통사고', '우리아이', '치료받을', '수', '있도록', '도와', '주세요'],
#  ['세상에', '이렇게', '억울한', '일도', '있습니까'],
#  ['년', '월', '일부터', '시행되는', '불법건축물로', '인한', '이행강제금', '서민들이', '울고', '있습니다'],
#  ['비례대표', '없는', '국회로', '갈아보자'],
#  ['자유한국당을', '명예훼손죄로', '고발주십시오'],
#  ['키코', '재조사', '요청합니다'],
#  ['문무일', '검찰총장의', '해임을', '청원합니다'],
#  ['사드를', '제발', '미국으로', '보내주십시오'],
#  ['정의당해산청원합니다'],
#  ['군산의', '눈물'],
#  ['장병', '휴가제도', '개선이동', '거리', '시간', '보상'],
#  ['수질환경산업기사', '과정평가형', '전환', '반대합니다', '환경관련', '과정평가', '전환', '반대'],
#  ['시민의', '실질적', '편의와', '안전을', '위한', '수도권', '광역버스', '대책', '시급'],
#  ['개인사업자를', '살려주세요'],
#  ['년정도',
#   '공부해야',
#   '취득할',
#   '수',
#   '있는',
#   '자격증을',
#   '이제',
#   '나라에서',
#   '그냥',
#   '나눠',
#   '준다는데',
#   '이게',
#   '옳은걸까요'],
#  ['제발', '제주도를', '지켜주세요', '제발', '부탁드립니다'],
#  ['자유로', '교통사고'],
#  ['주투어', '피해자', '만명'],
#  ['노총', '노총', '건설현장', '시위', '근절해', '주세요'],
#  ['자국민을', '말살하는', '외국인근로자정책', '축소철폐를', '해주세요'],
#  ['중견건설업체', '최고의', '갑질', '해고'],
#  ['총체적인', '갑질에', '정당한', '도로포장이', '안되고', '있습니다'],
#  ['치과의료사고', '예방하는', '이물질', '삼킴', '방지기구의', '건강보험', '적용과', '법제화의', '의', '필요성'],
#  ['대통령님', '제발제가', '흉악한', '경제사범이', '되지', '않도록', '저좀', '구해주세요ㅠㅠ'],
#  ['문무일', '검찰총장의', '파면을', '촉구합니다'],
#  ['김무성', '전', '의원을', '내란죄로', '다스려주십시오'],
#  ['목불인견', '국회의원', '퇴출', '청원', '첫', '번째', '자유한국당', '이은재'],
#  ['패스트트랙', '추인안', '철회', '요청'],
#  ['자한당', '김무성의원', '내란선동죄로', '처벌해주세요'],
#  ['국회에서',
#   '국회선진화법',
#   '위반',
#   '및',
#   '불법을',
#   '자행한',
#   '자유한국당',
#   '의원들을',
#   '법대로',
#   '엄정',
#   '처벌해주시기',
#   '바랍니다'],
#  ['영구해체', '자유한국당', '형사처벌과', '월급지급', '금지행정조치'],
#  ['충수암', '말기', '환자', '황씨를', '살려주세요중고차', '허위매물', '사기피해'],
#  ['보훈공단의', '경영평가', '조작사태에', '대한', '책임자를', '밝혀', '처벌해', '주십시오'],
#  ['인천', '동구', '아파트의', '안전', '대책을', '수립해', '주십시오'],
#  ['노인요양시설비리'],
#  ['곰탕집', '성추행', '사건', '공식입장문', '대법원의', '현명한', '판단을', '바란다'],
#  ['문재인', '대통령', '임기를', '늘려주세요'],
#  ['검찰', '구형', '년이', '무죄가'],
#  ['방탄소년단', '군', '면제', '청원', '대중문화예술계', '등', '병역특례법', '개정', '건의'],
#  ['부동산', '소유권', '이전에', '관한', '특별조치법', '신속', '처리', '요구'],
#  ['정부는',
#   '미세먼지',
#   '배출조작',
#   '기업을',
#   '전수조사하여',
#   '배출기준',
#   '위반기업에',
#   '대하여',
#   '법대로',
#   '엄격히',
#   '처벌하고',
#   '정부는',
#   '재발방지',
#   '대책을',
#   '즉각',
#   '마련하여',
#   '새행하라'],
#  ['거점국립대', '대학교', '산학협력단에서', '계약직명에', '대한', '부당한', '계약해지를', '진행하고', '있습니다'],
#  ['인구감소를', '이유로', '백년지대계', '교육투자를', '거부하는', '중투위제도'],
#  ['데이케어센터의', '차량도', '버스전용차선', '이용을', '허락해', '주세요'],
#  ['울진', '백암온천', '을', '오락문화', '관광특구로', '지정해주세요'],
#  ['악덕', '대주주를', '고발합니다'],
#  ['폐기물', '수거', '처리비를', '낮춰', '주세요'],
#  ['제한적', '사형제도', '부활영유아아동반인륜적', '살인해위'],
#  ['년삶에', '처음', '느낍니다', '한국에서', '태어난걸', '후회합니다'],
#  ['간병비', '의료비공제대상으로', '포함해주세요'],
#  ['전문대학에', '시행중인', '는', '즉각', '폐지되어야', '합니다'],
#  ['음주운전자에게', '영안실', '봉사', '처벌을', '내려주세요'],
#  ['온라인상의', '암표', '거래를', '제재해주세요'],
#  ['검찰이',
#   '윤',
#   '총경의',
#   '부정청탁금지법',
#   '혐의에',
#   '대해',
#   '명운을',
#   '걸고',
#   '수사해',
#   '주시길',
#   '강력히',
#   '촉구합니다'],
#  ['입양', '절차가', '즐거운', '나라가', '되게', '해주세요'],
#  ['어린이들이', '생존수영을', '배우는스포츠셴타와', '열병합발전소를', '지하지나는변경노선반대'],
#  ['여수시민의', '생명을', '지켜주세요'],
#  ['아파트', '층간소음', '저감제도', '운영실태의', '감사원', '감사결과에', '따른', '업체', '공개를', '요청합니다'],
#  ['정부지침사항',
#   '거부한',
#   '공공기관',
#   '고객센터',
#   '한국전력공사와',
#   '국민건강보험공단',
#   '고객센터',
#   '비정규직',
#   '근로자',
#   '정규직',
#   '전환요청'],
#  ['외국인', '건강보험', '지원을', '중단해주세요'],
#  ['서산', '아파트', '단지앞', '산폐장이', '말이', '되나요'],
#  ['개인의', '사유재산을', '빼앗는', '것이', '도시정비사업재건축인가요'],
#  ['해외원정성매매를', '권장하는', '만명', '회원의', '불건전사이트를', '단속해야합니디'],
#  ['명백히', '밝혀주세요', '에', '일', '하는', '모든', '여성들은', '빛쟁이', '입니다'],
#  ['이륜차', '보험료', '문제'],
#  ['소방공무원과', '경찰공무원의', '취업제한을', '완화해', '주십시요'],
#  ['학교내', '선생의', '학생', '폭력', '말이', '됩니까'],
#  ['기부금을', '기부', '받은', '용도로만', '사용해', '주세요'],
#  ['건설',
#   '갑질',
#   '행위에',
#   '공정거래위원회',
#   '및',
#   '산하',
#   '조정협의회',
#   '의',
#   '관대한',
#   '처리',
#   '바로',
#   '잡아',
#   '주세요'],
#  ['네트워크', '병의원들의', '인개소법', '위반을', '조사해주세요'],
#  ['백화점근무시간단축'],
#  ['현재', '법으로면', '자전거', '사고', '내면', '무조건', '도망가세요'],
#  ['내년', '총선에', '전자투표', '실시를', '청원합니다'],
#  ['차기', '검찰총장은', '임은정검사를', '기용해', '주십시요'],
#  ['낙태죄', '폐지', '반대', '청원'],
#  ['악덕', '대부업자의', '대변인', '대법원판사의', '해임', '청원'],
#  ['기름값'],
#  ['군무원', '시험', '공개를', '청원합니딘'],
#  ['왜', '웃돈을', '주고', '비싼', '택시를', '타야', '됩니까'],
#  ['최악의', '식량난에', '처한', '북한에', '식량을', '지원해', '주시기', '바랍니다'],
#  ['노인약자의', '생명을', '볼모로', '진행하는', '파업으로', '사망사고발생', '정부대책이', '필요합니다'],
#  ['북녘', '동포들에게', '따뜻한', '인도적', '지원을', '해주기를', '간절히', '청원합니다'],
#  ['주류제조사들의', '불법리베이트', '제공으로인한', '탈세조장', '처벌해주십시요'],
#  ['조현병을', '앓고', '있는딸을', '키우는', '엄마입니다', '조현병의', '국가관리', '시스템을', '청원합니다'],
#  ['피해', '지역민을', '두', '번', '울리는', '홍천', '양수발전소'],
#  ['기',
#   '신도시',
#   '정책은',
#   '시작부터',
#   '잘못되었다고',
#   '다들',
#   '말하고',
#   '있는데',
#   '왜',
#   '끝까지',
#   '밀어붙이십니까'],
#  ['홍문종', '자유한국당의원을', '탄핵해주세요'],
#  ['국회의원', '지문인식', '출퇴근부', '만들어', '주세요'],
#  ['법무부', '장관님', '국회', '농단', '관련자', '처벌을', '반드시', '올해', '안으로', '마무리', '해주세요'],
#  ['국회해산', '혹은', '봉사직전환을', '청원합니다'],
#  ['자한당', '황교안', '대표와', '나경원', '원내대표의', '민주화운동', '주년', '국가기념식', '불참을', '청원합니다'],
#  ['황교안이', '기념식에', '참석하지', '못하게', '해주십시오'],
#  ['고삐풀린', '검찰총장과', '추종검사들을', '항명죄로', '벌해주세요'],
#  ['촛불집회참가자', '폭행', '직무유기', '경찰', '모두', '처벌해주세요'],
#  ['공정거래법과', '사모펀드가', '국민의', '일자리를', '빼앗고', '있습니다'],
#  ['개성', '남북연락사무소', '폐쇄하라'],
#  ['한국에서', '추진하는', '모든', '대북지원과', '대북사업을', '전면중단시켜주십시오'],
#  ['자한당', '해산', '국민청원', '관철과', '김무성', '의원', '형사고발'],
#  ['청와대', '해산을', '청원합니다'],
#  ['광주테러를', '자행한', '민중당', '해산을', '청원합니다'],
#  ['자유한국당과', '대한애국당', '정당해산', '청원합니다'],
#  ['서울중앙지검', '호', '검사의', '편파수사를', '막아주세요'],
#  ['살', '여야의', '북송을', '막아주시고', '대한민국으로', '데려와', '주세요'],
#  ['장난까지마세요'],
#  ['기신도시', '고양지정', '일산신도시에', '사망선고', '대책을', '요구합니다'],
#  ['중앙보훈병원', '원장에', '병원', '원장', '임명을', '반대합니다'],
#  ['국가공공시설물', '시민개방', '청원학교체육관은', '학교장의', '개인소유물입니까'],
#  ['한국마사회에서', '시행하는', '경마를', '인터넷으로', '참여할수', '있도록', '해주십시요'],
#  ['헤르페스와', '인두유종바이러스', '치료제인', '알로페론', '임상실험과', '국내도입', '정부지원해주세요'],
#  ['공인인증서', '액티브엑스', '폐지', '인터넷', '보안강화는', '서비스', '제공', '업체가', '사용자는', '회원가입만'],
#  ['여경의날', '지정', '반대', '및', '역차별', '금지'],
#  ['시민단체들의', '보조금을', '중단해야', '합니다'],
#  ['동물구조',
#   '영웅의',
#   '추악한',
#   '두',
#   '얼굴에',
#   '대해',
#   '폭로하고',
#   '국민을',
#   '기만하는',
#   '행동에',
#   '대해',
#   '엄벌을',
#   '내려주시기',
#   '바랍니다'],
#  ['아이들의',
#   '안전과',
#   '건강을',
#   '위협하는',
#   '개발을',
#   '멈춰주세요',
#   '주택가',
#   '화물차',
#   '공영',
#   '차고지',
#   '개발',
#   '반대'],
#  ['백화점', '계열사', '의', '대기업', '갑질로', '길바닥에', '나', '앉게', '된', '대리점점주들을', '살려주세요'],
#  ['장애인이', '포장생산한', '기저귀와', '위생용품을', '구매하여', '주세요사활이', '걸려있습니다'],
#  ['사상초유의',
#   '사태',
#   '제주',
#   '제공항',
#   '용역보고서',
#   '폐기에도',
#   '아무런',
#   '언급도',
#   '없는',
#   '제주',
#   '국회의원',
#   '위성곤',
#   '오영훈',
#   '강창일',
#   '인방',
#   '자격을',
#   '박탈해주세요'],
#  ['같은', '차', '산업', '형평성에', '어긋난', '소득세법', '개정을', '요구합니다'],
#  ['서민', '죽이는', '금융상품은행'],
#  ['폐암신약', '의료급여혜택', '받게해주요'],
#  ['성수대교사고와', '같은', '교량붕괴사고를', '막아야합니다'],
#  ['밀양여중생집단성폭행', '사건', '처벌', '및', '재수사', '청원합니다'],
#  ['앞으로', '얼마나', '죽어야하는겁니까'],
#  ['고속도로', '바스전용차선', '승합차진입금지', '및', '전용차선', '연장확대'],
#  ['샌드위치패널의', '준불연성능을', '속이는', '행위', '강하게', '처벌해주십시오'],
#  ['서울', '고교', '축구부', '폐지', '청원'],
#  ['비리', '축구부', '감독의', '철저한', '진상조사와', '강력한', '처벌을', '요구합니다'],
#  ['과잉주택공급기신도시', '무분별한', '공급투입', '기', '검단신도시', '해결방책', '제시바랍니다'],
#  ['기신도시반대', '기신도시', '완성', '교통망', '구축후에', '합시다'],
#  ['기', '신도시', '위치', '선정', '기준과', '만호', '기준이', '무엇인가요'],
#  ['경기도', '의왕시', '내손동의', '중학교', '문제를', '해결해주십시요'],
#  ['힘없는', '일용직', '근로자들의', '권리를', '찾아주세요'],
#  ['구거복개', '도와주세요'],
#  ['세계문화유산인',
#   '서오릉',
#   '주변',
#   '기',
#   '신도시',
#   '지정을',
#   '즉각',
#   '철회하고',
#   '베드타운',
#   '운정신도시의',
#   '근본대책을',
#   '세워주세요'],
#  ['부회장', '대법원', '판결은', '진행중인', '검찰', '수사', '후에', '이뤄져야', '합니다'],
#  ['의', '갑질에', '자영업자만', '죽어나고', '있습니다', '살려주세요'],
#  ['사립유치원', '감사축소', '의혹이', '짙은', '경기도교육청', '감사관을', '교체하라'],
#  ['우리', '아이들이', '성희롱을', '일삼는', '교대', '출신의', '남선생들에게', '수업받지', '않도록', '해주세요'],
#  ['출시되고나서', '속도가', '너무느려짐'],
#  ['대북', '식량지원', '철회해주세요'],
#  ['대북', '쌀지원을', '하지말아주십시오'],
#  ['저희의', '이야기를', '들어주세요'],
#  ['부동산정책을', '등에업고', '전국적으로', '계약취소를', '강행하는', '시행사의', '횡포를', '막아주세요'],
#  ['부산', '부동산', '조정지역', '해제를', '청원합니다'],
#  ['고향교회를', '지켜주세요'],
#  ['사설', '렉카차를', '엄중히', '단속해주세요'],
#  ['가정폭력에서', '아이들을', '지켜주세요평택시', '청북면', '친모', '폭행사건'],
#  ['전자의', '노동자', '기만을', '고발합니다'],
#  ['장애인', '보장구', '지원', '관련', '내구연한', '기한및', '수리비', '지원을', '개정', '해주세요'],
#  ['아사자',
#   '생긴',
#   '북한',
#   '어린이에게',
#   '남측',
#   '남아도는',
#   '쌀',
#   '인도적',
#   '지원과',
#   '민간교류와',
#   '북',
#   '단기관광',
#   '허용해',
#   '주십시요'],
#  ['광주', '의붓딸', '살해', '사건', '친모는', '구속되어야', '합니다', '구속을', '청원합니다'],
#  ['국민들의',
#   '눈을',
#   '속이고',
#   '일몰을',
#   '연장한',
#   '교통에너지환경세법유류세',
#   '핵심',
#   '폐지를',
#   '간곡히',
#   '요청합니다'],
#  ['문재인대통령님', '학교폭력피해자들과', '가족들을', '도와주세요'],
#  ['급발진사고로', '고통받는', '사람들에게', '편', '이', '되어주세요'],
#  ['대출', '한도를', '하루아침에', '정책을', '펼치고', '소급', '전용을', '함으로써', '당황하고', '있습니다'],
#  ['일산서구', '주민들이', '교통에', '고통받고', '있습니다', '호선', '연장', '조속히', '추진하여', '주세요'],
#  ['첨단의료재생법'],
#  ['장기기증',
#   '후',
#   '시신은',
#   '유가족에게',
#   '인계하지말고',
#   '병원에서',
#   '장례까지',
#   '치를수',
#   '있도록',
#   '법제화',
#   '해주세요'],
#  ['월', '일', '외국인', '건강보험', '당연가입', '철회', '청원'],
#  ['경주마', '도살', '금지법', '촉구합니다'],
#  ['연금', '만원', '국립묘지', '안장', '막기', '위해', '공관병', '갑질', '박찬주를', '기소해주십시오'],
#  ['그룹', '회장', '황제보석을', '취소해주세요'],
#  ['북한',
#   '김정은',
#   '정권을',
#   '연장시켜',
#   '줄수',
#   '있는',
#   '북한',
#   '인도적차원의',
#   '쌀',
#   '지원을',
#   '중단하길',
#   '청원합니다'],
#  ['국회의원', '급여를', '최저시급으로', '바꿔주세요'],
#  ['춘천시와', '복지원에', '대한', '면밀한', '조사를', '희망합니다'],
#  ['교통사고', '피해자', '가족이', '받는', '엄청난', '고통을', '덜어줄', '제도를', '마련해', '주세요'],
#  ['세', '어머니가', '퇴원좀하게', '제발', '도와', '주십시요'],
#  ['대북', '식랑지원', '반대'],
#  ['기', '신도시', '지정', '재검토를', '요청합니다'],
#  ['코피아', '출신', '낙하산의', '벡스코', '경영을', '그만두게', '해주세요'],
#  ['특수교사의', '목소리를', '들어주십시오'],
#  ['세금폭탄으로', '대학의', '목을', '죄는', '지방세법', '개정을', '막아주십시오'],
#  ['공사서울도시주택의', '횡포를', '고발합니다'],
#  ['불법', '투기가', '만연해있는', '창릉', '기', '신도시', '지정', '철회를', '요청합니다'],
#  ['경기도의회',
#   '의원들의',
#   '이재명',
#   '경기도지사',
#   '선처',
#   '요구',
#   '탄원서',
#   '제출에',
#   '대해',
#   '강력히',
#   '항의합니다'],
#  ['기', '신도시', '관련', '전수조사', '원합니다'],
#  ['황교안과', '나경원의', '사전선거운동을', '선관위는', '조사하라'],
#  ['부산', '부두에서', '진행되는', '주피터프로젝트', '탄저균', '실험을', '즉각', '중지해주십시요'],
#  ['방송국', '해체'],
#  ['중증장애',
#   '등록을',
#   '예전기준으로',
#   '돌려주세요나',
#   '로',
#   '암',
#   '재발병소가',
#   '보이면',
#   '중증장애',
#   '추가연장등록이',
#   '가능하도록',
#   '해주세요'],
#  ['녹분유', '사건', '엄마입니다', '읽어주세요'],
#  ['대통령의', '대담은', '검증된', '실력을', '가진', '대담자와', '진행하도록', '하여', '주십시오'],
#  ['수신료를', '폐지해', '주세요'],
#  ['교습소', '학원', '설립', '조건을', '정비해주세요'],
#  ['는', '문재인', '정부', '년', '특집', '대담을', '본', '국민에게', '사과하라'],
#  ['관광버스', '차령을', '연장하여', '주십시요'],
#  ['청소년', '술', '담배', '구매', '이젠', '책임이', '뒤따라야합니다'],
#  ['기', '신도시', '현', '정부는', '기본', '개념을', '이해하고', '진행해', '주세요'],
#  ['마약에',
#   '대한',
#   '예방교육',
#   '단속',
#   '처벌을',
#   '강화해',
#   '주셔서',
#   '진정한',
#   '마약청정국가가',
#   '되게',
#   '해',
#   '주십시오'],
#  ['대기업', '효성과', '조합의', '횡포용산구역', '언제까지', '고통속에', '신음하고', '살아야', '하는', '걸까요'],
#  ['오토리스', '사기', '벌해주시고', '막아주세요', '대표', '벌해주세요'],
#  ['공공분양',
#   '분양가의',
#   '고공행진',
#   '이대로',
#   '놔두시렵니까',
#   '한국토지주택공사의',
#   '횡포를',
#   '엄중히',
#   '막아주십시오'],
#  ['기', '신도시', '예견된', '대참사'],
#  ['국민',
#   '생명',
#   '관련',
#   '직무',
#   '공무원',
#   '직무유기로',
#   '국민',
#   '사망',
#   '등',
#   '중대',
#   '피해',
#   '발생시',
#   '처벌',
#   '법안',
#   '마련',
#   '및',
#   '소방관',
#   '국가직',
#   '전환',
#   '반대'],
#  ['대구시', '소재', '내의', '부상사고', '어이없는', '사고', '처리에', '대해'],
#  ['신분당선', '서북부', '연장사업의', '조속한', '실행을', '요청합니다'],
#  ['한글', '삼재', '자', '체계', '정립', '청원'],
#  ['공매도', '적법성', '조사', '요청'],
#  ['수신료', '폐지', '청원과', '함께', '공영방송으로서', '적폐청산', '청원합니다'],
#  ['문무일', '검찰총장님과', '검찰을', '사랑하시는', '검사님들의', '공식적인', '답변을', '바랍니다'],
#  ['대',
#   '최악의',
#   '동식물국회',
#   '해산하고',
#   '조기총선하라',
#   '못살겠다',
#   '바꿔보자',
#   '이런',
#   '꼴',
#   '볼려고',
#   '국회의원',
#   '뽑았나',
#   '이럴려고',
#   '정치하나',
#   '대',
#   '종선',
#   '전',
#   '틀을',
#   '완전히',
#   '바꾸자'],
#  ['편파방송', '기자', '규탄한다'],
#  ['도경환', '말레이지아', '대사의', '갑질', '폭언은', '거짓입니다'],
#  ['자신의', '역할을', '망각한', '의', '수신료', '납부를', '거부합니다'],
#  ['수신료', '납부를', '전기세에서', '분리해', '주십시요'],
#  ['기신도시철회요청드려요'],
#  ['고령의', '참전유공자', '의료급여대상자', '지정', '청원합니다'],
#  ['고속도로사망사고줄이기'],
#  ['맞벌이', '부부의', '고민'],
#  ['년', '누구를', '위한', '의무화', '인가'],
#  ['귀농하였더니', '마을자치법으로', '정한', '입주금으로', '삼백만원을', '내라고', '하니'],
#  ['불', '합리', '관련', '퍼질', '수', '있도록', '확인', '요청', '드립니다'],
#  ['고객을', '기만하는', '를', '고발합니다'],
#  ['일반체당금신청', '기준적용', '및', '체불사업주', '강력처벌'],
#  ['단통법', '이대로는', '안됩니다'],
#  ['저는', '암환자이며', '큰아들은', '백혈병치료중이며', '둘째아들은', '심장병', '수술을', '하였습니다'],
#  ['단통법폐지및엄격한시행부탁'],
#  ['굶주리는', '북한', '동포에게', '인도적', '지원을', '하루빨리', '시행해주세요'],
#  ['자녀', '보이스', '피싱', '너무', '억울', '합니다'],
#  ['경의중앙선', '평일', '자전거', '휴대', '승차', '허용해주세요'],
#  ['시내버스', '비리척결'],
#  ['여론조사', '시스템을', '개선하라'],
#  ['장애인', '출입금지', '라고', '합니다'],
#  ['반려동물',
#   '사육산업의',
#   '현실적인',
#   '양성화',
#   '및',
#   '탄력적이고',
#   '융통성',
#   '있는',
#   '법적용과',
#   '법개정을',
#   '청원합니다'],
#  ['정부에서', '계획한', '기', '신도시', '사업', '완료후', '기', '신도시', '사업', '진행해주세요'],
#  ['경의중앙선경춘선의', '자전거', '휴대', '승차를', '하용해주세요'],
#  ['사법농단', '연루', '판사', '명을', '재판업무에서', '배제시켜', '주세요'],
#  ['매출', '조작에', '의한', '권리금', '편취가', '사기인가', '아닌가', '국민', '여러분께', '묻습니다'],
#  ['스몸비', '현상을', '해결할', '수', '있는', '정책을', '만들', '것을', '청원합니다'],
#  ['기신도시', '철회요청합니다'],
#  ['급', '공무원도', '꼭', '과정평가형', '도입해주시길', '바랍니다'],
#  ['가상화폐', '거래소', '의', '대한', '조사를', '요청합니다'],
#  ['육아',
#   '휴직자',
#   '왕따',
#   '및',
#   '인사차별로',
#   '자살하게',
#   '한',
#   '카드',
#   '조사',
#   '및',
#   '관련자',
#   '처벌',
#   '육아',
#   '휴직자',
#   '차별',
#   '방지',
#   '법률',
#   '제정을',
#   '청원합니다'],
#  ['사회', '혼란을', '야기시키는', '언론을', '개혁해', '주십시오'],
#  ['를', '폐지하거나', '정상화시켜주세요'],
#  ['노인들만', '노리는', '건강식품', '강매하는', '조합조합을', '파헤쳐주세요'],
#  ['부르키나파소에서',
#   '한국인',
#   '포함',
#   '인질명',
#   '구출하다가',
#   '전사한',
#   '프랑스',
#   '군인분의',
#   '대한민국의',
#   '무공',
#   '훈장',
#   '추서를',
#   '건의',
#   '드립니다'],
#  ['그루밍',
#   '성범죄',
#   '아직',
#   '끝나지',
#   '않았습니다',
#   '제의',
#   '인천교회',
#   '사태를',
#   '막기',
#   '위한',
#   '강력처벌을',
#   '촉구합니다'],
#  ['건설주영세한', '지역업체를', '상대로', '한', '두', '얼굴'],
#  ['연기금의', '책임감', '있는', '주식운용', '및', '이를위해', '대대적인', '감사를', '요청합니다'],
#  ['광주광역시', '구역', '재개발의', '현실을', '알립니다'],
#  ['면역성혈소판감소증', '치료신약에', '대한', '보험급여기준', '완화를', '청원합니다'],
#  ['해결되지', '않은', '일본군', '위안부', '문제'],
#  ['유튜브', '방송을', '패쇄시켜', '주십시요'],
#  ['가짜뉴스', '유튜버', '구속수사', '청원합니다'],
#  ['불공정과', '비리가', '의심되는', '인간문화재', '지정을', '고발합니다'],
#  ['일본', '야동배우의', '한국', '광고', '금지', '청원합니다'],
#  ['나경원의',
#   '문달이라는',
#   '극단의',
#   '성차별적',
#   '표현을',
#   '사용한',
#   '대국민',
#   '모욕행위를',
#   '고발하며',
#   '강력한',
#   '처벌을',
#   '청원합니다'],
#  ['여성혐오를', '일삼은', '나경원을', '국회에서', '재명하라'],
#  ['불특정', '다수의', '국민을', '문달이라고', '지칭한', '나경원', '원내대표의', '정계은퇴를', '요구합니다'],
#  ['미세먼지', '저감시스템', '보고서'],
#  ['국민을', '라', '칭한', '나경원', '자유한국당', '원내대표의', '의원직', '사퇴를', '요구합니다'],
#  ['나경원', '자유한국당', '원내대표의', '엄격처벌부탁합니다'],
#  ['나경원', '의원은', '자진', '사퇴하라'],
#  ['나경원', '원내대표의', '망언을', '규탄합니다'],
#  ['정치권은', '혐오', '비하발언을', '멈춰주십시오'],
#  ['문재인대통령지지자들에게', '달이라고발언한', '나경원원내대표', '사퇴청원'],
#  ['자유한국당',
#   '나경원',
#   '국회의원이',
#   '국민을',
#   '비하하거나',
#   '적어도',
#   '에',
#   '빗대는',
#   '일은',
#   '없게',
#   '해주세요'],
#  ['김', '사장의', '해임을', '요구합니다'],
#  ['갑질과', '횡포에', '중소기업이', '죽어갑니다', '국민', '여러분께서', '적폐', '청산에', '앞장서', '주십시오'],
#  ['프렌차이즈', '미용사들의', '노예', '사슬을', '끊어주세요'],
#  ['한국인은', '건들어도', '탈이', '없다', '안녕하세요', '옵서버', '이입니다'],
#  ['여론을', '왜곡하는', '여론조사', '기관', '처벌을', '청원합니다'],
#  ['기', '신도시', '즉각', '철회바랍니다'],
#  ['국세청을', '고발합니다'],
#  ['테이블', '동석만으로', '술도', '안먹었는데', '주류단속이', '된다말이안됩니다'],
#  ['민원업무를', '하는', '공무원들에게', '명찰착용', '의무화를', '청원합니다'],
#  ['낙태법은',
#   '헌법',
#   '불합치',
#   '판결인데도',
#   '벌금과',
#   '징역년형',
#   '받을',
#   '수',
#   '있습니다',
#   '헌법불합치',
#   '개정시한까지',
#   '국민이',
#   '처벌',
#   '받지',
#   '않도록',
#   '보호해주세요',
#   '개정시한',
#   '지나면',
#   '제발',
#   '위헌판결로',
#   '해주세요'],
#  ['쪼개기식', '편법개발', '건축', '허가만', '내주고', '피해방지', '대책없는', '용인시'],
#  ['대기업등', '반사회적', '불법광고를', '고발합니다'],
#  ['대형유통휴무'],
#  ['사회의', '일베', '및', '관련', '사이트', '폐지를', '요청합니다'],
#  ['에', '대해', '거짓보도한', '를', '처벌해주세요'],
#  ['기신도시', '명명백백히', '조사해주세요'],
#  ['북한주민들을', '위한', '식량과', '의료지원에', '동참해주십시요'],
#  ['문재인', '대통령님', '남양주시', '경춘선', '빨리', '해결해주세요'],
#  ['대한민국', '국민의', '반백년', '극한직업'],
#  ['동물학대', '및', '보호조치'],
#  ['청와대', '기자실', '폐쇄와', '청와대', '출입기자단', '제도를', '없애주세요'],
#  ['이승만', '박정희의', '묘를', '현충원에서', '파내야합니다', '역사를', '바로잡아야', '합니다'],
#  ['성범죄', '무고죄', '강화', '및', '진정한', '성평등을', '요구합니다'],
#  ['다단계제품', '인터넷재판매', '금지법'],
#  ['성범죄사건', '관련', '모든', '차가해를', '막아주세요'],
#  ['조폭두목으로', '부터', '저희', '주민들을', '구해', '주십시요'],
#  ['대통령님', '방문간호사들의', '희생을', '짓밟지', '말아주세요'],
#  ['자동차판매대리점', '노조탄압', '및기획폐업', '수사촉구'],
#  ['범정부차원의', '축산농가', '악취저감', '대책', '수립을', '촉구합니다'],
#  ['감정노동자들에', '대한', '법안을', '강화', '시켜주시길', '바랍니다'],
#  ['대학생까지', '학생', '교통비할인의', '범위를', '넓혀주세요'],
#  ['지금이', '통일', '식량을', '준비할', '때이다'],
#  ['환노위', '의원님들', '폐기물관리법', '통과해주세요'],
#  ['발암먼지도', '모자라서', '해상원전까지', '대한민국은', '과연', '안전합니까'],
#  ['유기동물', '법을', '더', '강화하고', '유기동물시설을', '더', '만들어주세요'],
#  ['불법적', '개농장', '철거'],
#  ['난임', '부부를', '위해', '난자기증공여', '제도를', '합법화', '해주세요'],
#  ['싼값에', '콘서트', '티켓', '미리', '구매환불', '불가', '약관', '논란'],
#  ['의료실비', '갱신', '폭탄', '문제있습니다'],
#  ['불법',
#   '향응',
#   '소비',
#   '범죄',
#   '가담',
#   '고객',
#   '수사',
#   '착수',
#   '및',
#   '유착',
#   '공권력',
#   '특검',
#   '청문회를',
#   '청원합니다'],
#  ['고속화도로', '회사갑질'],
#  ['고등학교', '학교폭력피해자아빠입니다', '저희아들', '억울함을청원합니다'],
#  ['산주를',
#   '배제하고',
#   '시행하는',
#   '위탁대행사업의',
#   '보완개선을',
#   '요구하며',
#   '산주가',
#   '직접',
#   '참여하는',
#   '대리경영',
#   '사업시행을',
#   '촉구한다'],
#  ['지역주택', '법의', '병패'],
#  ['영장기각', '구속해야합니다'],
#  ['구속영장을', '기각한', '부장판사', '해임', '건의'],
#  ['농식품부',
#   '장관이',
#   '환경부에',
#   '요청한',
#   '음식물잔반',
#   '양돈농가',
#   '급여금지',
#   '개정안에',
#   '개농장도',
#   '포함해주세요'],
#  ['경기도지사는',
#   '청년배당과',
#   '지역화폐',
#   '홍보비에',
#   '지출한',
#   '세금',
#   '내역과',
#   '버스',
#   '요금',
#   '인상',
#   '이유에',
#   '대해',
#   '공개하라'],
#  ['가락시장', '하역노조', '직선제를', '청원합니다'],
#  ['신문사의', '적폐'],
#  ['조선일보', '폐간', '및', '조선', '설립허가취소', '청원'],
#  ['대만', '수교'],
#  ['지금', '일본', '그래픽', '디자이너가', '위안부를', '모욕하고', '있습니다대한민국', '사람이라면', '동의해주세요'],
#  ['이종명의원', '군', '사고', '재조사및', '수사를', '요청합니다'],
#  ['고등학교', '페미니즘', '독재로', '동아리가', '해체되었습니다'],
#  ['층간소음을', '더', '이상', '방치해', '두지', '말아주세요'],
#  ['스포츠토토', '매출총량제를', '폐지해주세요'],
#  ['신상이', '공개된', '중대한', '성범죄자의', '위치를', '알', '수', '있게', '해주세요'],
#  ['한여자의', '남편', '두', '딸의', '아버지가', '바닷속에서', '추위에', '떨고', '계십니다'],
#  ['불쌍한', '우리', '딸의', '억울함이', '풀릴수', '있도록', '재수사가', '진행될수', '있도록', '도와주세요'],
#  ['선분양제도의', '피해를', '막아주세요'],
#  ['악덕기업', '주식회사', '일가를', '처벌해', '주십시오'],
#  ['친', '어머님을', '찾기엔', '어려운', '법'],
#  ['유흥종사자노래방', '도우미', '등', '식품위생법', '개정', '또는', '폐지'],
#  ['공매도', '개선', '청원'],
#  ['알바니아에', '한국', '대사관이나', '영사관을', '세워주세요'],
#  ['하루하루',
#   '목숨걸고',
#   '살아가는',
#   '대한민국',
#   '치킨집',
#   '업주입니다',
#   '익명을',
#   '무기삼은',
#   '사이버테러를',
#   '강력히',
#   '처벌해주세요'],
#  ['한국거래소',
#   '코스닥',
#   '시장본부의',
#   '년',
#   '월일',
#   '그룹의',
#   '상장',
#   '폐지',
#   '결정은',
#   '규정과원칙을',
#   '위배한',
#   '대단히',
#   '잘못된',
#   '심의',
#   '결과',
#   '입니다',
#   '반드시',
#   '바로',
#   '잡아주십시오'],
#  ['내항선',
#   '외국인',
#   '해기사',
#   '고용',
#   '제한',
#   '및',
#   '한국',
#   '해기사',
#   '고용으로',
#   '일자리',
#   '보존',
#   '및',
#   '인력',
#   '확보를',
#   '해주십시오'],
#  ['대통령님께', '고합니다'],
#  ['특검을', '요구합니다'],
#  ['증언자', '윤', '에', '대해', '눈물로', '청원합니다'],
#  ['국회의원', '정원을', '석으로', '줄여주세요'],
#  ['는', '불기소', '최초', '제보자', '씨는', '기소', '이게', '나라입니까'],
#  ['장자연', '씨', '사건', '성폭력', '의혹과', '진실을', '규명하기', '위한', '재수사를', '촉구합니다'],
#  ['창릉신도시', '지정관련', '국정감사및', '특검해야', '합니다'],
#  ['환경부', '공무원들정수기', '품질기준을', '위반한', '불법제품을업체', '뒤봐주기로', '수백만대', '시중에', '유통'],
#  ['쉼터에서', '보호해주고', '있는', '저희', '아이들을', '돌려보내주세요'],
#  ['외국인투자자', '합법화에', '발목을', '잡다'],
#  ['렌트카', '유사택시', '금지', '해', '주세요'],
#  ['국회의원', '무노동', '무임금', '실시'],
#  ['대학교병원', '중환자실에서의', '실수로', '고관절골절사고'],
#  ['집배원의', '억울한', '죽음'],
#  ['광주학살',
#   '원흉',
#   '전두환',
#   '일당을',
#   '국제형법상',
#   '반인도범죄로',
#   '소추하기',
#   '위한',
#   '국제특별형사재판소',
#   '설치',
#   '추진'],
#  ['대형', '맘카페의', '횡포', '강퇴', '글삭', '등', '을', '고발합니다'],
#  ['가상화폐', '거래소', '먹튀', '사건을', '공정하게', '수사해', '줄', '것을', '요청합니다'],
#  ['세종대왕', '탄신일월일을', '국가기념일로', '지정해', '주셨으면', '합니다'],
#  ['음주운전', '사망사고', '불구속', '억울한니다'],
#  ['통신비', '천만원', '대리점', '부조리', '방조하는'],
#  ['아직도', '여자', '육아휴직', '거부', '많습니다'],
#  ['가정폭력과', '암투병으로', '힘든', '시간을', '보내고', '세상을', '떠난', '우리언니', '이혼시켜주세요'],
#  ['급', '친일파', '박시춘', '생가의', '철거를', '청원합니다'],
#  ['사건의', '철저한', '수사를', '청원합니다'],
#  ['학원차량', '안전벨트', '의무화', '단속'],
#  ['중증의', '특수교육대상학생에게', '기저귀를', '지원해', '주십시오'],
#  ['의', '퇴직자들에', '대한', '잘못된', '처신에', '대하여', '호소합니다'],
#  ['직계가족활동보조사활동'],
#  ['악덕', '기업', '의', '감자를', '막아주세요'],
#  ['은평구의', '민주주의를', '살려주세요', '문재인', '대통령님과', '여당', '최고위원님들께'],
#  ['사법개혁', '방해하는', '문무일', '김명수를', '파면하라'],
#  ['축사건축으로', '인한', '주민피해', '해결'],
#  ['비리조사'],
#  ['광주', '학살', '주동자와', '가담자를', '다시', '수사', '하여', '처벌', '하도록', '해주세요'],
#  ['산림', '훼손을', '막고', '태양광', '활성화를', '위한', '정책', '개선', '제안'],
#  ['이재명', '유죄판결', '청원'],
#  ['국민', '여러분께', '억울함을', '호소합니다'],
#  ['독립', '유공자에게', '최대의', '예우', '및', '실질적인', '지원을', '다하자'],
#  ['광양', '초등학교', '옆', '행복주택', '건설을', '반대합니다'],
#  ['경제를', '망치는', '공매도를', '규제하고', '주식시장을', '살리자'],
#  ['일방적인', '권리', '주장으로', '정부의', '청년농업인', '육성과', '정착을', '저해하는', '자들이', '있습니다'],
#  ['주', '소액주주들의', '억울한', '피해를', '막아주세요'],
#  ['법까지', '바꿔가며', '무소불위의', '행정폭력을', '일삼는', '박원순', '시장을', '막아', '주세요'],
#  ['청와대', '국민', '청원을', '외국인들이', '쓸', '수', '없게', '막아주세요'],
#  ['한국산업인력공단', '채용', '시험', '재시험', '시행', '요청합니다', '도와주세요'],
#  ['좌초되어침몰하는', '바지선구해주세요'],
#  ['초등학교', '사서교사', '의무화'],
#  ['수술등으로',
#   '무의식',
#   '상태에서',
#   '이루어지는',
#   '의료행위',
#   '시',
#   '를',
#   '찍어',
#   '의사나',
#   '환자를',
#   '보호',
#   '합시다'],
#  ['저출산대책으로', '자동차세', '감면해주세요'],
#  ['시간', '근로', '준수를', '위한', '국회', '및', '감사원', '등', '요구자료', '요청', '방식', '개선'],
#  ['전환사채', '발행시', '전환율', '까지만', '허용해주세요'],
#  ['대통령님', '우리', '시각장애인들이', '일상을', '살아갈', '권리를', '보장해주실', '것을', '청원합니다'],
#  ['정신과진료비', '보험청구건'],
#  ['자전거를', '가지고', '열차를', '탑승', '할수', '있도록', '해', '주십시오'],
#  ['리그오브레전드', '선수들의', '입국', '금지를', '청원합니다'],
#  ['관공서에', '게양된', '새마을기를', '내려주십시요'],
#  ['유네스코', '세계유산기록', '유산', '위안부', '등재', '촉구', '서명운동', '동참에', '청원드립니다'],
#  ['고양시', '기신도시의', '건설의', '문제점'],
#  ['정신질환자에게도', '치료받을', '자유와', '권리를', '그리고', '그들의', '인권을', '지켜주세요'],
#  ['아울렛내',
#   '키즈카페',
#   '바로',
#   '옆',
#   '배',
#   '대형',
#   '키즈카페를',
#   '입점',
#   '시킨',
#   '대기업',
#   '갑질을',
#   '신고합니다'],
#  ['문화재청의', '불공정', '무형문화재', '보유자', '인정절차를', '당장', '멈춰주세요'],
#  ['건물주가', '임대기간종료후', '보증금을', '안돌려줍니다'],
#  ['헤르페스', '완치약', '개발보급해주세요'],
#  ['년',
#   '박환자의',
#   '인권위',
#   '진정으로',
#   '조사했으나',
#   '기각됐던',
#   '환자부림과',
#   '불법의료행위',
#   '갑질을',
#   '지속했던',
#   '음성현대병원을',
#   '조사해주세요'],
#  ['목사를', '신으로', '믿도록', '세뇌시키는', '교회', '유치원', '운영을', '중단시켜주십시오'],
#  ['정신적', '고통에', '대한', '안락사', '혹은', '조력자살을', '허용해주십시오'],
#  ['웹툰', '의', '연재를', '중지시켜주세요'],
#  ['년의',
#   '전통의',
#   '건강식품사',
#   '갑질',
#   '도급사',
#   '인사와',
#   '운영',
#   '개입으로',
#   '인한',
#   '도급직원',
#   '해고',
#   '위장도급을',
#   '고발합니다'],
#  ['공기업의', '갑질과', '월권을', '바로잡아', '주세요'],
#  ['한강신도시와',
#   '검단신도시를',
#   '위한',
#   '호선연장',
#   '노선',
#   '안고촌읍',
#   '신곡지구풍무동',
#   '유현사거리검단신도시검단산단골드밸리한강신도시',
#   '구래동김포북부권의',
#   '조속한',
#   '확정및추진을',
#   '희망합니다'],
#  ['고등학교의', '문제점을', '바로', '잡아주세요'],
#  ['이재명지사',
#   '사건',
#   '담당검사들의',
#   '공정성을',
#   '잃은',
#   '검찰의',
#   '권력행사를',
#   '규탄하며',
#   '사건',
#   '담당검사들의',
#   '탄핵과',
#   '징계를',
#   '청원합니다'],
#  ['기', '신도시', '반대', '집회', '행진', '사안의', '중요성'],
#  ['세월호', '참사', '학생들과', '미래후손들이', '기억하고', '잊지말아야합니다'],
#  ['국회의원들이', '누리는', '특혜와', '특권을', '없앱시다'],
#  ['한',
#   '치',
#   '앞도',
#   '살피지',
#   '않고',
#   '안일한',
#   '행정으로',
#   '반쪽짜리',
#   '집으로',
#   '남겨지게',
#   '될',
#   '대가',
#   '함께',
#   '살기',
#   '위한',
#   '저희',
#   '집을',
#   '지켜주세요'],
#  ['도', '국립', '교대', '교육대학', '부설초등학교', '학교폭력아동학대학폭규정위반사문서위조'],
#  ['진상조사규명위원회', '출범과', '민주화', '운동', '정신의', '헌법', '전문', '명기를', '청원합니다'],
#  ['오산', '정신병원을', '국가차원에서', '보호해', '주세요'],
#  ['이천', '강아지', '성폭행', '사건의', '범인에게', '악형을', '내려주세요'],
#  ['재개발재건축시', '선량한', '피해자가', '생기지', '않도록', '도와주십시오'],
#  ['한국전력의', '갑질에', '의한', '소프트웨어', '산업', '생태계파괴에', '대한', '책임자를', '처벌해', '주세요'],
#  ['승객을', '태우는', '영업용', '택시에', '속도제한장치를', '의무화', '해주세요'],
#  ['김포', '호선한강선', '기노선', '연장안', '실행', '청원드립니다'],
#  ['공동주택', '아파트', '소송의', '불합리성을', '개선하여', '주세요'],
#  ['여경', '비율', '축소', '및', '경찰', '임용시험', '체력검정', '기준강화'],
#  ['여경이', '아닌', '경찰을', '뽑아주세요', '여경', '할당제', '폐지'],
#  ['공영방송에서', '가짜뉴스로', '국민을', '기만하는', '사람들을', '처벌해', '주세요'],
#  ['대림동',
#   '경찰',
#   '폭행사건의',
#   '논란에',
#   '대해',
#   '공영방송에서',
#   '시행한',
#   '언론조작',
#   '진상규명을',
#   '요구합니다'],
#  ['여경', '선발', '비율을', '대폭', '축소시켜주세요'],
#  ['대한민국', '경제', '활성화를', '통한', '고용창출', '및', '지속', '가능한', '번영', '토대', '구축'],
#  ['한국산업인력공단큐넷의', '불공정한', '시험원서', '접수'],
#  ['이천에서',
#   '벌어진',
#   '동물수간사건에',
#   '대한',
#   '강력한',
#   '처벌과',
#   '동물학대에',
#   '대한',
#   '범국가적인',
#   '대책마련을',
#   '촉구합니다'],
#  ['제', '아내는', '입니까', '성추행범이', '무죄가', '되는', '세상'],
#  ['박근혜', '대통령님의', '석방을', '청원합니다'],
#  ['미용업계의', '부당한임금', '대책마련과', '처벌요구합니다'],
#  ['사리사욕을',
#   '위한',
#   '허위사실',
#   '청원글을',
#   '공정하게',
#   '경찰수사해주시고',
#   '이러한',
#   '일이',
#   '발생되지',
#   '않도록',
#   '청원게시판의',
#   '개선이',
#   '시급합니다'],
#  ['공수처',
#   '설치',
#   '신설',
#   '법안',
#   '대상',
#   '확대',
#   '발의안',
#   '권순일',
#   '불법',
#   '대법관',
#   '탄핵',
#   '소추안',
#   '사법',
#   '농단',
#   '피해의',
#   '구제에',
#   '관한',
#   '특별법',
#   '대상',
#   '확대',
#   '발의안등',
#   '긴급',
#   '국회',
#   '통과',
#   '요청',
#   '신규',
#   '청원서'],
#  ['국가가', '강제로', '파산시킨', '저축은행', '피해자를', '두번'],
#  ['직업군인과', '경찰', '소방공무원', '체력검정', '남녀', '동일기준검정', '제도개선요구합니다'],
#  ['인천공항', '고속도로', '통행료', '인하를', '추진해', '주세요'],
#  ['재능기부', '점수', '제도', '재능기부자의', '강의강연', '플랫폼'],
#  ['끊이지',
#   '않는',
#   '잔혹한',
#   '동물',
#   '학대를',
#   '막기',
#   '위해',
#   '동물보호법',
#   '및',
#   '학대범에',
#   '대한',
#   '처벌을',
#   '강화해주십시오'],
#  ['법인택시', '부가가치세경감분을', '전수조사하여', '환수하여주십시오'],
#  ['폐기처분할', '불량제품', '판매의혹'],
#  ['대한민국', '국민을', '살려주세요'],
#  ['난민법', '개정', '반드시', '해야합니다'],
#  ['박정희',
#   '대통령',
#   '각하를',
#   '사해한',
#   '김재규를',
#   '장군으로',
#   '호칭을',
#   '부른',
#   '장세용',
#   '구미시장',
#   '퇴진을',
#   '청원합니다'],
#  ['광주민주화',
#   '운동시의',
#   '포상자',
#   '명단과',
#   '포상사유를',
#   '공개해주십시오',
#   '명단은',
#   '이름없이',
#   '계급',
#   '또는',
#   '직위와',
#   '직책을',
#   '밝히는',
#   '것으로',
#   '충분합니다'],
#  ['박상기',
#   '법무부장관',
#   '진영',
#   '행정안전부장관께선',
#   '대통령의',
#   '지시이행에',
#   '최선을',
#   '다해주세요',
#   '장자연김학의버닝썬'],
#  ['장자연', '리스트', '재수사', '청원경찰', '검찰', '대통령', '나라는', '왜존재하나요'],
#  ['임산부석', '임산부', '폭행사건에', '대해', '무관심으로', '일관하는', '서울교통공사', '엄벌해주십시오'],
#  ['학교', '교회', '폭력', '사건의', '정당한', '처벌을', '요구합니다'],
#  ['저는', '살배기아들잃은', '아빠입니다'],
#  ['화물차불법증차', '피해', '구제를', '청원합니다'],
#  ['대', '육성', '산업인', '바이오헬스', '산업', '육성을', '위한', '기업', '투자', '환경을', '바로잡아주세요'],
#  ['영세자영업자와의', '상생에', '어긋나는', '대기업', '주', '의', '우월적', '갑질을', '막아주세요'],
#  ['아웃도어', '정대표의', '화려한', '성공뒤의', '특급갑질을', '고발합니다'],
#  ['보이지않는', '학교폭력으로', '조카가', '자살까지', '하려고', '하고', '있습니다'],
#  ['대구시', '팔공산', '관광활성화', '왜', '꼭', '구름다리여야', '하는가'],
#  ['하룻밤',
#   '새',
#   '사라진',
#   '수술실',
#   '설치법',
#   '다시',
#   '살릴',
#   '수',
#   '있을까요',
#   '정부는',
#   '계속',
#   '뒷짐만',
#   '지실',
#   '겁니까'],
#  ['우리', '아이들을', '상대로', '돈놀이를', '한', '의', '철저한', '조사', '청원', '합니다'],
#  ['저는', '지인아들사망사건의', '살애기아빠입니다'],
#  ['대한민국의', '아이들을', '지켜주세요'],
#  ...]

# %%
#포스태깅된 컨텐츠를 100차원의 벡터로 바꿔라. 
#주변 단어(window)는 앞뒤로 두개까지 보되, 
#코퍼스 내 출현 빈도가 2번 미만인 단어는 분석에서 제외해라. 
#CPU는 쿼드코어를 쓰고 100번 반복 학습해라. 
#분석방법론은 CBOW와 Skip-Gram 중 후자를 선택해라.
from gensim.models import Word2Vec
embedding_model_20 = Word2Vec(dic, size=20, window = 2, min_count=2, workers=4, iter=100, sg=1)

# %%
embedding_model_20.wv.vocab
# Out:
# {'국민건강보험공단': <gensim.models.keyedvectors.Vocab at 0x1c452cab048>,
#  '고객센터': <gensim.models.keyedvectors.Vocab at 0x1c454685ba8>,
#  '비정규직': <gensim.models.keyedvectors.Vocab at 0x1c454685780>,
#  '근로자': <gensim.models.keyedvectors.Vocab at 0x1c454685c88>,
#  '정규직': <gensim.models.keyedvectors.Vocab at 0x1c454685be0>,
#  '전환요청': <gensim.models.keyedvectors.Vocab at 0x1c454685828>,
#  '고발합니다': <gensim.models.keyedvectors.Vocab at 0x1c454685a20>,
#  '해주십시오': <gensim.models.keyedvectors.Vocab at 0x1c454685978>,
#  '부산시': <gensim.models.keyedvectors.Vocab at 0x1c4546857b8>,
#  '시의원': <gensim.models.keyedvectors.Vocab at 0x1c454685a58>,
#  '년': <gensim.models.keyedvectors.Vocab at 0x1c454361710>,
#  '계산하여': <gensim.models.keyedvectors.Vocab at 0x1c454361e10>,
#  '수당': <gensim.models.keyedvectors.Vocab at 0x1c4543616a0>,
#  '난임': <gensim.models.keyedvectors.Vocab at 0x1c454361d68>,
#  '당장': <gensim.models.keyedvectors.Vocab at 0x1c454361cc0>,
#  '합니다': <gensim.models.keyedvectors.Vocab at 0x1c454361898>,
#  '폭행': <gensim.models.keyedvectors.Vocab at 0x1c454361a20>,
#  '강력': <gensim.models.keyedvectors.Vocab at 0x1c452eebc50>,
#  '처벌': <gensim.models.keyedvectors.Vocab at 0x1c452eeb128>,
#  '및': <gensim.models.keyedvectors.Vocab at 0x1c452eeb208>,
#  '재발방지방안': <gensim.models.keyedvectors.Vocab at 0x1c45680c048>,
#  '수립을': <gensim.models.keyedvectors.Vocab at 0x1c45680c080>,
#  '폭행을': <gensim.models.keyedvectors.Vocab at 0x1c45680c0b8>,
#  '당했습니다': <gensim.models.keyedvectors.Vocab at 0x1c45680c0f0>,
#  '삶을': <gensim.models.keyedvectors.Vocab at 0x1c45680c128>,
#  '자동차에': <gensim.models.keyedvectors.Vocab at 0x1c45680c160>,
#  '강아지를': <gensim.models.keyedvectors.Vocab at 0x1c45680c198>,
#  '저는': <gensim.models.keyedvectors.Vocab at 0x1c45680c1d0>,
#  '의료사고로': <gensim.models.keyedvectors.Vocab at 0x1c45680c208>,
#  '화재': <gensim.models.keyedvectors.Vocab at 0x1c45680c240>,
#  '되고': <gensim.models.keyedvectors.Vocab at 0x1c45680c278>,
#  '피해자도': <gensim.models.keyedvectors.Vocab at 0x1c45680c2b0>,
#  '읽어주세요': <gensim.models.keyedvectors.Vocab at 0x1c45680c2e8>,
#  '경남': <gensim.models.keyedvectors.Vocab at 0x1c45680c320>,
#  '의': <gensim.models.keyedvectors.Vocab at 0x1c45680c358>,
#  '징계를': <gensim.models.keyedvectors.Vocab at 0x1c45680c390>,
#  '막아주세요': <gensim.models.keyedvectors.Vocab at 0x1c45680c3c8>,
#  '넘어': <gensim.models.keyedvectors.Vocab at 0x1c45680c400>,
#  '만행': <gensim.models.keyedvectors.Vocab at 0x1c45680c438>,
#  '많은': <gensim.models.keyedvectors.Vocab at 0x1c45680c470>,
#  '도와주세요': <gensim.models.keyedvectors.Vocab at 0x1c45680c4a8>,
#  '안녕하세요': <gensim.models.keyedvectors.Vocab at 0x1c45680c4e0>,
#  '작은': <gensim.models.keyedvectors.Vocab at 0x1c45680c518>,
#  '법': <gensim.models.keyedvectors.Vocab at 0x1c45680c550>,
#  '이게': <gensim.models.keyedvectors.Vocab at 0x1c45680c588>,
#  '인가': <gensim.models.keyedvectors.Vocab at 0x1c45680c5c0>,
#  '피눈물': <gensim.models.keyedvectors.Vocab at 0x1c45680c5f8>,
#  '나는': <gensim.models.keyedvectors.Vocab at 0x1c45680c630>,
#  '돈': <gensim.models.keyedvectors.Vocab at 0x1c45680c668>,
#  '을': <gensim.models.keyedvectors.Vocab at 0x1c45680c6a0>,
#  '돌려': <gensim.models.keyedvectors.Vocab at 0x1c45680c6d8>,
#  '해주세요': <gensim.models.keyedvectors.Vocab at 0x1c45680c710>,
#  '문제점': <gensim.models.keyedvectors.Vocab at 0x1c45680c748>,
#  '따른': <gensim.models.keyedvectors.Vocab at 0x1c45680c780>,
#  '수개표': <gensim.models.keyedvectors.Vocab at 0x1c45680c7b8>,
#  '받을': <gensim.models.keyedvectors.Vocab at 0x1c45680c7f0>,
#  '수': <gensim.models.keyedvectors.Vocab at 0x1c45680c828>,
#  '있게': <gensim.models.keyedvectors.Vocab at 0x1c45680c860>,
#  '도와': <gensim.models.keyedvectors.Vocab at 0x1c45680c898>,
#  '주십시요': <gensim.models.keyedvectors.Vocab at 0x1c45680c8d0>,
#  '관련하여': <gensim.models.keyedvectors.Vocab at 0x1c45680c908>,
#  '청원드립니다': <gensim.models.keyedvectors.Vocab at 0x1c45680c940>,
#  '월': <gensim.models.keyedvectors.Vocab at 0x1c45680c978>,
#  '강서구': <gensim.models.keyedvectors.Vocab at 0x1c45680c9b0>,
#  '살인': <gensim.models.keyedvectors.Vocab at 0x1c45680c9e8>,
#  '사건': <gensim.models.keyedvectors.Vocab at 0x1c45680ca20>,
#  '가해자': <gensim.models.keyedvectors.Vocab at 0x1c45680ca58>,
#  '제': <gensim.models.keyedvectors.Vocab at 0x1c45680ca90>,
#  '친구가': <gensim.models.keyedvectors.Vocab at 0x1c45680cac8>,
#  '성추행을': <gensim.models.keyedvectors.Vocab at 0x1c45680cb00>,
#  '공공기관': <gensim.models.keyedvectors.Vocab at 0x1c45680cb38>,
#  '전환': <gensim.models.keyedvectors.Vocab at 0x1c45680cb70>,
#  '문재인': <gensim.models.keyedvectors.Vocab at 0x1c45680cba8>,
#  '대통령님께': <gensim.models.keyedvectors.Vocab at 0x1c45680cbe0>,
#  '구합니다': <gensim.models.keyedvectors.Vocab at 0x1c45680cc18>,
#  '수첩': <gensim.models.keyedvectors.Vocab at 0x1c45680cc50>,
#  '방송된': <gensim.models.keyedvectors.Vocab at 0x1c45680cc88>,
#  '몰려': <gensim.models.keyedvectors.Vocab at 0x1c45680ccc0>,
#  '억울하게': <gensim.models.keyedvectors.Vocab at 0x1c45680ccf8>,
#  '부실': <gensim.models.keyedvectors.Vocab at 0x1c45680cd30>,
#  '판사': <gensim.models.keyedvectors.Vocab at 0x1c45680cd68>,
#  '처벌해주세요': <gensim.models.keyedvectors.Vocab at 0x1c45680cda0>,
#  '폭행한': <gensim.models.keyedvectors.Vocab at 0x1c45680cdd8>,
#  '강력하게': <gensim.models.keyedvectors.Vocab at 0x1c45680ce10>,
#  '처벌해': <gensim.models.keyedvectors.Vocab at 0x1c45680ce48>,
#  '내': <gensim.models.keyedvectors.Vocab at 0x1c45680ce80>,
#  '돌아가신': <gensim.models.keyedvectors.Vocab at 0x1c45680ceb8>,
#  '저의': <gensim.models.keyedvectors.Vocab at 0x1c45680cef0>,
#  '삼촌': <gensim.models.keyedvectors.Vocab at 0x1c45680cf28>,
#  '재발방지': <gensim.models.keyedvectors.Vocab at 0x1c45680cf60>,
#  '대책': <gensim.models.keyedvectors.Vocab at 0x1c45680cf98>,
#  '마련이': <gensim.models.keyedvectors.Vocab at 0x1c45680cfd0>,
#  '필요합니다': <gensim.models.keyedvectors.Vocab at 0x1c45680f048>,
#  '갑질로': <gensim.models.keyedvectors.Vocab at 0x1c45680f080>,
#  '중소기업이': <gensim.models.keyedvectors.Vocab at 0x1c45680f0b8>,
#  '힘': <gensim.models.keyedvectors.Vocab at 0x1c45680f0f0>,
#  '힘을': <gensim.models.keyedvectors.Vocab at 0x1c45680f128>,
#  '실어주세요': <gensim.models.keyedvectors.Vocab at 0x1c45680f160>,
#  '아이의': <gensim.models.keyedvectors.Vocab at 0x1c45680f198>,
#  '미래를': <gensim.models.keyedvectors.Vocab at 0x1c45680f1d0>,
#  '망가뜨리는': <gensim.models.keyedvectors.Vocab at 0x1c45680f208>,
#  '어린이집': <gensim.models.keyedvectors.Vocab at 0x1c45680f240>,
#  '정서적': <gensim.models.keyedvectors.Vocab at 0x1c45680f278>,
#  '아동학대': <gensim.models.keyedvectors.Vocab at 0x1c45680f2b0>,
#  '반드시': <gensim.models.keyedvectors.Vocab at 0x1c45680f2e8>,
#  '파괴하는': <gensim.models.keyedvectors.Vocab at 0x1c45680f320>,
#  '인천': <gensim.models.keyedvectors.Vocab at 0x1c45680f358>,
#  '건립을': <gensim.models.keyedvectors.Vocab at 0x1c45680f390>,
#  '관련': <gensim.models.keyedvectors.Vocab at 0x1c45680f3c8>,
#  '업체': <gensim.models.keyedvectors.Vocab at 0x1c45680f400>,
#  '선정': <gensim.models.keyedvectors.Vocab at 0x1c45680f438>,
#  '특정': <gensim.models.keyedvectors.Vocab at 0x1c45680f470>,
#  '위한': <gensim.models.keyedvectors.Vocab at 0x1c45680f4a8>,
#  '의심': <gensim.models.keyedvectors.Vocab at 0x1c45680f4e0>,
#  '신고': <gensim.models.keyedvectors.Vocab at 0x1c45680f518>,
#  '죽이는': <gensim.models.keyedvectors.Vocab at 0x1c45680f550>,
#  '추진': <gensim.models.keyedvectors.Vocab at 0x1c45680f588>,
#  '반대합니다': <gensim.models.keyedvectors.Vocab at 0x1c45680f5c0>,
#  '꼭': <gensim.models.keyedvectors.Vocab at 0x1c45680f5f8>,
#  '살려주세요': <gensim.models.keyedvectors.Vocab at 0x1c45680f630>,
#  '제도를': <gensim.models.keyedvectors.Vocab at 0x1c45680f668>,
#  '소액주주들의': <gensim.models.keyedvectors.Vocab at 0x1c45680f6a0>,
#  '피해를': <gensim.models.keyedvectors.Vocab at 0x1c45680f6d8>,
#  '직접': <gensim.models.keyedvectors.Vocab at 0x1c45680f710>,
#  '관리': <gensim.models.keyedvectors.Vocab at 0x1c45680f748>,
#  '없이': <gensim.models.keyedvectors.Vocab at 0x1c45680f780>,
#  '양수발전소': <gensim.models.keyedvectors.Vocab at 0x1c45680f7b8>,
#  '유치': <gensim.models.keyedvectors.Vocab at 0x1c45680f7f0>,
#  '건설을': <gensim.models.keyedvectors.Vocab at 0x1c45680f828>,
#  '원주': <gensim.models.keyedvectors.Vocab at 0x1c45680f860>,
#  '초등학교': <gensim.models.keyedvectors.Vocab at 0x1c45680f898>,
#  '주십시오': <gensim.models.keyedvectors.Vocab at 0x1c45680f8d0>,
#  '않는': <gensim.models.keyedvectors.Vocab at 0x1c45680f908>,
#  '윤': <gensim.models.keyedvectors.Vocab at 0x1c45680f940>,
#  '개정을': <gensim.models.keyedvectors.Vocab at 0x1c45680f978>,
#  '요청합니다': <gensim.models.keyedvectors.Vocab at 0x1c45680f9b0>,
#  '병원의': <gensim.models.keyedvectors.Vocab at 0x1c45680f9e8>,
#  '의료사고': <gensim.models.keyedvectors.Vocab at 0x1c45680fa20>,
#  '강요하는': <gensim.models.keyedvectors.Vocab at 0x1c45680fa58>,
#  '미얀마': <gensim.models.keyedvectors.Vocab at 0x1c45680fa90>,
#  '한국인을': <gensim.models.keyedvectors.Vocab at 0x1c45680fac8>,
#  '구해주세요': <gensim.models.keyedvectors.Vocab at 0x1c45680fb00>,
#  '자동차': <gensim.models.keyedvectors.Vocab at 0x1c45680fb38>,
#  '사고': <gensim.models.keyedvectors.Vocab at 0x1c45680fb70>,
#  '진상규명': <gensim.models.keyedvectors.Vocab at 0x1c45680fba8>,
#  '바랍니다': <gensim.models.keyedvectors.Vocab at 0x1c45680fbe0>,
#  '의한': <gensim.models.keyedvectors.Vocab at 0x1c45680fc18>,
#  '처리': <gensim.models.keyedvectors.Vocab at 0x1c45680fc50>,
#  '경찰에': <gensim.models.keyedvectors.Vocab at 0x1c45680fc88>,
#  '개인정보': <gensim.models.keyedvectors.Vocab at 0x1c45680fcc0>,
#  '침해': <gensim.models.keyedvectors.Vocab at 0x1c45680fcf8>,
#  '업무': <gensim.models.keyedvectors.Vocab at 0x1c45680fd30>,
#  '방해': <gensim.models.keyedvectors.Vocab at 0x1c45680fd68>,
#  '건': <gensim.models.keyedvectors.Vocab at 0x1c45680fda0>,
#  '변경': <gensim.models.keyedvectors.Vocab at 0x1c45680fdd8>,
#  '청원': <gensim.models.keyedvectors.Vocab at 0x1c45680fe10>,
#  '불법': <gensim.models.keyedvectors.Vocab at 0x1c45680fe48>,
#  '소상공인': <gensim.models.keyedvectors.Vocab at 0x1c45680fe80>,
#  '처해있어요': <gensim.models.keyedvectors.Vocab at 0x1c45680feb8>,
#  '조치를': <gensim.models.keyedvectors.Vocab at 0x1c45680fef0>,
#  '주세요': <gensim.models.keyedvectors.Vocab at 0x1c45680ff28>,
#  '주': <gensim.models.keyedvectors.Vocab at 0x1c45680ff60>,
#  '대한민국': <gensim.models.keyedvectors.Vocab at 0x1c45680ff98>,
#  '입양': <gensim.models.keyedvectors.Vocab at 0x1c45680ffd0>,
#  '시간': <gensim.models.keyedvectors.Vocab at 0x1c456812048>,
#  '단축': <gensim.models.keyedvectors.Vocab at 0x1c456812080>,
#  '이재명': <gensim.models.keyedvectors.Vocab at 0x1c4568120b8>,
#  '보복성': <gensim.models.keyedvectors.Vocab at 0x1c4568120f0>,
#  '폐원을': <gensim.models.keyedvectors.Vocab at 0x1c456812128>,
#  '국민혈세로': <gensim.models.keyedvectors.Vocab at 0x1c456812160>,
#  '전면': <gensim.models.keyedvectors.Vocab at 0x1c456812198>,
#  '폐지를': <gensim.models.keyedvectors.Vocab at 0x1c4568121d0>,
#  '청원합니다': <gensim.models.keyedvectors.Vocab at 0x1c456812208>,
#  '수상한': <gensim.models.keyedvectors.Vocab at 0x1c456812240>,
#  '즉각': <gensim.models.keyedvectors.Vocab at 0x1c456812278>,
#  '명칭을': <gensim.models.keyedvectors.Vocab at 0x1c4568122b0>,
#  '바꿔': <gensim.models.keyedvectors.Vocab at 0x1c4568122e8>,
#  '가': <gensim.models.keyedvectors.Vocab at 0x1c456812320>,
#  '어린이': <gensim.models.keyedvectors.Vocab at 0x1c456812358>,
#  '구': <gensim.models.keyedvectors.Vocab at 0x1c456812390>,
#  '구역': <gensim.models.keyedvectors.Vocab at 0x1c4568123c8>,
#  '수사촉구': <gensim.models.keyedvectors.Vocab at 0x1c456812400>,
#  '대한': <gensim.models.keyedvectors.Vocab at 0x1c456812438>,
#  '신속하게': <gensim.models.keyedvectors.Vocab at 0x1c456812470>,
#  '자유한국당': <gensim.models.keyedvectors.Vocab at 0x1c4568124a8>,
#  '나경원': <gensim.models.keyedvectors.Vocab at 0x1c4568124e0>,
#  '원내대표의': <gensim.models.keyedvectors.Vocab at 0x1c456812518>,
#  '세가지': <gensim.models.keyedvectors.Vocab at 0x1c456812550>,
#  '의혹': <gensim.models.keyedvectors.Vocab at 0x1c456812588>,
#  '풀어주세요': <gensim.models.keyedvectors.Vocab at 0x1c4568125c0>,
#  '부동산': <gensim.models.keyedvectors.Vocab at 0x1c4568125f8>,
#  '사기로': <gensim.models.keyedvectors.Vocab at 0x1c456812630>,
#  '삶': <gensim.models.keyedvectors.Vocab at 0x1c456812668>,
#  '재난': <gensim.models.keyedvectors.Vocab at 0x1c4568126a0>,
#  '발생': <gensim.models.keyedvectors.Vocab at 0x1c4568126d8>,
#  '시': <gensim.models.keyedvectors.Vocab at 0x1c456812710>,
#  '방송': <gensim.models.keyedvectors.Vocab at 0x1c456812748>,
#  '대규모': <gensim.models.keyedvectors.Vocab at 0x1c456812780>,
#  '있는': <gensim.models.keyedvectors.Vocab at 0x1c4568127b8>,
#  '도입을': <gensim.models.keyedvectors.Vocab at 0x1c4568127f0>,
#  '장애인': <gensim.models.keyedvectors.Vocab at 0x1c456812828>,
#  '제대로': <gensim.models.keyedvectors.Vocab at 0x1c456812860>,
#  '검토해주세요': <gensim.models.keyedvectors.Vocab at 0x1c456812898>,
#  '법을': <gensim.models.keyedvectors.Vocab at 0x1c4568128d0>,
#  '수사팀을': <gensim.models.keyedvectors.Vocab at 0x1c456812908>,
#  '전국에': <gensim.models.keyedvectors.Vocab at 0x1c456812940>,
#  '재수사': <gensim.models.keyedvectors.Vocab at 0x1c456812978>,
#  '그리고': <gensim.models.keyedvectors.Vocab at 0x1c4568129b0>,
#  '병원': <gensim.models.keyedvectors.Vocab at 0x1c4568129e8>,
#  '억울함을': <gensim.models.keyedvectors.Vocab at 0x1c456812a20>,
#  '호소합니다': <gensim.models.keyedvectors.Vocab at 0x1c456812a58>,
#  '악성': <gensim.models.keyedvectors.Vocab at 0x1c456812a90>,
#  '통제': <gensim.models.keyedvectors.Vocab at 0x1c456812ac8>,
#  '강화': <gensim.models.keyedvectors.Vocab at 0x1c456812b00>,
#  '요청': <gensim.models.keyedvectors.Vocab at 0x1c456812b38>,
#  '인근': <gensim.models.keyedvectors.Vocab at 0x1c456812b70>,
#  '공직자들의': <gensim.models.keyedvectors.Vocab at 0x1c456812ba8>,
#  '두': <gensim.models.keyedvectors.Vocab at 0x1c456812be0>,
#  '늘려주세요': <gensim.models.keyedvectors.Vocab at 0x1c456812c18>,
#  '군': <gensim.models.keyedvectors.Vocab at 0x1c456812c50>,
#  '수협의': <gensim.models.keyedvectors.Vocab at 0x1c456812c88>,
#  '조합원': <gensim.models.keyedvectors.Vocab at 0x1c456812cc0>,
#  '대해': <gensim.models.keyedvectors.Vocab at 0x1c456812cf8>,
#  '문제를': <gensim.models.keyedvectors.Vocab at 0x1c456812d30>,
#  '제기합니다': <gensim.models.keyedvectors.Vocab at 0x1c456812d68>,
#  '내려주세요': <gensim.models.keyedvectors.Vocab at 0x1c456812da0>,
#  '대구': <gensim.models.keyedvectors.Vocab at 0x1c456812dd8>,
#  '지정관련': <gensim.models.keyedvectors.Vocab at 0x1c456812e10>,
#  '유착관계': <gensim.models.keyedvectors.Vocab at 0x1c456812e48>,
#  '또는': <gensim.models.keyedvectors.Vocab at 0x1c456812e80>,
#  '은평구의': <gensim.models.keyedvectors.Vocab at 0x1c456812eb8>,
#  '민주주의를': <gensim.models.keyedvectors.Vocab at 0x1c456812ef0>,
#  '지켜주세요': <gensim.models.keyedvectors.Vocab at 0x1c456812f28>,
#  '이대로는': <gensim.models.keyedvectors.Vocab at 0x1c456812f60>,
#  '다': <gensim.models.keyedvectors.Vocab at 0x1c456812f98>,
#  '죽습니다': <gensim.models.keyedvectors.Vocab at 0x1c456812fd0>,
#  '대한민국의': <gensim.models.keyedvectors.Vocab at 0x1c456813048>,
#  '국가가': <gensim.models.keyedvectors.Vocab at 0x1c456813080>,
#  '문': <gensim.models.keyedvectors.Vocab at 0x1c4568130b8>,
#  '대통령님': <gensim.models.keyedvectors.Vocab at 0x1c4568130f0>,
#  '시험': <gensim.models.keyedvectors.Vocab at 0x1c456813128>,
#  '일정': <gensim.models.keyedvectors.Vocab at 0x1c456813160>,
#  '아닙니다': <gensim.models.keyedvectors.Vocab at 0x1c456813198>,
#  '쪼개기식': <gensim.models.keyedvectors.Vocab at 0x1c4568131d0>,
#  '공무원의': <gensim.models.keyedvectors.Vocab at 0x1c456813208>,
#  '편법개발': <gensim.models.keyedvectors.Vocab at 0x1c456813240>,
#  '현': <gensim.models.keyedvectors.Vocab at 0x1c456813278>,
#  '억원': <gensim.models.keyedvectors.Vocab at 0x1c4568132b0>,
#  '정말': <gensim.models.keyedvectors.Vocab at 0x1c4568132e8>,
#  '폐지': <gensim.models.keyedvectors.Vocab at 0x1c456813320>,
#  '해야합니다': <gensim.models.keyedvectors.Vocab at 0x1c456813358>,
#  '일본의': <gensim.models.keyedvectors.Vocab at 0x1c456813390>,
#  '강하게': <gensim.models.keyedvectors.Vocab at 0x1c4568133c8>,
#  '간절한': <gensim.models.keyedvectors.Vocab at 0x1c456813400>,
#  '희망을': <gensim.models.keyedvectors.Vocab at 0x1c456813438>,
#  '나서': <gensim.models.keyedvectors.Vocab at 0x1c456813470>,
#  '가는': <gensim.models.keyedvectors.Vocab at 0x1c4568134a8>,
#  '정부': <gensim.models.keyedvectors.Vocab at 0x1c4568134e0>,
#  '정책': <gensim.models.keyedvectors.Vocab at 0x1c456813518>,
#  '죽음을': <gensim.models.keyedvectors.Vocab at 0x1c456813550>,
#  '제발': <gensim.models.keyedvectors.Vocab at 0x1c456813588>,
#  '소방관': <gensim.models.keyedvectors.Vocab at 0x1c4568135c0>,
#  '개선을': <gensim.models.keyedvectors.Vocab at 0x1c4568135f8>,
#  '위해': <gensim.models.keyedvectors.Vocab at 0x1c456813630>,
#  '다시한번': <gensim.models.keyedvectors.Vocab at 0x1c456813668>,
#  '아이들이': <gensim.models.keyedvectors.Vocab at 0x1c4568136a0>,
#  '안전하게': <gensim.models.keyedvectors.Vocab at 0x1c4568136d8>,
#  '갈': <gensim.models.keyedvectors.Vocab at 0x1c456813710>,
#  '있도록': <gensim.models.keyedvectors.Vocab at 0x1c456813748>,
#  '건설': <gensim.models.keyedvectors.Vocab at 0x1c456813780>,
#  '근로자의': <gensim.models.keyedvectors.Vocab at 0x1c4568137b8>,
#  '눈물': <gensim.models.keyedvectors.Vocab at 0x1c4568137f0>,
#  '맞는': <gensim.models.keyedvectors.Vocab at 0x1c456813828>,
#  '월급을': <gensim.models.keyedvectors.Vocab at 0x1c456813860>,
#  '인상': <gensim.models.keyedvectors.Vocab at 0x1c456813898>,
#  '부탁': <gensim.models.keyedvectors.Vocab at 0x1c4568138d0>,
#  '드립니다': <gensim.models.keyedvectors.Vocab at 0x1c456813908>,
#  '폐지해주세요': <gensim.models.keyedvectors.Vocab at 0x1c456813940>,
#  '성희롱을': <gensim.models.keyedvectors.Vocab at 0x1c456813978>,
#  '말아': <gensim.models.keyedvectors.Vocab at 0x1c4568139b0>,
#  '조속한': <gensim.models.keyedvectors.Vocab at 0x1c4568139e8>,
#  '통과를': <gensim.models.keyedvectors.Vocab at 0x1c456813a20>,
#  '의원': <gensim.models.keyedvectors.Vocab at 0x1c456813a58>,
#  '박탈': <gensim.models.keyedvectors.Vocab at 0x1c456813a90>,
#  '반려동물': <gensim.models.keyedvectors.Vocab at 0x1c456813ac8>,
#  '만들어': <gensim.models.keyedvectors.Vocab at 0x1c456813b00>,
#  '산림청': <gensim.models.keyedvectors.Vocab at 0x1c456813b38>,
#  '처우개선을': <gensim.models.keyedvectors.Vocab at 0x1c456813b70>,
#  '고성': <gensim.models.keyedvectors.Vocab at 0x1c456813ba8>,
#  '산불': <gensim.models.keyedvectors.Vocab at 0x1c456813be0>,
#  '올려주세요': <gensim.models.keyedvectors.Vocab at 0x1c456813c18>,
#  '대통령님의': <gensim.models.keyedvectors.Vocab at 0x1c456813c50>,
#  '다시': <gensim.models.keyedvectors.Vocab at 0x1c456813c88>,
#  '국민의': <gensim.models.keyedvectors.Vocab at 0x1c456813cc0>,
#  '생명을': <gensim.models.keyedvectors.Vocab at 0x1c456813cf8>,
#  '위협하는': <gensim.models.keyedvectors.Vocab at 0x1c456813d30>,
#  '국회의원을': <gensim.models.keyedvectors.Vocab at 0x1c456813d68>,
#  '수원': <gensim.models.keyedvectors.Vocab at 0x1c456813da0>,
#  '고등학교': <gensim.models.keyedvectors.Vocab at 0x1c456813dd8>,
#  '학생들을': <gensim.models.keyedvectors.Vocab at 0x1c456813e10>,
#  '전환을': <gensim.models.keyedvectors.Vocab at 0x1c456813e48>,
#  '합법화': <gensim.models.keyedvectors.Vocab at 0x1c456813e80>,
#  '개정': <gensim.models.keyedvectors.Vocab at 0x1c456813eb8>,
#  '사망사건': <gensim.models.keyedvectors.Vocab at 0x1c456813ef0>,
#  '동생의': <gensim.models.keyedvectors.Vocab at 0x1c456813f28>,
#  '억울한': <gensim.models.keyedvectors.Vocab at 0x1c456813f60>,
#  '밝혀주세요': <gensim.models.keyedvectors.Vocab at 0x1c456813f98>,
#  '지주': <gensim.models.keyedvectors.Vocab at 0x1c456813fd0>,
#  '적폐': <gensim.models.keyedvectors.Vocab at 0x1c456818048>,
#  '박회장': <gensim.models.keyedvectors.Vocab at 0x1c456818080>,
#  '처벌하여': <gensim.models.keyedvectors.Vocab at 0x1c4568180b8>,
#  '일': <gensim.models.keyedvectors.Vocab at 0x1c4568180f0>,
#  '검찰총장의': <gensim.models.keyedvectors.Vocab at 0x1c456818128>,
#  '교통사고': <gensim.models.keyedvectors.Vocab at 0x1c456818160>,
#  '없는': <gensim.models.keyedvectors.Vocab at 0x1c456818198>,
#  '대구시': <gensim.models.keyedvectors.Vocab at 0x1c4568181d0>,
#  '여당': <gensim.models.keyedvectors.Vocab at 0x1c456818208>,
#  '밝혀': <gensim.models.keyedvectors.Vocab at 0x1c456818240>,
#  '양주시': <gensim.models.keyedvectors.Vocab at 0x1c456818278>,
#  '동': <gensim.models.keyedvectors.Vocab at 0x1c4568182b0>,
#  '나오는': <gensim.models.keyedvectors.Vocab at 0x1c4568182e8>,
#  '해결해주세요': <gensim.models.keyedvectors.Vocab at 0x1c456818320>,
#  '살': <gensim.models.keyedvectors.Vocab at 0x1c456818358>,
#  '만세': <gensim.models.keyedvectors.Vocab at 0x1c456818390>,
#  '저희딸이': <gensim.models.keyedvectors.Vocab at 0x1c4568183c8>,
#  '노동자를': <gensim.models.keyedvectors.Vocab at 0x1c456818400>,
#  '만': <gensim.models.keyedvectors.Vocab at 0x1c456818438>,
#  '낙태법': <gensim.models.keyedvectors.Vocab at 0x1c456818470>,
#  '생명의': <gensim.models.keyedvectors.Vocab at 0x1c4568184a8>,
#  '친': <gensim.models.keyedvectors.Vocab at 0x1c4568184e0>,
#  '정부가': <gensim.models.keyedvectors.Vocab at 0x1c456818518>,
#  '잃어버린': <gensim.models.keyedvectors.Vocab at 0x1c456818550>,
#  '부탁드립니다': <gensim.models.keyedvectors.Vocab at 0x1c456818588>,
#  '더이상': <gensim.models.keyedvectors.Vocab at 0x1c4568185c0>,
#  '재고를': <gensim.models.keyedvectors.Vocab at 0x1c4568185f8>,
#  '관한': <gensim.models.keyedvectors.Vocab at 0x1c456818630>,
#  '싶습니다': <gensim.models.keyedvectors.Vocab at 0x1c456818668>,
#  '민주당': <gensim.models.keyedvectors.Vocab at 0x1c4568186a0>,
#  '이해찬': <gensim.models.keyedvectors.Vocab at 0x1c4568186d8>,
#  '탄핵': <gensim.models.keyedvectors.Vocab at 0x1c456818710>,
#  '단독주택': <gensim.models.keyedvectors.Vocab at 0x1c456818748>,
#  '확대해': <gensim.models.keyedvectors.Vocab at 0x1c456818780>,
#  '경찰의': <gensim.models.keyedvectors.Vocab at 0x1c4568187b8>,
#  '행정에': <gensim.models.keyedvectors.Vocab at 0x1c4568187f0>,
#  '대책마련': <gensim.models.keyedvectors.Vocab at 0x1c456818828>,
#  '년을': <gensim.models.keyedvectors.Vocab at 0x1c456818860>,
#  '계약한': <gensim.models.keyedvectors.Vocab at 0x1c456818898>,
#  '한국토지주택공사의': <gensim.models.keyedvectors.Vocab at 0x1c4568188d0>,
#  '죄를': <gensim.models.keyedvectors.Vocab at 0x1c456818908>,
#  '감사원': <gensim.models.keyedvectors.Vocab at 0x1c456818940>,
#  '제의': <gensim.models.keyedvectors.Vocab at 0x1c456818978>,
#  '조작': <gensim.models.keyedvectors.Vocab at 0x1c4568189b0>,
#  '수사해주세요': <gensim.models.keyedvectors.Vocab at 0x1c4568189e8>,
#  '명': <gensim.models.keyedvectors.Vocab at 0x1c456818a20>,
#  '규모': <gensim.models.keyedvectors.Vocab at 0x1c456818a58>,
#  '성범죄자': <gensim.models.keyedvectors.Vocab at 0x1c456818a90>,
#  '인간문화재': <gensim.models.keyedvectors.Vocab at 0x1c456818ac8>,
#  '자격을': <gensim.models.keyedvectors.Vocab at 0x1c456818b00>,
#  '어디에': <gensim.models.keyedvectors.Vocab at 0x1c456818b38>,
#  '환노위': <gensim.models.keyedvectors.Vocab at 0x1c456818b70>,
#  '폐기물': <gensim.models.keyedvectors.Vocab at 0x1c456818ba8>,
#  '통과해주세요': <gensim.models.keyedvectors.Vocab at 0x1c456818be0>,
#  '비리': <gensim.models.keyedvectors.Vocab at 0x1c456818c18>,
#  '연금지급': <gensim.models.keyedvectors.Vocab at 0x1c456818c50>,
#  '국회의원': <gensim.models.keyedvectors.Vocab at 0x1c456818c88>,
#  '세비': <gensim.models.keyedvectors.Vocab at 0x1c456818cc0>,
#  '횡포를': <gensim.models.keyedvectors.Vocab at 0x1c456818cf8>,
#  '막아': <gensim.models.keyedvectors.Vocab at 0x1c456818d30>,
#  '공시가격': <gensim.models.keyedvectors.Vocab at 0x1c456818d68>,
#  '환자': <gensim.models.keyedvectors.Vocab at 0x1c456818da0>,
#  '건강보험': <gensim.models.keyedvectors.Vocab at 0x1c456818dd8>,
#  '급여': <gensim.models.keyedvectors.Vocab at 0x1c456818e10>,
#  '적용': <gensim.models.keyedvectors.Vocab at 0x1c456818e48>,
#  '규정': <gensim.models.keyedvectors.Vocab at 0x1c456818e80>,
#  '철회': <gensim.models.keyedvectors.Vocab at 0x1c456818eb8>,
#  '는': <gensim.models.keyedvectors.Vocab at 0x1c456818ef0>,
#  '미분양': <gensim.models.keyedvectors.Vocab at 0x1c456818f28>,
#  '주택': <gensim.models.keyedvectors.Vocab at 0x1c456818f60>,
#  '왜': <gensim.models.keyedvectors.Vocab at 0x1c456818f98>,
#  '중단하라': <gensim.models.keyedvectors.Vocab at 0x1c456818fd0>,
#  '노인': <gensim.models.keyedvectors.Vocab at 0x1c45681c048>,
#  '아파트': <gensim.models.keyedvectors.Vocab at 0x1c45681c080>,
#  '검찰': <gensim.models.keyedvectors.Vocab at 0x1c45681c0b8>,
#  '어떻게': <gensim.models.keyedvectors.Vocab at 0x1c45681c0f0>,
#  '통해': <gensim.models.keyedvectors.Vocab at 0x1c45681c128>,
#  '운영하는': <gensim.models.keyedvectors.Vocab at 0x1c45681c160>,
#  '방안을': <gensim.models.keyedvectors.Vocab at 0x1c45681c198>,
#  '동참해': <gensim.models.keyedvectors.Vocab at 0x1c45681c1d0>,
#  '무능한': <gensim.models.keyedvectors.Vocab at 0x1c45681c208>,
#  '공권력': <gensim.models.keyedvectors.Vocab at 0x1c45681c240>,
#  '못': <gensim.models.keyedvectors.Vocab at 0x1c45681c278>,
#  '회사가': <gensim.models.keyedvectors.Vocab at 0x1c45681c2b0>,
#  '있습니다': <gensim.models.keyedvectors.Vocab at 0x1c45681c2e8>,
#  '환자를': <gensim.models.keyedvectors.Vocab at 0x1c45681c320>,
#  '하지': <gensim.models.keyedvectors.Vocab at 0x1c45681c358>,
#  '않은': <gensim.models.keyedvectors.Vocab at 0x1c45681c390>,
#  '주시기': <gensim.models.keyedvectors.Vocab at 0x1c45681c3c8>,
#  '과도한': <gensim.models.keyedvectors.Vocab at 0x1c45681c400>,
#  '제도개선': <gensim.models.keyedvectors.Vocab at 0x1c45681c438>,
#  '건의': <gensim.models.keyedvectors.Vocab at 0x1c45681c470>,
#  '납부를': <gensim.models.keyedvectors.Vocab at 0x1c45681c4a8>,
#  '거부합니다': <gensim.models.keyedvectors.Vocab at 0x1c45681c4e0>,
#  '화물시장의': <gensim.models.keyedvectors.Vocab at 0x1c45681c518>,
#  '적폐를': <gensim.models.keyedvectors.Vocab at 0x1c45681c550>,
#  '개선해주세요': <gensim.models.keyedvectors.Vocab at 0x1c45681c588>,
#  '이용해': <gensim.models.keyedvectors.Vocab at 0x1c45681c5c0>,
#  '하는': <gensim.models.keyedvectors.Vocab at 0x1c45681c5f8>,
#  '것은': <gensim.models.keyedvectors.Vocab at 0x1c45681c630>,
#  '피해자들을': <gensim.models.keyedvectors.Vocab at 0x1c45681c668>,
#  '위협받고': <gensim.models.keyedvectors.Vocab at 0x1c45681c6a0>,
#  '건립': <gensim.models.keyedvectors.Vocab at 0x1c45681c6d8>,
#  '은평구': <gensim.models.keyedvectors.Vocab at 0x1c45681c710>,
#  '주민들을': <gensim.models.keyedvectors.Vocab at 0x1c45681c748>,
#  '살려주십시요': <gensim.models.keyedvectors.Vocab at 0x1c45681c780>,
#  '직원': <gensim.models.keyedvectors.Vocab at 0x1c45681c7b8>,
#  '처우를': <gensim.models.keyedvectors.Vocab at 0x1c45681c7f0>,
#  '아들은': <gensim.models.keyedvectors.Vocab at 0x1c45681c828>,
#  '보이스피싱': <gensim.models.keyedvectors.Vocab at 0x1c45681c860>,
#  '범죄자가': <gensim.models.keyedvectors.Vocab at 0x1c45681c898>,
#  '아니라': <gensim.models.keyedvectors.Vocab at 0x1c45681c8d0>,
#  '피해자입니다': <gensim.models.keyedvectors.Vocab at 0x1c45681c908>,
#  '바로잡아': <gensim.models.keyedvectors.Vocab at 0x1c45681c940>,
#  '속초': <gensim.models.keyedvectors.Vocab at 0x1c45681c978>,
#  '등록': <gensim.models.keyedvectors.Vocab at 0x1c45681c9b0>,
#  '연장': <gensim.models.keyedvectors.Vocab at 0x1c45681c9e8>,
#  '국민과': <gensim.models.keyedvectors.Vocab at 0x1c45681ca20>,
#  '더불어': <gensim.models.keyedvectors.Vocab at 0x1c45681ca58>,
#  '대통령': <gensim.models.keyedvectors.Vocab at 0x1c45681ca90>,
#  '설치를': <gensim.models.keyedvectors.Vocab at 0x1c45681cac8>,
#  '정치적으로': <gensim.models.keyedvectors.Vocab at 0x1c45681cb00>,
#  '사람들에게': <gensim.models.keyedvectors.Vocab at 0x1c45681cb38>,
#  '강력한': <gensim.models.keyedvectors.Vocab at 0x1c45681cb70>,
#  '처벌이': <gensim.models.keyedvectors.Vocab at 0x1c45681cba8>,
#  '버닝썬': <gensim.models.keyedvectors.Vocab at 0x1c45681cbe0>,
#  '수사해': <gensim.models.keyedvectors.Vocab at 0x1c45681cc18>,
#  '보조금': <gensim.models.keyedvectors.Vocab at 0x1c45681cc50>,
#  '지원을': <gensim.models.keyedvectors.Vocab at 0x1c45681cc88>,
#  '받게': <gensim.models.keyedvectors.Vocab at 0x1c45681ccc0>,
#  '그': <gensim.models.keyedvectors.Vocab at 0x1c45681ccf8>,
#  '아무런': <gensim.models.keyedvectors.Vocab at 0x1c45681cd30>,
#  '강제': <gensim.models.keyedvectors.Vocab at 0x1c45681cd68>,
#  '도와주십시오': <gensim.models.keyedvectors.Vocab at 0x1c45681cda0>,
#  '신설': <gensim.models.keyedvectors.Vocab at 0x1c45681cdd8>,
#  '촉구': <gensim.models.keyedvectors.Vocab at 0x1c45681ce10>,
#  '사고를': <gensim.models.keyedvectors.Vocab at 0x1c45681ce48>,
#  '법안을': <gensim.models.keyedvectors.Vocab at 0x1c45681ce80>,
#  '마련해주세요': <gensim.models.keyedvectors.Vocab at 0x1c45681ceb8>,
#  '서울': <gensim.models.keyedvectors.Vocab at 0x1c45681cef0>,
#  '지하철': <gensim.models.keyedvectors.Vocab at 0x1c45681cf28>,
#  '임산부': <gensim.models.keyedvectors.Vocab at 0x1c45681cf60>,
#  '배려석에': <gensim.models.keyedvectors.Vocab at 0x1c45681cf98>,
#  '핑크라이트': <gensim.models.keyedvectors.Vocab at 0x1c45681cfd0>,
#  '일은': <gensim.models.keyedvectors.Vocab at 0x1c45681f048>,
#  '하고': <gensim.models.keyedvectors.Vocab at 0x1c45681f080>,
#  '길바닥에': <gensim.models.keyedvectors.Vocab at 0x1c45681f0b8>,
#  '나': <gensim.models.keyedvectors.Vocab at 0x1c45681f0f0>,
#  '앉게': <gensim.models.keyedvectors.Vocab at 0x1c45681f128>,
#  '생겼습니다': <gensim.models.keyedvectors.Vocab at 0x1c45681f160>,
#  '걱정입니다': <gensim.models.keyedvectors.Vocab at 0x1c45681f198>,
#  '전담': <gensim.models.keyedvectors.Vocab at 0x1c45681f1d0>,
#  '발본색원': <gensim.models.keyedvectors.Vocab at 0x1c45681f208>,
#  '약속을': <gensim.models.keyedvectors.Vocab at 0x1c45681f240>,
#  '학교': <gensim.models.keyedvectors.Vocab at 0x1c45681f278>,
#  '성': <gensim.models.keyedvectors.Vocab at 0x1c45681f2b0>,
#  '말아주세요': <gensim.models.keyedvectors.Vocab at 0x1c45681f2e8>,
#  '후쿠시마': <gensim.models.keyedvectors.Vocab at 0x1c45681f320>,
#  '수입금지': <gensim.models.keyedvectors.Vocab at 0x1c45681f358>,
#  '공무원들이': <gensim.models.keyedvectors.Vocab at 0x1c45681f390>,
#  '해': <gensim.models.keyedvectors.Vocab at 0x1c45681f3c8>,
#  '살려': <gensim.models.keyedvectors.Vocab at 0x1c45681f400>,
#  '동대문': <gensim.models.keyedvectors.Vocab at 0x1c45681f438>,
#  '분양': <gensim.models.keyedvectors.Vocab at 0x1c45681f470>,
#  '건설사': <gensim.models.keyedvectors.Vocab at 0x1c45681f4a8>,
#  '와': <gensim.models.keyedvectors.Vocab at 0x1c45681f4e0>,
#  '횡포': <gensim.models.keyedvectors.Vocab at 0x1c45681f518>,
#  '유치원': <gensim.models.keyedvectors.Vocab at 0x1c45681f550>,
#  '교사': <gensim.models.keyedvectors.Vocab at 0x1c45681f588>,
#  '근무': <gensim.models.keyedvectors.Vocab at 0x1c45681f5c0>,
#  '이제': <gensim.models.keyedvectors.Vocab at 0x1c45681f5f8>,
#  '요청드립니다': <gensim.models.keyedvectors.Vocab at 0x1c45681f630>,
#  '중공업': <gensim.models.keyedvectors.Vocab at 0x1c45681f668>,
#  '갑질': <gensim.models.keyedvectors.Vocab at 0x1c45681f6a0>,
#  '멈춰주세요': <gensim.models.keyedvectors.Vocab at 0x1c45681f6d8>,
#  '그린벨트': <gensim.models.keyedvectors.Vocab at 0x1c45681f710>,
#  '처우': <gensim.models.keyedvectors.Vocab at 0x1c45681f748>,
#  '정책에': <gensim.models.keyedvectors.Vocab at 0x1c45681f780>,
#  '대하여': <gensim.models.keyedvectors.Vocab at 0x1c45681f7b8>,
#  '보완': <gensim.models.keyedvectors.Vocab at 0x1c45681f7f0>,
#  '일본이': <gensim.models.keyedvectors.Vocab at 0x1c45681f828>,
#  '마음으로': <gensim.models.keyedvectors.Vocab at 0x1c45681f860>,
#  '이웃이': <gensim.models.keyedvectors.Vocab at 0x1c45681f898>,
#  '낙태죄': <gensim.models.keyedvectors.Vocab at 0x1c45681f8d0>,
#  '지원': <gensim.models.keyedvectors.Vocab at 0x1c45681f908>,
#  '부패': <gensim.models.keyedvectors.Vocab at 0x1c45681f940>,
#  '공무원': <gensim.models.keyedvectors.Vocab at 0x1c45681f978>,
#  '도입': <gensim.models.keyedvectors.Vocab at 0x1c45681f9b0>,
#  '제안': <gensim.models.keyedvectors.Vocab at 0x1c45681f9e8>,
#  '동물': <gensim.models.keyedvectors.Vocab at 0x1c45681fa20>,
#  '실험을': <gensim.models.keyedvectors.Vocab at 0x1c45681fa58>,
#  '아들의': <gensim.models.keyedvectors.Vocab at 0x1c45681fa90>,
#  '한국': <gensim.models.keyedvectors.Vocab at 0x1c45681fac8>,
#  '시장': <gensim.models.keyedvectors.Vocab at 0x1c45681fb00>,
#  '개선': <gensim.models.keyedvectors.Vocab at 0x1c45681fb38>,
#  '방안': <gensim.models.keyedvectors.Vocab at 0x1c45681fb70>,
#  '법안': <gensim.models.keyedvectors.Vocab at 0x1c45681fba8>,
#  '제정': <gensim.models.keyedvectors.Vocab at 0x1c45681fbe0>,
#  '편의점': <gensim.models.keyedvectors.Vocab at 0x1c45681fc18>,
#  '허위': <gensim.models.keyedvectors.Vocab at 0x1c45681fc50>,
#  '과장': <gensim.models.keyedvectors.Vocab at 0x1c45681fc88>,
#  '인한': <gensim.models.keyedvectors.Vocab at 0x1c45681fcc0>,
#  '피해': <gensim.models.keyedvectors.Vocab at 0x1c45681fcf8>,
#  '같은': <gensim.models.keyedvectors.Vocab at 0x1c45681fd30>,
#  '겪고': <gensim.models.keyedvectors.Vocab at 0x1c45681fd68>,
#  '국민들을': <gensim.models.keyedvectors.Vocab at 0x1c45681fda0>,
#  '않습니까': <gensim.models.keyedvectors.Vocab at 0x1c45681fdd8>,
#  '법제화': <gensim.models.keyedvectors.Vocab at 0x1c45681fe10>,
#  '미성년자': <gensim.models.keyedvectors.Vocab at 0x1c45681fe48>,
#  '피해보상': <gensim.models.keyedvectors.Vocab at 0x1c45681fe80>,
#  '무기징역': <gensim.models.keyedvectors.Vocab at 0x1c45681feb8>,
#  '빨리': <gensim.models.keyedvectors.Vocab at 0x1c45681fef0>,
#  '남양주시': <gensim.models.keyedvectors.Vocab at 0x1c45681ff28>,
#  '대통령보다': <gensim.models.keyedvectors.Vocab at 0x1c45681ff60>,
#  '더': <gensim.models.keyedvectors.Vocab at 0x1c45681ff98>,
#  '본인': <gensim.models.keyedvectors.Vocab at 0x1c45681ffd0>,
#  '칭하는': <gensim.models.keyedvectors.Vocab at 0x1c456821048>,
#  '사람': <gensim.models.keyedvectors.Vocab at 0x1c456821080>,
#  '대': <gensim.models.keyedvectors.Vocab at 0x1c4568210b8>,
#  '시스템을': <gensim.models.keyedvectors.Vocab at 0x1c4568210f0>,
#  '간곡히': <gensim.models.keyedvectors.Vocab at 0x1c456821128>,
#  '급여를': <gensim.models.keyedvectors.Vocab at 0x1c456821160>,
#  '한전': <gensim.models.keyedvectors.Vocab at 0x1c456821198>,
#  '아닌': <gensim.models.keyedvectors.Vocab at 0x1c4568211d0>,
#  '경기도': <gensim.models.keyedvectors.Vocab at 0x1c456821208>,
#  '원장을': <gensim.models.keyedvectors.Vocab at 0x1c456821240>,
#  '강력히': <gensim.models.keyedvectors.Vocab at 0x1c456821278>,
#  '비정규직의': <gensim.models.keyedvectors.Vocab at 0x1c4568212b0>,
#  '현실': <gensim.models.keyedvectors.Vocab at 0x1c4568212e8>,
#  '교육부의': <gensim.models.keyedvectors.Vocab at 0x1c456821320>,
#  '철폐를': <gensim.models.keyedvectors.Vocab at 0x1c456821358>,
#  '통한': <gensim.models.keyedvectors.Vocab at 0x1c456821390>,
#  '게임': <gensim.models.keyedvectors.Vocab at 0x1c4568213c8>,
#  '아버지를': <gensim.models.keyedvectors.Vocab at 0x1c456821400>,
#  '아들을': <gensim.models.keyedvectors.Vocab at 0x1c456821438>,
#  '부당한': <gensim.models.keyedvectors.Vocab at 0x1c456821470>,
#  '검찰개혁을': <gensim.models.keyedvectors.Vocab at 0x1c4568214a8>,
#  '임은정': <gensim.models.keyedvectors.Vocab at 0x1c4568214e0>,
#  '추천합니다': <gensim.models.keyedvectors.Vocab at 0x1c456821518>,
#  '세월호': <gensim.models.keyedvectors.Vocab at 0x1c456821550>,
#  '차명진': <gensim.models.keyedvectors.Vocab at 0x1c456821588>,
#  '전': <gensim.models.keyedvectors.Vocab at 0x1c4568215c0>,
#  '의원을': <gensim.models.keyedvectors.Vocab at 0x1c4568215f8>,
#  '처벌해주시기': <gensim.models.keyedvectors.Vocab at 0x1c456821630>,
#  '긴급': <gensim.models.keyedvectors.Vocab at 0x1c456821668>,
#  '부당해고': <gensim.models.keyedvectors.Vocab at 0x1c4568216a0>,
#  '반민특위': <gensim.models.keyedvectors.Vocab at 0x1c4568216d8>,
#  '다큐멘터리': <gensim.models.keyedvectors.Vocab at 0x1c456821710>,
#  '제작': <gensim.models.keyedvectors.Vocab at 0x1c456821748>,
#  '책임이': <gensim.models.keyedvectors.Vocab at 0x1c456821780>,
#  '요구합니다': <gensim.models.keyedvectors.Vocab at 0x1c4568217b8>,
#  '시를': <gensim.models.keyedvectors.Vocab at 0x1c4568217f0>,
#  '한': <gensim.models.keyedvectors.Vocab at 0x1c456821828>,
#  '대리점을': <gensim.models.keyedvectors.Vocab at 0x1c456821860>,
#  '무조건적인': <gensim.models.keyedvectors.Vocab at 0x1c456821898>,
#  '반대': <gensim.models.keyedvectors.Vocab at 0x1c4568218d0>,
#  '조사': <gensim.models.keyedvectors.Vocab at 0x1c456821908>,
#  '직장': <gensim.models.keyedvectors.Vocab at 0x1c456821940>,
#  '금지': <gensim.models.keyedvectors.Vocab at 0x1c456821978>,
#  '출신': <gensim.models.keyedvectors.Vocab at 0x1c4568219b0>,
#  '사기': <gensim.models.keyedvectors.Vocab at 0x1c4568219e8>,
#  '공정하게': <gensim.models.keyedvectors.Vocab at 0x1c456821a20>,
#  '만들어주세요': <gensim.models.keyedvectors.Vocab at 0x1c456821a58>,
#  '조사를': <gensim.models.keyedvectors.Vocab at 0x1c456821a90>,
#  '엄벌': <gensim.models.keyedvectors.Vocab at 0x1c456821ac8>,
#  '무궁화를': <gensim.models.keyedvectors.Vocab at 0x1c456821b00>,
#  '버스': <gensim.models.keyedvectors.Vocab at 0x1c456821b38>,
#  '실시해주세요': <gensim.models.keyedvectors.Vocab at 0x1c456821b70>,
#  '회': <gensim.models.keyedvectors.Vocab at 0x1c456821ba8>,
#  '영구': <gensim.models.keyedvectors.Vocab at 0x1c456821be0>,
#  '퇴출': <gensim.models.keyedvectors.Vocab at 0x1c456821c18>,
#  '요구': <gensim.models.keyedvectors.Vocab at 0x1c456821c50>,
#  '구해': <gensim.models.keyedvectors.Vocab at 0x1c456821c88>,
#  '듭니다': <gensim.models.keyedvectors.Vocab at 0x1c456821cc0>,
#  '호선': <gensim.models.keyedvectors.Vocab at 0x1c456821cf8>,
#  '저희': <gensim.models.keyedvectors.Vocab at 0x1c456821d30>,
#  '정부의': <gensim.models.keyedvectors.Vocab at 0x1c456821d68>,
#  '고': <gensim.models.keyedvectors.Vocab at 0x1c456821da0>,
#  '대국민': <gensim.models.keyedvectors.Vocab at 0x1c456821dd8>,
#  '박근혜': <gensim.models.keyedvectors.Vocab at 0x1c456821e10>,
#  '석방을': <gensim.models.keyedvectors.Vocab at 0x1c456821e48>,
#  '진주': <gensim.models.keyedvectors.Vocab at 0x1c456821e80>,
#  '방화': <gensim.models.keyedvectors.Vocab at 0x1c456821eb8>,
#  '범죄자에': <gensim.models.keyedvectors.Vocab at 0x1c456821ef0>,
#  '대해서': <gensim.models.keyedvectors.Vocab at 0x1c456821f28>,
#  '기록물': <gensim.models.keyedvectors.Vocab at 0x1c456821f60>,
#  '공개': <gensim.models.keyedvectors.Vocab at 0x1c456821f98>,
#  '대책을': <gensim.models.keyedvectors.Vocab at 0x1c456821fd0>,
#  '재개발': <gensim.models.keyedvectors.Vocab at 0x1c456826048>,
#  '조합': <gensim.models.keyedvectors.Vocab at 0x1c456826080>,
#  '적폐청산': <gensim.models.keyedvectors.Vocab at 0x1c4568260b8>,
#  '공정한': <gensim.models.keyedvectors.Vocab at 0x1c4568260f0>,
#  '재판을': <gensim.models.keyedvectors.Vocab at 0x1c456826128>,
#  '받을수': <gensim.models.keyedvectors.Vocab at 0x1c456826160>,
#  '현재': <gensim.models.keyedvectors.Vocab at 0x1c456826198>,
#  '허가': <gensim.models.keyedvectors.Vocab at 0x1c4568261d0>,
#  '석방': <gensim.models.keyedvectors.Vocab at 0x1c456826208>,
#  '절대': <gensim.models.keyedvectors.Vocab at 0x1c456826240>,
#  '가습기': <gensim.models.keyedvectors.Vocab at 0x1c456826278>,
#  '대표': <gensim.models.keyedvectors.Vocab at 0x1c4568262b0>,
#  '구속': <gensim.models.keyedvectors.Vocab at 0x1c4568262e8>,
#  '수사': <gensim.models.keyedvectors.Vocab at 0x1c456826320>,
#  '임대아파트': <gensim.models.keyedvectors.Vocab at 0x1c456826358>,
#  '피해자와': <gensim.models.keyedvectors.Vocab at 0x1c456826390>,
#  '남겨진': <gensim.models.keyedvectors.Vocab at 0x1c4568263c8>,
#  '가족들을': <gensim.models.keyedvectors.Vocab at 0x1c456826400>,
#  '먼저': <gensim.models.keyedvectors.Vocab at 0x1c456826438>,
#  '예견된': <gensim.models.keyedvectors.Vocab at 0x1c456826470>,
#  '사건을': <gensim.models.keyedvectors.Vocab at 0x1c4568264a8>,
#  '못한': <gensim.models.keyedvectors.Vocab at 0x1c4568264e0>,
#  '경찰들': <gensim.models.keyedvectors.Vocab at 0x1c456826518>,
#  '수사를': <gensim.models.keyedvectors.Vocab at 0x1c456826550>,
#  '특검': <gensim.models.keyedvectors.Vocab at 0x1c456826588>,
#  '철저히': <gensim.models.keyedvectors.Vocab at 0x1c4568265c0>,
#  '대통령의': <gensim.models.keyedvectors.Vocab at 0x1c4568265f8>,
#  '안됩니다': <gensim.models.keyedvectors.Vocab at 0x1c456826630>,
#  '교사가': <gensim.models.keyedvectors.Vocab at 0x1c456826668>,
#  '세워주세요': <gensim.models.keyedvectors.Vocab at 0x1c4568266a0>,
#  '힘없는': <gensim.models.keyedvectors.Vocab at 0x1c4568266d8>,
#  '피해자를': <gensim.models.keyedvectors.Vocab at 0x1c456826710>,
#  '두번': <gensim.models.keyedvectors.Vocab at 0x1c456826748>,
#  '함께': <gensim.models.keyedvectors.Vocab at 0x1c456826780>,
#  '사법': <gensim.models.keyedvectors.Vocab at 0x1c4568267b8>,
#  '건설사의': <gensim.models.keyedvectors.Vocab at 0x1c4568267f0>,
#  '불법행위에': <gensim.models.keyedvectors.Vocab at 0x1c456826828>,
#  '사건과': <gensim.models.keyedvectors.Vocab at 0x1c456826860>,
#  '것을': <gensim.models.keyedvectors.Vocab at 0x1c456826898>,
#  '범죄': <gensim.models.keyedvectors.Vocab at 0x1c4568268d0>,
#  '원합니다': <gensim.models.keyedvectors.Vocab at 0x1c456826908>,
#  '말기': <gensim.models.keyedvectors.Vocab at 0x1c456826940>,
#  '너무': <gensim.models.keyedvectors.Vocab at 0x1c456826978>,
#  '출생신고': <gensim.models.keyedvectors.Vocab at 0x1c4568269b0>,
#  '의료': <gensim.models.keyedvectors.Vocab at 0x1c4568269e8>,
#  '교육': <gensim.models.keyedvectors.Vocab at 0x1c456826a20>,
#  '혜택': <gensim.models.keyedvectors.Vocab at 0x1c456826a58>,
#  '주는': <gensim.models.keyedvectors.Vocab at 0x1c456826a90>,
#  '아동': <gensim.models.keyedvectors.Vocab at 0x1c456826ac8>,
#  '마십시오': <gensim.models.keyedvectors.Vocab at 0x1c456826b00>,
#  '불법적인': <gensim.models.keyedvectors.Vocab at 0x1c456826b38>,
#  '바로잡아주세요': <gensim.models.keyedvectors.Vocab at 0x1c456826b70>,
#  '요양원을': <gensim.models.keyedvectors.Vocab at 0x1c456826ba8>,
#  '올바른': <gensim.models.keyedvectors.Vocab at 0x1c456826be0>,
#  '동물보호법': <gensim.models.keyedvectors.Vocab at 0x1c456826c18>,
#  '항동지구를': <gensim.models.keyedvectors.Vocab at 0x1c456826c50>,
#  '사람이': <gensim.models.keyedvectors.Vocab at 0x1c456826c88>,
#  '준': <gensim.models.keyedvectors.Vocab at 0x1c456826cc0>,
#  '국토부는': <gensim.models.keyedvectors.Vocab at 0x1c456826cf8>,
#  '평생': <gensim.models.keyedvectors.Vocab at 0x1c456826d30>,
#  '몸에': <gensim.models.keyedvectors.Vocab at 0x1c456826d68>,
#  '살아가는': <gensim.models.keyedvectors.Vocab at 0x1c456826da0>,
#  '명예를': <gensim.models.keyedvectors.Vocab at 0x1c456826dd8>,
#  '심신미약': <gensim.models.keyedvectors.Vocab at 0x1c456826e10>,
#  '등의': <gensim.models.keyedvectors.Vocab at 0x1c456826e48>,
#  '증인': <gensim.models.keyedvectors.Vocab at 0x1c456826e80>,
#  '동의하시길': <gensim.models.keyedvectors.Vocab at 0x1c456826eb8>,
#  '공동주택': <gensim.models.keyedvectors.Vocab at 0x1c456826ef0>,
#  '무너지고': <gensim.models.keyedvectors.Vocab at 0x1c456826f28>,
#  '단': <gensim.models.keyedvectors.Vocab at 0x1c456826f60>,
#  '담당': <gensim.models.keyedvectors.Vocab at 0x1c456826f98>,
#  '세입자를': <gensim.models.keyedvectors.Vocab at 0x1c456826fd0>,
#  '환경을': <gensim.models.keyedvectors.Vocab at 0x1c45682a048>,
#  '있을': <gensim.models.keyedvectors.Vocab at 0x1c45682a080>,
#  '학대': <gensim.models.keyedvectors.Vocab at 0x1c45682a0b8>,
#  '친일': <gensim.models.keyedvectors.Vocab at 0x1c45682a0f0>,
#  '교사를': <gensim.models.keyedvectors.Vocab at 0x1c45682a128>,
#  '시켜주세요': <gensim.models.keyedvectors.Vocab at 0x1c45682a160>,
#  '층간소음': <gensim.models.keyedvectors.Vocab at 0x1c45682a198>,
#  '본사의': <gensim.models.keyedvectors.Vocab at 0x1c45682a1d0>,
#  '철저한': <gensim.models.keyedvectors.Vocab at 0x1c45682a208>,
#  '지역': <gensim.models.keyedvectors.Vocab at 0x1c45682a240>,
#  '완화를': <gensim.models.keyedvectors.Vocab at 0x1c45682a278>,
#  '않게': <gensim.models.keyedvectors.Vocab at 0x1c45682a2b0>,
#  '제대로된': <gensim.models.keyedvectors.Vocab at 0x1c45682a2e8>,
#  '부탁합니다': <gensim.models.keyedvectors.Vocab at 0x1c45682a320>,
#  '세입자들의': <gensim.models.keyedvectors.Vocab at 0x1c45682a358>,
#  '들어주세요': <gensim.models.keyedvectors.Vocab at 0x1c45682a390>,
#  '경찰서': <gensim.models.keyedvectors.Vocab at 0x1c45682a3c8>,
#  '지사': <gensim.models.keyedvectors.Vocab at 0x1c45682a400>,
#  '차량에': <gensim.models.keyedvectors.Vocab at 0x1c45682a438>,
#  '비호': <gensim.models.keyedvectors.Vocab at 0x1c45682a470>,
#  '피해자가': <gensim.models.keyedvectors.Vocab at 0x1c45682a4a8>,
#  '되는': <gensim.models.keyedvectors.Vocab at 0x1c45682a4e0>,
#  '경찰과': <gensim.models.keyedvectors.Vocab at 0x1c45682a518>,
#  '살기': <gensim.models.keyedvectors.Vocab at 0x1c45682a550>,
#  '좋은': <gensim.models.keyedvectors.Vocab at 0x1c45682a588>,
#  '건설의': <gensim.models.keyedvectors.Vocab at 0x1c45682a5c0>,
#  '언제까지': <gensim.models.keyedvectors.Vocab at 0x1c45682a5f8>,
#  '시설': <gensim.models.keyedvectors.Vocab at 0x1c45682a630>,
#  '자유': <gensim.models.keyedvectors.Vocab at 0x1c45682a668>,
#  '한국당': <gensim.models.keyedvectors.Vocab at 0x1c45682a6a0>,
#  '정당해산': <gensim.models.keyedvectors.Vocab at 0x1c45682a6d8>,
#  '폐지에': <gensim.models.keyedvectors.Vocab at 0x1c45682a710>,
#  '김도현': <gensim.models.keyedvectors.Vocab at 0x1c45682a748>,
#  '과연': <gensim.models.keyedvectors.Vocab at 0x1c45682a780>,
#  '기자': <gensim.models.keyedvectors.Vocab at 0x1c45682a7b8>,
#  '촉구합니다': <gensim.models.keyedvectors.Vocab at 0x1c45682a7f0>,
#  '해산': <gensim.models.keyedvectors.Vocab at 0x1c45682a828>,
#  '권순일': <gensim.models.keyedvectors.Vocab at 0x1c45682a860>,
#  '대통령님은': <gensim.models.keyedvectors.Vocab at 0x1c45682a898>,
#  '공수처': <gensim.models.keyedvectors.Vocab at 0x1c45682a8d0>,
#  '대상': <gensim.models.keyedvectors.Vocab at 0x1c45682a908>,
#  '확대': <gensim.models.keyedvectors.Vocab at 0x1c45682a940>,
#  '발의안': <gensim.models.keyedvectors.Vocab at 0x1c45682a978>,
#  '국회': <gensim.models.keyedvectors.Vocab at 0x1c45682a9b0>,
#  '통과': <gensim.models.keyedvectors.Vocab at 0x1c45682a9e8>,
#  '신규': <gensim.models.keyedvectors.Vocab at 0x1c45682aa20>,
#  '청원서': <gensim.models.keyedvectors.Vocab at 0x1c45682aa58>,
#  '부터': <gensim.models.keyedvectors.Vocab at 0x1c45682aa90>,
#  '바로': <gensim.models.keyedvectors.Vocab at 0x1c45682aac8>,
#  '될': <gensim.models.keyedvectors.Vocab at 0x1c45682ab00>,
#  '없습니다': <gensim.models.keyedvectors.Vocab at 0x1c45682ab38>,
#  '법의': <gensim.models.keyedvectors.Vocab at 0x1c45682ab70>,
#  '물류': <gensim.models.keyedvectors.Vocab at 0x1c45682aba8>,
#  '국회의원의': <gensim.models.keyedvectors.Vocab at 0x1c45682abe0>,
#  '장관': <gensim.models.keyedvectors.Vocab at 0x1c45682ac18>,
#  '되지': <gensim.models.keyedvectors.Vocab at 0x1c45682ac50>,
#  '않을까요': <gensim.models.keyedvectors.Vocab at 0x1c45682ac88>,
#  '상수원': <gensim.models.keyedvectors.Vocab at 0x1c45682acc0>,
#  '시행하는': <gensim.models.keyedvectors.Vocab at 0x1c45682acf8>,
#  '모든': <gensim.models.keyedvectors.Vocab at 0x1c45682ad30>,
#  '경찰이': <gensim.models.keyedvectors.Vocab at 0x1c45682ad68>,
#  '등': <gensim.models.keyedvectors.Vocab at 0x1c45682ada0>,
#  '생명이': <gensim.models.keyedvectors.Vocab at 0x1c45682add8>,
#  '사태를': <gensim.models.keyedvectors.Vocab at 0x1c45682ae10>,
#  '건물주의': <gensim.models.keyedvectors.Vocab at 0x1c45682ae48>,
#  '횡포에': <gensim.models.keyedvectors.Vocab at 0x1c45682ae80>,
#  '같이': <gensim.models.keyedvectors.Vocab at 0x1c45682aeb8>,
#  '살아야': <gensim.models.keyedvectors.Vocab at 0x1c45682aef0>,
#  '우리': <gensim.models.keyedvectors.Vocab at 0x1c45682af28>,
#  '대한민국을': <gensim.models.keyedvectors.Vocab at 0x1c45682af60>,
#  '적극': <gensim.models.keyedvectors.Vocab at 0x1c45682af98>,
#  '간절히': <gensim.models.keyedvectors.Vocab at 0x1c45682afd0>,
#  '잘못': <gensim.models.keyedvectors.Vocab at 0x1c45682d048>,
#  '쓴': <gensim.models.keyedvectors.Vocab at 0x1c45682d080>,
#  '최저임금': <gensim.models.keyedvectors.Vocab at 0x1c45682d0b8>,
#  '비애': <gensim.models.keyedvectors.Vocab at 0x1c45682d0f0>,
#  '좀': <gensim.models.keyedvectors.Vocab at 0x1c45682d128>,
#  '보험료': <gensim.models.keyedvectors.Vocab at 0x1c45682d160>,
#  '은폐': <gensim.models.keyedvectors.Vocab at 0x1c45682d198>,
#  '횡포와': <gensim.models.keyedvectors.Vocab at 0x1c45682d1d0>,
#  '갑질에서': <gensim.models.keyedvectors.Vocab at 0x1c45682d208>,
#  '국민이': <gensim.models.keyedvectors.Vocab at 0x1c45682d240>,
#  '번': <gensim.models.keyedvectors.Vocab at 0x1c45682d278>,
#  '지금의': <gensim.models.keyedvectors.Vocab at 0x1c45682d2b0>,
#  '를': <gensim.models.keyedvectors.Vocab at 0x1c45682d2e8>,
#  '에': <gensim.models.keyedvectors.Vocab at 0x1c45682d320>,
#  '되어야': <gensim.models.keyedvectors.Vocab at 0x1c45682d358>,
#  '억': <gensim.models.keyedvectors.Vocab at 0x1c45682d390>,
#  '검증': <gensim.models.keyedvectors.Vocab at 0x1c45682d3c8>,
#  '처벌과': <gensim.models.keyedvectors.Vocab at 0x1c45682d400>,
#  '가능하게': <gensim.models.keyedvectors.Vocab at 0x1c45682d438>,
#  '노동자입니다': <gensim.models.keyedvectors.Vocab at 0x1c45682d470>,
#  '수사와': <gensim.models.keyedvectors.Vocab at 0x1c45682d4a8>,
#  '감사를': <gensim.models.keyedvectors.Vocab at 0x1c45682d4e0>,
#  '특검을': <gensim.models.keyedvectors.Vocab at 0x1c45682d518>,
#  '조선족': <gensim.models.keyedvectors.Vocab at 0x1c45682d550>,
#  '받았습니다': <gensim.models.keyedvectors.Vocab at 0x1c45682d588>,
#  '안전을': <gensim.models.keyedvectors.Vocab at 0x1c45682d5c0>,
#  '고속도로': <gensim.models.keyedvectors.Vocab at 0x1c45682d5f8>,
#  '갑질을': <gensim.models.keyedvectors.Vocab at 0x1c45682d630>,
#  '신고합니다': <gensim.models.keyedvectors.Vocab at 0x1c45682d668>,
#  '남편의': <gensim.models.keyedvectors.Vocab at 0x1c45682d6a0>,
#  '죽음에': <gensim.models.keyedvectors.Vocab at 0x1c45682d6d8>,
#  '정부는': <gensim.models.keyedvectors.Vocab at 0x1c45682d710>,
#  '면': <gensim.models.keyedvectors.Vocab at 0x1c45682d748>,
#  '민주주의': <gensim.models.keyedvectors.Vocab at 0x1c45682d780>,
#  '대한민국에서': <gensim.models.keyedvectors.Vocab at 0x1c45682d7b8>,
#  '행위를': <gensim.models.keyedvectors.Vocab at 0x1c45682d7f0>,
#  '경찰': <gensim.models.keyedvectors.Vocab at 0x1c45682d828>,
#  '계급': <gensim.models.keyedvectors.Vocab at 0x1c45682d860>,
#  '차': <gensim.models.keyedvectors.Vocab at 0x1c45682d898>,
#  '바꾸자': <gensim.models.keyedvectors.Vocab at 0x1c45682d8d0>,
#  '구축': <gensim.models.keyedvectors.Vocab at 0x1c45682d908>,
#  '전용': <gensim.models.keyedvectors.Vocab at 0x1c45682d940>,
#  '건설현장': <gensim.models.keyedvectors.Vocab at 0x1c45682d978>,
#  '이렇게': <gensim.models.keyedvectors.Vocab at 0x1c45682d9b0>,
#  '한번': <gensim.models.keyedvectors.Vocab at 0x1c45682d9e8>,
#  '고민': <gensim.models.keyedvectors.Vocab at 0x1c45682da20>,
#  '학교폭력을': <gensim.models.keyedvectors.Vocab at 0x1c45682da58>,
#  '가담자를': <gensim.models.keyedvectors.Vocab at 0x1c45682da90>,
#  '은폐하는': <gensim.models.keyedvectors.Vocab at 0x1c45682dac8>,
#  '아이들을': <gensim.models.keyedvectors.Vocab at 0x1c45682db00>,
#  '비리를': <gensim.models.keyedvectors.Vocab at 0x1c45682db38>,
#  '간': <gensim.models.keyedvectors.Vocab at 0x1c45682db70>,
#  '법으로': <gensim.models.keyedvectors.Vocab at 0x1c45682dba8>,
#  '원내대표': <gensim.models.keyedvectors.Vocab at 0x1c45682dbe0>,
#  '풀어': <gensim.models.keyedvectors.Vocab at 0x1c45682dc18>,
#  '악질': <gensim.models.keyedvectors.Vocab at 0x1c45682dc50>,
#  '할머니': <gensim.models.keyedvectors.Vocab at 0x1c45682dc88>,
#  '학대를': <gensim.models.keyedvectors.Vocab at 0x1c45682dcc0>,
#  '받은': <gensim.models.keyedvectors.Vocab at 0x1c45682dcf8>,
#  '들의': <gensim.models.keyedvectors.Vocab at 0x1c45682dd30>,
#  '국회법': <gensim.models.keyedvectors.Vocab at 0x1c45682dd68>,
#  '조': <gensim.models.keyedvectors.Vocab at 0x1c45682dda0>,
#  '조에': <gensim.models.keyedvectors.Vocab at 0x1c45682ddd8>,
#  '의원들의': <gensim.models.keyedvectors.Vocab at 0x1c45682de10>,
#  '처벌을': <gensim.models.keyedvectors.Vocab at 0x1c45682de48>,
#  '권리금': <gensim.models.keyedvectors.Vocab at 0x1c45682de80>,
#  '기준을': <gensim.models.keyedvectors.Vocab at 0x1c45682deb8>,
#  '더불어민주당': <gensim.models.keyedvectors.Vocab at 0x1c45682def0>,
#  '해체': <gensim.models.keyedvectors.Vocab at 0x1c45682df28>,
#  '원장': <gensim.models.keyedvectors.Vocab at 0x1c45682df60>,
#  '못하게': <gensim.models.keyedvectors.Vocab at 0x1c45682df98>,
#  '때문에': <gensim.models.keyedvectors.Vocab at 0x1c45682dfd0>,
#  '일어난': <gensim.models.keyedvectors.Vocab at 0x1c456830048>,
#  '상황': <gensim.models.keyedvectors.Vocab at 0x1c456830080>,
#  '해체를': <gensim.models.keyedvectors.Vocab at 0x1c4568300b8>,
#  '않도록': <gensim.models.keyedvectors.Vocab at 0x1c4568300f0>,
#  '발생한': <gensim.models.keyedvectors.Vocab at 0x1c456830128>,
#  '정신질환자': <gensim.models.keyedvectors.Vocab at 0x1c456830160>,
#  '저지른': <gensim.models.keyedvectors.Vocab at 0x1c456830198>,
#  '된': <gensim.models.keyedvectors.Vocab at 0x1c4568301d0>,
#  '정당': <gensim.models.keyedvectors.Vocab at 0x1c456830208>,
#  '일을': <gensim.models.keyedvectors.Vocab at 0x1c456830240>,
#  '승인을': <gensim.models.keyedvectors.Vocab at 0x1c456830278>,
#  '했습니다': <gensim.models.keyedvectors.Vocab at 0x1c4568302b0>,
#  '자유한국당의원': <gensim.models.keyedvectors.Vocab at 0x1c4568302e8>,
#  '의원들을': <gensim.models.keyedvectors.Vocab at 0x1c456830320>,
#  '협박': <gensim.models.keyedvectors.Vocab at 0x1c456830358>,
#  '목적의': <gensim.models.keyedvectors.Vocab at 0x1c456830390>,
#  '줄여주세요': <gensim.models.keyedvectors.Vocab at 0x1c4568303c8>,
#  '성남': <gensim.models.keyedvectors.Vocab at 0x1c456830400>,
#  '조현병을': <gensim.models.keyedvectors.Vocab at 0x1c456830438>,
#  '앓고': <gensim.models.keyedvectors.Vocab at 0x1c456830470>,
#  '환자의': <gensim.models.keyedvectors.Vocab at 0x1c4568304a8>,
#  '무고한': <gensim.models.keyedvectors.Vocab at 0x1c4568304e0>,
#  '조현병': <gensim.models.keyedvectors.Vocab at 0x1c456830518>,
#  '개정이': <gensim.models.keyedvectors.Vocab at 0x1c456830550>,
#  '시급합니다': <gensim.models.keyedvectors.Vocab at 0x1c456830588>,
#  '곰탕집': <gensim.models.keyedvectors.Vocab at 0x1c4568305c0>,
#  '성추행': <gensim.models.keyedvectors.Vocab at 0x1c4568305f8>,
#  '사건의': <gensim.models.keyedvectors.Vocab at 0x1c456830630>,
#  '위헌재판': <gensim.models.keyedvectors.Vocab at 0x1c456830668>,
#  '사과를': <gensim.models.keyedvectors.Vocab at 0x1c4568306a0>,
#  '위반한': <gensim.models.keyedvectors.Vocab at 0x1c4568306d8>,
#  '피해자': <gensim.models.keyedvectors.Vocab at 0x1c456830710>,
#  '입니다': <gensim.models.keyedvectors.Vocab at 0x1c456830748>,
#  '추악한': <gensim.models.keyedvectors.Vocab at 0x1c456830780>,
#  '성적': <gensim.models.keyedvectors.Vocab at 0x1c4568307b8>,
#  '전기산업기사': <gensim.models.keyedvectors.Vocab at 0x1c4568307f0>,
#  '과정평가형': <gensim.models.keyedvectors.Vocab at 0x1c456830828>,
#  '대법원': <gensim.models.keyedvectors.Vocab at 0x1c456830860>,
#  '나라': <gensim.models.keyedvectors.Vocab at 0x1c456830898>,
#  '땅을': <gensim.models.keyedvectors.Vocab at 0x1c4568308d0>,
#  '교회': <gensim.models.keyedvectors.Vocab at 0x1c456830908>,
#  '국회의원과': <gensim.models.keyedvectors.Vocab at 0x1c456830940>,
#  '특별법': <gensim.models.keyedvectors.Vocab at 0x1c456830978>,
#  '역사왜곡': <gensim.models.keyedvectors.Vocab at 0x1c4568309b0>,
#  '처벌법': <gensim.models.keyedvectors.Vocab at 0x1c4568309e8>,
#  '비례대표제': <gensim.models.keyedvectors.Vocab at 0x1c456830a20>,
#  '결사': <gensim.models.keyedvectors.Vocab at 0x1c456830a58>,
#  '해산시켜주세요': <gensim.models.keyedvectors.Vocab at 0x1c456830a90>,
#  '징계': <gensim.models.keyedvectors.Vocab at 0x1c456830ac8>,
#  '법적': <gensim.models.keyedvectors.Vocab at 0x1c456830b00>,
#  '처벌은': <gensim.models.keyedvectors.Vocab at 0x1c456830b38>,
#  '범죄자': <gensim.models.keyedvectors.Vocab at 0x1c456830b70>,
#  '조두순의': <gensim.models.keyedvectors.Vocab at 0x1c456830ba8>,
#  '출소를': <gensim.models.keyedvectors.Vocab at 0x1c456830be0>,
#  '퇴직금': <gensim.models.keyedvectors.Vocab at 0x1c456830c18>,
#  '요구하는': <gensim.models.keyedvectors.Vocab at 0x1c456830c50>,
#  '모욕하고': <gensim.models.keyedvectors.Vocab at 0x1c456830c88>,
#  '항': <gensim.models.keyedvectors.Vocab at 0x1c456830cc0>,
#  '악용하는': <gensim.models.keyedvectors.Vocab at 0x1c456830cf8>,
#  '정규직화': <gensim.models.keyedvectors.Vocab at 0x1c456830d30>,
#  '검토': <gensim.models.keyedvectors.Vocab at 0x1c456830d68>,
#  '엔터테인먼트': <gensim.models.keyedvectors.Vocab at 0x1c456830da0>,
#  '말하고': <gensim.models.keyedvectors.Vocab at 0x1c456830dd8>,
#  '대기업의': <gensim.models.keyedvectors.Vocab at 0x1c456830e10>,
#  '이상을': <gensim.models.keyedvectors.Vocab at 0x1c456830e48>,
#  '법규': <gensim.models.keyedvectors.Vocab at 0x1c456830e80>,
#  '해산을': <gensim.models.keyedvectors.Vocab at 0x1c456830eb8>,
#  '활성화': <gensim.models.keyedvectors.Vocab at 0x1c456830ef0>,
#  '서민의': <gensim.models.keyedvectors.Vocab at 0x1c456830f28>,
#  '다자녀': <gensim.models.keyedvectors.Vocab at 0x1c456830f60>,
#  '자동차세': <gensim.models.keyedvectors.Vocab at 0x1c456830f98>,
#  '감면': <gensim.models.keyedvectors.Vocab at 0x1c456830fd0>,
#  '원칙을': <gensim.models.keyedvectors.Vocab at 0x1c456835048>,
#  '국민청원': <gensim.models.keyedvectors.Vocab at 0x1c456835080>,
#  '김': <gensim.models.keyedvectors.Vocab at 0x1c4568350b8>,
#  '에서': <gensim.models.keyedvectors.Vocab at 0x1c4568350f0>,
#  '의해': <gensim.models.keyedvectors.Vocab at 0x1c456835128>,
#  '아이': <gensim.models.keyedvectors.Vocab at 0x1c456835160>,
#  '의원직': <gensim.models.keyedvectors.Vocab at 0x1c456835198>,
#  '무분별한': <gensim.models.keyedvectors.Vocab at 0x1c4568351d0>,
#  '단속을': <gensim.models.keyedvectors.Vocab at 0x1c456835208>,
#  '청원에': <gensim.models.keyedvectors.Vocab at 0x1c456835240>,
#  '오히려': <gensim.models.keyedvectors.Vocab at 0x1c456835278>,
#  '할': <gensim.models.keyedvectors.Vocab at 0x1c4568352b0>,
#  '치료제인': <gensim.models.keyedvectors.Vocab at 0x1c4568352e8>,
#  '인권침해': <gensim.models.keyedvectors.Vocab at 0x1c456835320>,
#  '인권유린': <gensim.models.keyedvectors.Vocab at 0x1c456835358>,
#  '전쟁': <gensim.models.keyedvectors.Vocab at 0x1c456835390>,
#  '선거': <gensim.models.keyedvectors.Vocab at 0x1c4568353c8>,
#  '폐지되어야': <gensim.models.keyedvectors.Vocab at 0x1c456835400>,
#  '마세요': <gensim.models.keyedvectors.Vocab at 0x1c456835438>,
#  '딸': <gensim.models.keyedvectors.Vocab at 0x1c456835470>,
#  '채용비리': <gensim.models.keyedvectors.Vocab at 0x1c4568354a8>,
#  '어린': <gensim.models.keyedvectors.Vocab at 0x1c4568354e0>,
#  '여자아이': <gensim.models.keyedvectors.Vocab at 0x1c456835518>,
#  '탈북자': <gensim.models.keyedvectors.Vocab at 0x1c456835550>,
#  '강제북송을': <gensim.models.keyedvectors.Vocab at 0x1c456835588>,
#  '일보': <gensim.models.keyedvectors.Vocab at 0x1c4568355c0>,
#  '파리': <gensim.models.keyedvectors.Vocab at 0x1c4568355f8>,
#  '성폭행가정폭력': <gensim.models.keyedvectors.Vocab at 0x1c456835630>,
#  '패스트트랙': <gensim.models.keyedvectors.Vocab at 0x1c456835668>,
#  '의원의': <gensim.models.keyedvectors.Vocab at 0x1c4568356a0>,
#  '이런': <gensim.models.keyedvectors.Vocab at 0x1c4568356d8>,
#  '그냥': <gensim.models.keyedvectors.Vocab at 0x1c456835710>,
#  '안': <gensim.models.keyedvectors.Vocab at 0x1c456835748>,
#  '됩니다': <gensim.models.keyedvectors.Vocab at 0x1c456835780>,
#  '갑질과': <gensim.models.keyedvectors.Vocab at 0x1c4568357b8>,
#  '인해': <gensim.models.keyedvectors.Vocab at 0x1c4568357f0>,
#  '선량한': <gensim.models.keyedvectors.Vocab at 0x1c456835828>,
#  '탄핵을': <gensim.models.keyedvectors.Vocab at 0x1c456835860>,
#  '대금': <gensim.models.keyedvectors.Vocab at 0x1c456835898>,
#  '아닙니까': <gensim.models.keyedvectors.Vocab at 0x1c4568358d0>,
#  '타워크레인': <gensim.models.keyedvectors.Vocab at 0x1c456835908>,
#  '조선': <gensim.models.keyedvectors.Vocab at 0x1c456835940>,
#  '광주': <gensim.models.keyedvectors.Vocab at 0x1c456835978>,
#  '민주화': <gensim.models.keyedvectors.Vocab at 0x1c4568359b0>,
#  '공개해주십시오': <gensim.models.keyedvectors.Vocab at 0x1c4568359e8>,
#  '고소장을': <gensim.models.keyedvectors.Vocab at 0x1c456835a20>,
#  '강요하며': <gensim.models.keyedvectors.Vocab at 0x1c456835a58>,
#  '형사': <gensim.models.keyedvectors.Vocab at 0x1c456835a90>,
#  '맞습니까': <gensim.models.keyedvectors.Vocab at 0x1c456835ac8>,
#  '학대한': <gensim.models.keyedvectors.Vocab at 0x1c456835b00>,
#  '날': <gensim.models.keyedvectors.Vocab at 0x1c456835b38>,
#  '진짜': <gensim.models.keyedvectors.Vocab at 0x1c456835b70>,
#  '서민': <gensim.models.keyedvectors.Vocab at 0x1c456835ba8>,
#  '철회하라': <gensim.models.keyedvectors.Vocab at 0x1c456835be0>,
#  '됩니까': <gensim.models.keyedvectors.Vocab at 0x1c456835c18>,
#  '여러분': <gensim.models.keyedvectors.Vocab at 0x1c456835c50>,
#  '엄마입니다': <gensim.models.keyedvectors.Vocab at 0x1c456835c88>,
#  '솜방망이': <gensim.models.keyedvectors.Vocab at 0x1c456835cc0>,
#  '옆': <gensim.models.keyedvectors.Vocab at 0x1c456835cf8>,
#  '철회해주세요': <gensim.models.keyedvectors.Vocab at 0x1c456835d30>,
#  '파렴치한': <gensim.models.keyedvectors.Vocab at 0x1c456835d68>,
#  '일가를': <gensim.models.keyedvectors.Vocab at 0x1c456835da0>,
#  '힘으로': <gensim.models.keyedvectors.Vocab at 0x1c456835dd8>,
#  '엄벌에': <gensim.models.keyedvectors.Vocab at 0x1c456835e10>,
#  '처해주세요': <gensim.models.keyedvectors.Vocab at 0x1c456835e48>,
#  '사용금지': <gensim.models.keyedvectors.Vocab at 0x1c456835e80>,
#  '위기에': <gensim.models.keyedvectors.Vocab at 0x1c456835eb8>,
#  '처한': <gensim.models.keyedvectors.Vocab at 0x1c456835ef0>,
#  '명을': <gensim.models.keyedvectors.Vocab at 0x1c456835f28>,
#  '가장한': <gensim.models.keyedvectors.Vocab at 0x1c456835f60>,
#  '만행을': <gensim.models.keyedvectors.Vocab at 0x1c456835f98>,
#  '해산과': <gensim.models.keyedvectors.Vocab at 0x1c456835fd0>,
#  '부당해고와': <gensim.models.keyedvectors.Vocab at 0x1c456839048>,
#  '당한': <gensim.models.keyedvectors.Vocab at 0x1c456839080>,
#  '출신의': <gensim.models.keyedvectors.Vocab at 0x1c4568390b8>,
#  '삼아': <gensim.models.keyedvectors.Vocab at 0x1c4568390f0>,
#  '지역의': <gensim.models.keyedvectors.Vocab at 0x1c456839128>,
#  '지역구': <gensim.models.keyedvectors.Vocab at 0x1c456839160>,
#  '전국': <gensim.models.keyedvectors.Vocab at 0x1c456839198>,
#  '조정해': <gensim.models.keyedvectors.Vocab at 0x1c4568391d0>,
#  '제정을': <gensim.models.keyedvectors.Vocab at 0x1c456839208>,
#  '그것이': <gensim.models.keyedvectors.Vocab at 0x1c456839240>,
#  '국회선진화법': <gensim.models.keyedvectors.Vocab at 0x1c456839278>,
#  '위반': <gensim.models.keyedvectors.Vocab at 0x1c4568392b0>,
#  '날을': <gensim.models.keyedvectors.Vocab at 0x1c4568392e8>,
#  '어느': <gensim.models.keyedvectors.Vocab at 0x1c456839320>,
#  '장기기증': <gensim.models.keyedvectors.Vocab at 0x1c456839358>,
#  '유가족을': <gensim.models.keyedvectors.Vocab at 0x1c456839390>,
#  '말고': <gensim.models.keyedvectors.Vocab at 0x1c4568393c8>,
#  '청와대': <gensim.models.keyedvectors.Vocab at 0x1c456839400>,
#  '국민': <gensim.models.keyedvectors.Vocab at 0x1c456839438>,
#  '외국인들이': <gensim.models.keyedvectors.Vocab at 0x1c456839470>,
#  '의견': <gensim.models.keyedvectors.Vocab at 0x1c4568394a8>,
#  '폐쇄를': <gensim.models.keyedvectors.Vocab at 0x1c4568394e0>,
#  '회사': <gensim.models.keyedvectors.Vocab at 0x1c456839518>,
#  '궁금합니다': <gensim.models.keyedvectors.Vocab at 0x1c456839550>,
#  '문무일': <gensim.models.keyedvectors.Vocab at 0x1c456839588>,
#  '파면을': <gensim.models.keyedvectors.Vocab at 0x1c4568395c0>,
#  '검찰총장과': <gensim.models.keyedvectors.Vocab at 0x1c4568395f8>,
#  '교체': <gensim.models.keyedvectors.Vocab at 0x1c456839630>,
#  '남편': <gensim.models.keyedvectors.Vocab at 0x1c456839668>,
#  '죽음': <gensim.models.keyedvectors.Vocab at 0x1c4568396a0>,
#  '아동학대를': <gensim.models.keyedvectors.Vocab at 0x1c4568396d8>,
#  '일삼은': <gensim.models.keyedvectors.Vocab at 0x1c456839710>,
#  '투표': <gensim.models.keyedvectors.Vocab at 0x1c456839748>,
#  '무시하는': <gensim.models.keyedvectors.Vocab at 0x1c456839780>,
#  '해임해주세요': <gensim.models.keyedvectors.Vocab at 0x1c4568397b8>,
#  '도쿄': <gensim.models.keyedvectors.Vocab at 0x1c4568397f0>,
#  '올림픽': <gensim.models.keyedvectors.Vocab at 0x1c456839828>,
#  '교육의': <gensim.models.keyedvectors.Vocab at 0x1c456839860>,
#  '치료받을': <gensim.models.keyedvectors.Vocab at 0x1c456839898>,
#  '있습니까': <gensim.models.keyedvectors.Vocab at 0x1c4568398d0>,
#  '비례대표': <gensim.models.keyedvectors.Vocab at 0x1c456839908>,
#  '국회로': <gensim.models.keyedvectors.Vocab at 0x1c456839940>,
#  '재조사': <gensim.models.keyedvectors.Vocab at 0x1c456839978>,
#  '해임을': <gensim.models.keyedvectors.Vocab at 0x1c4568399b0>,
#  ...}

# %%
embedding_model_20["즉각"]
# Out:
# C:\Users\YOUNG\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([-0.07727563, -1.1248949 ,  1.0419977 ,  0.660733  , -1.218778  ,
#        -1.6730449 ,  0.05332053, -0.09975209, -0.44503036, -0.904519  ,
#         0.39847845,  0.7859707 , -1.3230745 , -0.7848779 , -2.0978835 ,
#        -0.32639283,  0.24013287, -1.6218925 , -1.2316636 , -0.34637183],
#       dtype=float32)

# %%
print(embedding_model_20.wv.most_similar("국민"))
# Out:
# [('이유로', 0.8116465210914612), ('외국인들이', 0.8027549982070923), ('중소기업이', 0.7772419452667236), ('생명', 0.7730544805526733), ('여러분께', 0.7662830352783203), ('전기요금', 0.7456650733947754), ('안', 0.7361467480659485), ('기자실', 0.7237789630889893), ('암환자', 0.7198678255081177), ('여러분', 0.7166993618011475)]

# %%
embedding_model_20.wv.most_similar(positive=["공무원","문제점"], negative=["근로자"], topn=9)
# Out:
# [('명을', 0.6938477754592896),
#  ('관련', 0.6902395486831665),
#  ('국토부', 0.6744182705879211),
#  ('일베', 0.6729520559310913),
#  ('제재해주세요', 0.6711760759353638),
#  ('이게', 0.6666595935821533),
#  ('퇴출', 0.6576916575431824),
#  ('여고생', 0.6563912034034729),
#  ('시켜주세요', 0.6563578844070435)]

# %%
dir(embedding_model_20.wv)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_adapt_by_suffix',
#  '_load_specials',
#  '_log_evaluate_word_analogies',
#  '_save_specials',
#  '_smart_save',
#  'accuracy',
#  'add',
#  'closer_than',
#  'cosine_similarities',
#  'distance',
#  'distances',
#  'doesnt_match',
#  'evaluate_word_analogies',
#  'evaluate_word_pairs',
#  'get_keras_embedding',
#  'get_vector',
#  'index2entity',
#  'index2word',
#  'init_sims',
#  'load',
#  'load_word2vec_format',
#  'log_accuracy',
#  'log_evaluate_word_pairs',
#  'most_similar',
#  'most_similar_cosmul',
#  'most_similar_to_given',
#  'n_similarity',
#  'rank',
#  'relative_cosine_similarity',
#  'save',
#  'save_word2vec_format',
#  'similar_by_vector',
#  'similar_by_word',
#  'similarity',
#  'similarity_matrix',
#  'syn0',
#  'syn0norm',
#  'vector_size',
#  'vectors',
#  'vectors_norm',
#  'vocab',
#  'wmdistance',
#  'word_vec',
#  'words_closer_than',
#  'wv']

# %%
embedding_model_20.wv.similarity("국민", "공무원")
# Out:
# 0.6550467

# %%
embedding_model_20.wv.distance("국민", "공무원")
# Out:
# 0.3449532985687256
